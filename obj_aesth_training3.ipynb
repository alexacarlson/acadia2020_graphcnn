# %%
## install the pytorch3d package; hit 'shift+enter' keys to run
# !conda create --name pytorch3d --yes
# !conda activate pytorch3d
# !python3 -m pip install --upgrade numpy
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch --yes
# !conda install -c conda-forge -c takatosp1 fvcore --yes
# !conda install pytorch3d -c pytorch3d --yes
# !python3 -m pip install tqdm pandas scipy opencv-python 
# !python3 -m pip install --upgrade matplotlib --ignore-installed certifi

# %%
## download the concerthall optimization code base; hit 'shift+enter' keys to run
#!rm -rf /storage/acadia2020_graphcnn
#!git clone https://github.com/alexacarlson/acadia2020_graphcnn.git /storage/acadia2020_graphcnn

## check size of dataset/verts etc
# !python check_dataset.py

# %%
## Train the graph convolutional neural network; hit 'shift+enter' keys to run
## NOTES on Training the Graph Convolutional Neural network to map 3D meshes --> aesthetic and functionality parameters:
## To train your own graph convolutional network, you first need to create a folder in paperspace storage 
## at `/storage/concert_dataset` upload your data there. All of your meshes should be `.obj` files and
## should exist in a subdirectory of the dataset: `/storage/acadia2020_graphcnn_dataset/Separated/`. 
## You will need to have a csv file of label/parameters (where each line is in the format `mesh.obj label1 label2 ... label10`) 
## located at and named `/storage/acadia2020_graphcnn_dataset/NamingBookV2.csv`.
## The results (network weights and training loss values) will be saved to `/storage/acadia2020_graphcnn_training_results`.
##
## Note that this function takes in the absolute filepath of a configuration file (CFG_PATH) that sets up the network architecture.
## ## To train on 4 labels:
#!cd /storage/acadia2020_graphcnn && bash run_train_graphconv_regression.sh "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
#!cd /tf/notebooks/acadia2020_graphcnn_src && bash run_train_graphconv_regression.sh "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"

#!CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"
# !CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train3.yml"

# %%
## train on single class: house
# !CUDA_VISIBLE_DEVICES=2 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_house.yml"

# %%
## train on single task: aesthetics
# !CUDA_VISIBLE_DEVICES=3 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singletask_aesthetics.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: all
#   WHICH_TASK: aesthetic
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf_singletask
# OPTIM:
#   BATCH_SIZE: 32
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 1000
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_24_13_36_03_ai_aesthetics_optim_centered_bs32_lr2e-4_hd128_256_512_taskaesthetic_nettype-GraphConvClf_singletask_class-all
#   full_experiment_name: exp_11_24_13_36_03_ai_aesthetics_optim_centered_bs32_lr2e-4_hd128_256_512_taskaesthetic_nettype-GraphConvClf_singletask_class-all
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singletask_aesthetics.yml
# config_override     : []
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# number of training samples: 2076
# Training Samples: 65
# Validation Samples: 100
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 155.861, tensor([155.8610])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 21 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 151.636, tensor([151.6360])
#
# 	 EPOCH 2, totalloss: 148.428, tensor([148.4280])
#
# 	 EPOCH 3, totalloss: 147.246, tensor([147.2460])
#
# 	 EPOCH 4, totalloss: 144.059, tensor([144.0590])
#
# 	 EPOCH 5, totalloss: 141.696, tensor([141.6960])
#
# 	 EPOCH 6, totalloss: 139.099, tensor([139.0990])
#
# 	 EPOCH 7, totalloss: 136.501, tensor([136.5010])
#
# 	 EPOCH 8, totalloss: 134.881, tensor([134.8810])
#
# 	 EPOCH 9, totalloss: 134.367, tensor([134.3670])
#
# 	 EPOCH 10, totalloss: 131.66, tensor([131.6600])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 11, totalloss: 132.051, tensor([132.0510])
#
# 	 EPOCH 12, totalloss: 128.256, tensor([128.2560])
#
# 	 EPOCH 13, totalloss: 127.083, tensor([127.0830])
#
# 	 EPOCH 14, totalloss: 126.151, tensor([126.1510])
#
# 	 EPOCH 15, totalloss: 124.514, tensor([124.5140])
#
# 	 EPOCH 16, totalloss: 125.073, tensor([125.0730])
#
# 	 EPOCH 17, totalloss: 125.227, tensor([125.2270])
#
# 	 EPOCH 18, totalloss: 120.977, tensor([120.9770])
#
# 	 EPOCH 19, totalloss: 119.492, tensor([119.4920])
#
# 	 EPOCH 20, totalloss: 119.155, tensor([119.1550])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 21, totalloss: 118.473, tensor([118.4730])
#
# 	 EPOCH 22, totalloss: 118.935, tensor([118.9350])
#
# 	 EPOCH 23, totalloss: 119.522, tensor([119.5220])
#
# 	 EPOCH 24, totalloss: 119.364, tensor([119.3640])
#
# 	 EPOCH 25, totalloss: 118.598, tensor([118.5980])
#
# 	 EPOCH 26, totalloss: 117.922, tensor([117.9220])
#
# 	 EPOCH 27, totalloss: 114.579, tensor([114.5790])
#
# 	 EPOCH 28, totalloss: 114.166, tensor([114.1660])
#
# 	 EPOCH 29, totalloss: 114.407, tensor([114.4070])
#
# 	 EPOCH 30, totalloss: 111.507, tensor([111.5070])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 41 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 31, totalloss: 116.863, tensor([116.8630])
#
# 	 EPOCH 32, totalloss: 110.99, tensor([110.9900])
#
# 	 EPOCH 33, totalloss: 109.674, tensor([109.6740])
#
# 	 EPOCH 34, totalloss: 111.65, tensor([111.6500])
#
# 	 EPOCH 35, totalloss: 108.515, tensor([108.5150])
#
# 	 EPOCH 36, totalloss: 110.062, tensor([110.0620])
#
# 	 EPOCH 37, totalloss: 108.351, tensor([108.3510])
#
# 	 EPOCH 38, totalloss: 105.985, tensor([105.9850])
#
# 	 EPOCH 39, totalloss: 107.412, tensor([107.4120])
#
# 	 EPOCH 40, totalloss: 104.371, tensor([104.3710])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 47 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 41, totalloss: 106.195, tensor([106.1950])
#
# 	 EPOCH 42, totalloss: 107.135, tensor([107.1350])
#
# 	 EPOCH 43, totalloss: 105.601, tensor([105.6010])
#
# 	 EPOCH 44, totalloss: 101.648, tensor([101.6480])
#
# 	 EPOCH 45, totalloss: 106.167, tensor([106.1670])
#
# 	 EPOCH 46, totalloss: 102.897, tensor([102.8970])
#
# 	 EPOCH 47, totalloss: 102.457, tensor([102.4570])
#
# 	 EPOCH 48, totalloss: 101.785, tensor([101.7850])
#
# 	 EPOCH 49, totalloss: 102.988, tensor([102.9880])
#
# 	 EPOCH 50, totalloss: 99.927, tensor([99.9270])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 51, totalloss: 97.933, tensor([97.9330])
#
# 	 EPOCH 52, totalloss: 97.33, tensor([97.3300])
#
# 	 EPOCH 53, totalloss: 100.088, tensor([100.0880])
#
# 	 EPOCH 54, totalloss: 98.875, tensor([98.8750])
#
# 	 EPOCH 55, totalloss: 98.147, tensor([98.1470])
#
# 	 EPOCH 56, totalloss: 99.214, tensor([99.2140])
#
# 	 EPOCH 57, totalloss: 97.252, tensor([97.2520])
#
# 	 EPOCH 58, totalloss: 97.681, tensor([97.6810])
#
# 	 EPOCH 59, totalloss: 95.123, tensor([95.1230])
#
# 	 EPOCH 60, totalloss: 96.365, tensor([96.3650])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 44 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 61, totalloss: 95.952, tensor([95.9520])
#
# 	 EPOCH 62, totalloss: 95.672, tensor([95.6720])
#
# 	 EPOCH 63, totalloss: 95.424, tensor([95.4240])
#
# 	 EPOCH 64, totalloss: 94.309, tensor([94.3090])
#
# 	 EPOCH 65, totalloss: 93.056, tensor([93.0560])
#
# 	 EPOCH 66, totalloss: 92.175, tensor([92.1750])
#
# 	 EPOCH 67, totalloss: 90.831, tensor([90.8310])
#
# 	 EPOCH 68, totalloss: 92.556, tensor([92.5560])
#
# 	 EPOCH 69, totalloss: 93.363, tensor([93.3630])
#
# 	 EPOCH 70, totalloss: 93.675, tensor([93.6750])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 55 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 71, totalloss: 90.68, tensor([90.6800])
#
# 	 EPOCH 72, totalloss: 90.126, tensor([90.1260])
#
# 	 EPOCH 73, totalloss: 89.69, tensor([89.6900])
#
# 	 EPOCH 74, totalloss: 90.185, tensor([90.1850])
#
# 	 EPOCH 75, totalloss: 88.595, tensor([88.5950])
#
# 	 EPOCH 76, totalloss: 87.804, tensor([87.8040])
#
# 	 EPOCH 77, totalloss: 88.452, tensor([88.4520])
#
# 	 EPOCH 78, totalloss: 91.727, tensor([91.7270])
#
# 	 EPOCH 79, totalloss: 90.649, tensor([90.6490])
#
# 	 EPOCH 80, totalloss: 87.523, tensor([87.5230])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 81, totalloss: 89.797, tensor([89.7970])
#
# 	 EPOCH 82, totalloss: 86.887, tensor([86.8870])
#
# 	 EPOCH 83, totalloss: 86.606, tensor([86.6060])
#
# 	 EPOCH 84, totalloss: 84.68, tensor([84.6800])
#
# 	 EPOCH 85, totalloss: 85.142, tensor([85.1420])
#
# 	 EPOCH 86, totalloss: 83.431, tensor([83.4310])
#
# 	 EPOCH 87, totalloss: 84.482, tensor([84.4820])
#
# 	 EPOCH 88, totalloss: 88.929, tensor([88.9290])
#
# 	 EPOCH 89, totalloss: 85.43, tensor([85.4300])
#
# 	 EPOCH 90, totalloss: 84.847, tensor([84.8470])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 91, totalloss: 85.952, tensor([85.9520])
#
# 	 EPOCH 92, totalloss: 84.611, tensor([84.6110])
# 	 EPOCH 93, totalloss: 84.067, tensor([84.0680])
#
# 	 EPOCH 94, totalloss: 84.345, tensor([84.3450])
#
# 	 EPOCH 95, totalloss: 83.575, tensor([83.5750])
#
# 	 EPOCH 96, totalloss: 81.484, tensor([81.4840])
#
# 	 EPOCH 97, totalloss: 82.85, tensor([82.8500])
#
# 	 EPOCH 98, totalloss: 83.378, tensor([83.3780])
#
# 	 EPOCH 99, totalloss: 81.866, tensor([81.8660])
#
# 	 EPOCH 100, totalloss: 82.757, tensor([82.7570])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 101, totalloss: 82.76, tensor([82.7600])
#
# 	 EPOCH 102, totalloss: 81.776, tensor([81.7760])
#
# 	 EPOCH 103, totalloss: 80.7, tensor([80.7000])
#
# 	 EPOCH 104, totalloss: 79.633, tensor([79.6330])
#
# 	 EPOCH 105, totalloss: 81.702, tensor([81.7020])
#
# 	 EPOCH 106, totalloss: 81.803, tensor([81.8030])
#
# 	 EPOCH 107, totalloss: 81.058, tensor([81.0580])
#
# 	 EPOCH 108, totalloss: 80.266, tensor([80.2660])
#
# 	 EPOCH 109, totalloss: 79.582, tensor([79.5820])
#
# 	 EPOCH 110, totalloss: 80.814, tensor([80.8140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 111, totalloss: 80.954, tensor([80.9540])
#
# 	 EPOCH 112, totalloss: 79.411, tensor([79.4110])
#
# 	 EPOCH 113, totalloss: 81.998, tensor([81.9980])
#
# 	 EPOCH 114, totalloss: 78.702, tensor([78.7020])
#
# 	 EPOCH 115, totalloss: 77.363, tensor([77.3630])
#
# 	 EPOCH 116, totalloss: 77.988, tensor([77.9880])
#
# 	 EPOCH 117, totalloss: 77.599, tensor([77.5990])
#
# 	 EPOCH 118, totalloss: 78.574, tensor([78.5740])
#
# 	 EPOCH 119, totalloss: 77.18, tensor([77.1800])
#
# 	 EPOCH 120, totalloss: 78.493, tensor([78.4930])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 121, totalloss: 78.482, tensor([78.4820])
#
# 	 EPOCH 122, totalloss: 78.136, tensor([78.1360])
#
# 	 EPOCH 123, totalloss: 76.712, tensor([76.7120])
#
# 	 EPOCH 124, totalloss: 77.58, tensor([77.5800])
#
# 	 EPOCH 125, totalloss: 77.199, tensor([77.1990])
#
# 	 EPOCH 126, totalloss: 76.277, tensor([76.2770])
#
# 	 EPOCH 127, totalloss: 77.861, tensor([77.8610])
#
# 	 EPOCH 128, totalloss: 75.131, tensor([75.1310])
#
# 	 EPOCH 129, totalloss: 73.816, tensor([73.8160])
#
# 	 EPOCH 130, totalloss: 76.176, tensor([76.1760])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 131, totalloss: 73.46, tensor([73.4600])
#
# 	 EPOCH 132, totalloss: 77.72, tensor([77.7200])
#
# 	 EPOCH 133, totalloss: 75.873, tensor([75.8730])
#
# 	 EPOCH 134, totalloss: 76.217, tensor([76.2170])
#
# 	 EPOCH 135, totalloss: 75.399, tensor([75.3990])
#
# 	 EPOCH 136, totalloss: 76.515, tensor([76.5140])
#
# 	 EPOCH 137, totalloss: 77.973, tensor([77.9730])
#
# 	 EPOCH 138, totalloss: 73.922, tensor([73.9220])
#
# 	 EPOCH 139, totalloss: 74.32, tensor([74.3200])
#
# 	 EPOCH 140, totalloss: 73.812, tensor([73.8120])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 141, totalloss: 76.304, tensor([76.3040])
#
# 	 EPOCH 142, totalloss: 73.819, tensor([73.8190])
#
# 	 EPOCH 143, totalloss: 71.118, tensor([71.1180])
#
# 	 EPOCH 144, totalloss: 73.995, tensor([73.9950])
#
# 	 EPOCH 145, totalloss: 73.075, tensor([73.0750])
#
# 	 EPOCH 146, totalloss: 72.848, tensor([72.8480])
#
# 	 EPOCH 147, totalloss: 75.953, tensor([75.9530])
#
# 	 EPOCH 148, totalloss: 71.876, tensor([71.8760])
#
# 	 EPOCH 149, totalloss: 74.842, tensor([74.8420])
#
# 	 EPOCH 150, totalloss: 72.132, tensor([72.1320])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 151, totalloss: 75.378, tensor([75.3780])
#
# 	 EPOCH 152, totalloss: 73.154, tensor([73.1540])
#
# 	 EPOCH 153, totalloss: 70.284, tensor([70.2840])
#
# 	 EPOCH 154, totalloss: 70.674, tensor([70.6740])
#
# 	 EPOCH 155, totalloss: 71.105, tensor([71.1050])
#
# 	 EPOCH 156, totalloss: 70.989, tensor([70.9890])
#
# 	 EPOCH 157, totalloss: 71.25, tensor([71.2500])
#
# 	 EPOCH 158, totalloss: 70.501, tensor([70.5010])
#
# 	 EPOCH 159, totalloss: 73.417, tensor([73.4170])
#
# 	 EPOCH 160, totalloss: 71.34, tensor([71.3400])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 161, totalloss: 73.157, tensor([73.1570])
#
# 	 EPOCH 162, totalloss: 71.071, tensor([71.0710])
#
# 	 EPOCH 163, totalloss: 70.76, tensor([70.7600])
#
# 	 EPOCH 164, totalloss: 71.536, tensor([71.5360])
#
# 	 EPOCH 165, totalloss: 71.233, tensor([71.2330])
#
# 	 EPOCH 166, totalloss: 72.722, tensor([72.7220])
#
# 	 EPOCH 167, totalloss: 71.407, tensor([71.4070])
#
# 	 EPOCH 168, totalloss: 69.358, tensor([69.3580])
#
# 	 EPOCH 169, totalloss: 70.238, tensor([70.2380])
#
# 	 EPOCH 170, totalloss: 70.296, tensor([70.2960])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 171, totalloss: 69.976, tensor([69.9760])
#
# 	 EPOCH 172, totalloss: 70.009, tensor([70.0090])
#
# 	 EPOCH 173, totalloss: 71.861, tensor([71.8610])
#
# 	 EPOCH 174, totalloss: 68.635, tensor([68.6350])
#
# 	 EPOCH 175, totalloss: 70.707, tensor([70.7070])
#
# 	 EPOCH 176, totalloss: 69.597, tensor([69.5970])
#
# 	 EPOCH 177, totalloss: 71.05, tensor([71.0500])
#
# 	 EPOCH 178, totalloss: 67.835, tensor([67.8350])
#
# 	 EPOCH 179, totalloss: 68.889, tensor([68.8890])
#
# 	 EPOCH 180, totalloss: 68.167, tensor([68.1670])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 181, totalloss: 69.196, tensor([69.1960])
#
# 	 EPOCH 182, totalloss: 68.178, tensor([68.1780])
#
# 	 EPOCH 183, totalloss: 67.482, tensor([67.4820])
#
# 	 EPOCH 184, totalloss: 70.063, tensor([70.0630])
#
# 	 EPOCH 185, totalloss: 69.611, tensor([69.6110])
#
# 	 EPOCH 186, totalloss: 68.649, tensor([68.6490])
#
# 	 EPOCH 187, totalloss: 72.436, tensor([72.4360])
#
# 	 EPOCH 188, totalloss: 68.541, tensor([68.5410])
#
# 	 EPOCH 189, totalloss: 67.22, tensor([67.2200])
#
# 	 EPOCH 190, totalloss: 68.775, tensor([68.7750])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 191, totalloss: 68.736, tensor([68.7360])
#
# 	 EPOCH 192, totalloss: 66.335, tensor([66.3350])
#
# 	 EPOCH 193, totalloss: 67.974, tensor([67.9740])
#
# 	 EPOCH 194, totalloss: 69.09, tensor([69.0900])
#
# 	 EPOCH 195, totalloss: 67.604, tensor([67.6040])
#
# 	 EPOCH 196, totalloss: 68.215, tensor([68.2150])
#
# 	 EPOCH 197, totalloss: 68.082, tensor([68.0820])
#
# 	 EPOCH 198, totalloss: 68.049, tensor([68.0490])
#
# 	 EPOCH 199, totalloss: 68.232, tensor([68.2320])
#
# 	 EPOCH 200, totalloss: 67.954, tensor([67.9540])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 201, totalloss: 66.354, tensor([66.3540])
#
# 	 EPOCH 202, totalloss: 66.635, tensor([66.6350])
#
# 	 EPOCH 203, totalloss: 65.277, tensor([65.2770])
#
# 	 EPOCH 204, totalloss: 66.09, tensor([66.0900])
#
# 	 EPOCH 205, totalloss: 68.038, tensor([68.0380])
# 	 EPOCH 206, totalloss: 66.32, tensor([66.3200])
#
# 	 EPOCH 207, totalloss: 67.264, tensor([67.2640])
#
# 	 EPOCH 208, totalloss: 65.23, tensor([65.2300])
#
# 	 EPOCH 209, totalloss: 67.203, tensor([67.2030])
#
# 	 EPOCH 210, totalloss: 69.264, tensor([69.2640])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 211, totalloss: 66.466, tensor([66.4660])
#
# 	 EPOCH 212, totalloss: 65.986, tensor([65.9860])
#
# 	 EPOCH 213, totalloss: 64.894, tensor([64.8940])
#
# 	 EPOCH 214, totalloss: 65.638, tensor([65.6380])
#
# 	 EPOCH 215, totalloss: 66.286, tensor([66.2860])
#
# 	 EPOCH 216, totalloss: 64.755, tensor([64.7550])
#
# 	 EPOCH 217, totalloss: 66.918, tensor([66.9180])
#
# 	 EPOCH 218, totalloss: 65.44, tensor([65.4400])
#
# 	 EPOCH 219, totalloss: 66.955, tensor([66.9550])
#
# 	 EPOCH 220, totalloss: 65.168, tensor([65.1680])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 221, totalloss: 65.51, tensor([65.5100])
#
# 	 EPOCH 222, totalloss: 66.074, tensor([66.0740])
#
# 	 EPOCH 223, totalloss: 67.631, tensor([67.6310])
#
# 	 EPOCH 224, totalloss: 66.095, tensor([66.0950])
#
# 	 EPOCH 225, totalloss: 65.164, tensor([65.1640])
#
# 	 EPOCH 226, totalloss: 64.987, tensor([64.9870])
#
# 	 EPOCH 227, totalloss: 63.766, tensor([63.7660])
#
# 	 EPOCH 228, totalloss: 65.704, tensor([65.7040])
#
# 	 EPOCH 229, totalloss: 64.003, tensor([64.0030])
#
# 	 EPOCH 230, totalloss: 65.001, tensor([65.0010])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 231, totalloss: 65.417, tensor([65.4170])
#
# 	 EPOCH 232, totalloss: 62.227, tensor([62.2270])
#
# 	 EPOCH 233, totalloss: 63.454, tensor([63.4540])
#
# 	 EPOCH 234, totalloss: 62.965, tensor([62.9650])
#
# 	 EPOCH 235, totalloss: 65.993, tensor([65.9930])
#
# 	 EPOCH 236, totalloss: 63.662, tensor([63.6620])
#
# 	 EPOCH 237, totalloss: 64.681, tensor([64.6810])
#
# 	 EPOCH 238, totalloss: 62.311, tensor([62.3110])
#
# 	 EPOCH 239, totalloss: 63.518, tensor([63.5180])
#
# 	 EPOCH 240, totalloss: 63.485, tensor([63.4850])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 241, totalloss: 63.54, tensor([63.5400])
#
# 	 EPOCH 242, totalloss: 63.524, tensor([63.5240])
#
# 	 EPOCH 243, totalloss: 64.824, tensor([64.8240])
#
# 	 EPOCH 244, totalloss: 62.896, tensor([62.8960])
#
# 	 EPOCH 245, totalloss: 64.225, tensor([64.2250])
#
# 	 EPOCH 246, totalloss: 63.882, tensor([63.8820])
#
# 	 EPOCH 247, totalloss: 61.924, tensor([61.9240])
#
# 	 EPOCH 248, totalloss: 64.626, tensor([64.6260])
#
# 	 EPOCH 249, totalloss: 62.636, tensor([62.6360])
#
# 	 EPOCH 250, totalloss: 63.951, tensor([63.9510])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 251, totalloss: 60.777, tensor([60.7770])
#
# 	 EPOCH 252, totalloss: 61.294, tensor([61.2940])
#
# 	 EPOCH 253, totalloss: 63.717, tensor([63.7170])
#
# 	 EPOCH 254, totalloss: 63.277, tensor([63.2770])
#
# 	 EPOCH 255, totalloss: 61.418, tensor([61.4180])
#
# 	 EPOCH 256, totalloss: 66.7, tensor([66.6990])
#
# 	 EPOCH 257, totalloss: 69.944, tensor([69.9440])
#
# 	 EPOCH 258, totalloss: 62.759, tensor([62.7590])
#
# 	 EPOCH 259, totalloss: 65.553, tensor([65.5530])
#
# 	 EPOCH 260, totalloss: 61.954, tensor([61.9540])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 261, totalloss: 60.521, tensor([60.5210])
#
# 	 EPOCH 262, totalloss: 62.071, tensor([62.0710])
#
# 	 EPOCH 263, totalloss: 62.77, tensor([62.7700])
#
# 	 EPOCH 264, totalloss: 64.119, tensor([64.1190])
#
# 	 EPOCH 265, totalloss: 60.007, tensor([60.0070])
#
# 	 EPOCH 266, totalloss: 60.835, tensor([60.8350])
#
# 	 EPOCH 267, totalloss: 61.456, tensor([61.4560])
#
# 	 EPOCH 268, totalloss: 62.098, tensor([62.0980])
#
# 	 EPOCH 269, totalloss: 61.205, tensor([61.2050])
#
# 	 EPOCH 270, totalloss: 60.465, tensor([60.4650])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 271, totalloss: 58.844, tensor([58.8440])
#
# 	 EPOCH 272, totalloss: 60.711, tensor([60.7110])
#
# 	 EPOCH 273, totalloss: 63.163, tensor([63.1630])
#
# 	 EPOCH 274, totalloss: 61.013, tensor([61.0130])
#
# 	 EPOCH 275, totalloss: 61.799, tensor([61.7990])
#
# 	 EPOCH 276, totalloss: 61.358, tensor([61.3580])
#
# 	 EPOCH 277, totalloss: 60.508, tensor([60.5080])
#
# 	 EPOCH 278, totalloss: 61.35, tensor([61.3500])
#
# 	 EPOCH 279, totalloss: 61.4, tensor([61.4000])
#
# 	 EPOCH 280, totalloss: 61.049, tensor([61.0490])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 281, totalloss: 61.63, tensor([61.6300])
#
# 	 EPOCH 282, totalloss: 59.683, tensor([59.6830])
#
# 	 EPOCH 283, totalloss: 61.751, tensor([61.7510])
#
# 	 EPOCH 284, totalloss: 63.04, tensor([63.0400])
#
# 	 EPOCH 285, totalloss: 60.184, tensor([60.1840])
#
# 	 EPOCH 286, totalloss: 59.66, tensor([59.6600])
#
# 	 EPOCH 287, totalloss: 59.876, tensor([59.8760])
#
# 	 EPOCH 288, totalloss: 57.945, tensor([57.9450])
#
# 	 EPOCH 289, totalloss: 60.943, tensor([60.9430])
#
# 	 EPOCH 290, totalloss: 59.639, tensor([59.6390])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 291, totalloss: 58.857, tensor([58.8570])
#
# 	 EPOCH 292, totalloss: 59.123, tensor([59.1230])
#
# 	 EPOCH 293, totalloss: 60.349, tensor([60.3490])
#
# 	 EPOCH 294, totalloss: 58.297, tensor([58.2970])
#
# 	 EPOCH 295, totalloss: 58.884, tensor([58.8840])
#
# 	 EPOCH 296, totalloss: 60.489, tensor([60.4890])
#
# 	 EPOCH 297, totalloss: 59.809, tensor([59.8090])
#
# 	 EPOCH 298, totalloss: 58.844, tensor([58.8440])
#
# 	 EPOCH 299, totalloss: 60.023, tensor([60.0230])
#
# 	 EPOCH 300, totalloss: 60.919, tensor([60.9190])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 301, totalloss: 57.286, tensor([57.2860])
#
# 	 EPOCH 302, totalloss: 59.53, tensor([59.5300])
#
# 	 EPOCH 303, totalloss: 58.973, tensor([58.9730])
#
# 	 EPOCH 304, totalloss: 59.033, tensor([59.0330])
#
# 	 EPOCH 305, totalloss: 57.865, tensor([57.8650])
#
# 	 EPOCH 306, totalloss: 60.333, tensor([60.3330])
#
# 	 EPOCH 307, totalloss: 59.468, tensor([59.4680])
#
# 	 EPOCH 308, totalloss: 59.046, tensor([59.0460])
#
# 	 EPOCH 309, totalloss: 59.611, tensor([59.6110])
#
# 	 EPOCH 310, totalloss: 58.533, tensor([58.5330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 311, totalloss: 58.006, tensor([58.0060])
#
# 	 EPOCH 312, totalloss: 58.042, tensor([58.0420])
#
# 	 EPOCH 313, totalloss: 60.385, tensor([60.3850])
#
# 	 EPOCH 314, totalloss: 58.614, tensor([58.6140])
#
# 	 EPOCH 315, totalloss: 58.915, tensor([58.9150])
#
# 	 EPOCH 316, totalloss: 59.496, tensor([59.4960])
#
# 	 EPOCH 317, totalloss: 59.467, tensor([59.4670])
#
# 	 EPOCH 318, totalloss: 58.913, tensor([58.9130])
# 	 EPOCH 319, totalloss: 58.089, tensor([58.0890])
#
# 	 EPOCH 320, totalloss: 58.328, tensor([58.3280])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 321, totalloss: 60.041, tensor([60.0410])
#
# 	 EPOCH 322, totalloss: 57.86, tensor([57.8600])
#
# 	 EPOCH 323, totalloss: 58.37, tensor([58.3700])
#
# 	 EPOCH 324, totalloss: 58.878, tensor([58.8780])
#
# 	 EPOCH 325, totalloss: 56.173, tensor([56.1730])
#
# 	 EPOCH 326, totalloss: 57.302, tensor([57.3020])
#
# 	 EPOCH 327, totalloss: 57.895, tensor([57.8950])
#
# 	 EPOCH 328, totalloss: 57.231, tensor([57.2310])
#
# 	 EPOCH 329, totalloss: 57.443, tensor([57.4430])
#
# 	 EPOCH 330, totalloss: 60.045, tensor([60.0450])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 331, totalloss: 56.775, tensor([56.7750])
#
# 	 EPOCH 332, totalloss: 57.539, tensor([57.5390])
#
# 	 EPOCH 333, totalloss: 56.366, tensor([56.3660])
#
# 	 EPOCH 334, totalloss: 57.424, tensor([57.4240])
#
# 	 EPOCH 335, totalloss: 58.442, tensor([58.4420])
#
# 	 EPOCH 336, totalloss: 59.118, tensor([59.1180])
#
# 	 EPOCH 337, totalloss: 58.278, tensor([58.2780])
#
# 	 EPOCH 338, totalloss: 56.074, tensor([56.0740])
#
# 	 EPOCH 339, totalloss: 56.574, tensor([56.5740])
#
# 	 EPOCH 340, totalloss: 56.727, tensor([56.7270])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 341, totalloss: 59.348, tensor([59.3480])
#
# 	 EPOCH 342, totalloss: 57.772, tensor([57.7720])
#
# 	 EPOCH 343, totalloss: 58.357, tensor([58.3570])
#
# 	 EPOCH 344, totalloss: 59.278, tensor([59.2780])
#
# 	 EPOCH 345, totalloss: 60.289, tensor([60.2890])
#
# 	 EPOCH 346, totalloss: 56.78, tensor([56.7800])
#
# 	 EPOCH 347, totalloss: 56.111, tensor([56.1110])
#
# 	 EPOCH 348, totalloss: 56.582, tensor([56.5820])
#
# 	 EPOCH 349, totalloss: 56.483, tensor([56.4830])
#
# 	 EPOCH 350, totalloss: 58.007, tensor([58.0070])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 351, totalloss: 56.809, tensor([56.8090])
#
# 	 EPOCH 352, totalloss: 57.156, tensor([57.1560])
#
# 	 EPOCH 353, totalloss: 57.679, tensor([57.6790])
#
# 	 EPOCH 354, totalloss: 57.022, tensor([57.0220])
#
# 	 EPOCH 355, totalloss: 55.873, tensor([55.8730])
#
# 	 EPOCH 356, totalloss: 56.606, tensor([56.6060])
#
# 	 EPOCH 357, totalloss: 54.408, tensor([54.4080])
#
# 	 EPOCH 358, totalloss: 57.967, tensor([57.9670])
#
# 	 EPOCH 359, totalloss: 56.202, tensor([56.2020])
#
# 	 EPOCH 360, totalloss: 55.463, tensor([55.4630])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 71 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 361, totalloss: 56.362, tensor([56.3620])
#
# 	 EPOCH 362, totalloss: 59.334, tensor([59.3340])
#
# 	 EPOCH 363, totalloss: 56.013, tensor([56.0130])
#
# 	 EPOCH 364, totalloss: 55.829, tensor([55.8290])
#
# 	 EPOCH 365, totalloss: 54.188, tensor([54.1880])
#
# 	 EPOCH 366, totalloss: 55.849, tensor([55.8490])
#
# 	 EPOCH 367, totalloss: 54.9, tensor([54.9000])
#
# 	 EPOCH 368, totalloss: 56.032, tensor([56.0320])
#
# 	 EPOCH 369, totalloss: 57.344, tensor([57.3440])
#
# 	 EPOCH 370, totalloss: 57.906, tensor([57.9060])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 371, totalloss: 54.823, tensor([54.8230])
#
# 	 EPOCH 372, totalloss: 55.436, tensor([55.4360])
#
# 	 EPOCH 373, totalloss: 57.135, tensor([57.1350])
#
# 	 EPOCH 374, totalloss: 57.44, tensor([57.4400])
#
# 	 EPOCH 375, totalloss: 56.976, tensor([56.9760])
#
# 	 EPOCH 376, totalloss: 55.429, tensor([55.4290])
#
# 	 EPOCH 377, totalloss: 58.358, tensor([58.3580])
#
# 	 EPOCH 378, totalloss: 56.261, tensor([56.2610])
#
# 	 EPOCH 379, totalloss: 53.987, tensor([53.9870])
#
# 	 EPOCH 380, totalloss: 56.624, tensor([56.6240])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 381, totalloss: 57.626, tensor([57.6260])
#
# 	 EPOCH 382, totalloss: 55.493, tensor([55.4930])
#
# 	 EPOCH 383, totalloss: 54.753, tensor([54.7530])
#
# 	 EPOCH 384, totalloss: 55.076, tensor([55.0760])
#
# 	 EPOCH 385, totalloss: 52.995, tensor([52.9950])
#
# 	 EPOCH 386, totalloss: 55.964, tensor([55.9640])
#
# 	 EPOCH 387, totalloss: 55.843, tensor([55.8430])
#
# 	 EPOCH 388, totalloss: 56.557, tensor([56.5570])
#
# 	 EPOCH 389, totalloss: 53.993, tensor([53.9930])
#
# 	 EPOCH 390, totalloss: 54.492, tensor([54.4920])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 391, totalloss: 55.657, tensor([55.6570])
#
# 	 EPOCH 392, totalloss: 54.692, tensor([54.6920])
#
# 	 EPOCH 393, totalloss: 56.054, tensor([56.0540])
#
# 	 EPOCH 394, totalloss: 57.961, tensor([57.9610])
#
# 	 EPOCH 395, totalloss: 54.635, tensor([54.6350])
#
# 	 EPOCH 396, totalloss: 52.647, tensor([52.6470])
#
# 	 EPOCH 397, totalloss: 53.687, tensor([53.6870])
#
# 	 EPOCH 398, totalloss: 52.104, tensor([52.1040])
#
# 	 EPOCH 399, totalloss: 54.47, tensor([54.4700])
#
# 	 EPOCH 400, totalloss: 54.743, tensor([54.7430])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 401, totalloss: 54.06, tensor([54.0600])
#
# 	 EPOCH 402, totalloss: 56.911, tensor([56.9110])
#
# 	 EPOCH 403, totalloss: 53.137, tensor([53.1370])
#
# 	 EPOCH 404, totalloss: 54.743, tensor([54.7430])
#
# 	 EPOCH 405, totalloss: 55.036, tensor([55.0360])
#
# 	 EPOCH 406, totalloss: 54.758, tensor([54.7580])
#
# 	 EPOCH 407, totalloss: 53.871, tensor([53.8710])
#
# 	 EPOCH 408, totalloss: 54.573, tensor([54.5730])
#
# 	 EPOCH 409, totalloss: 53.506, tensor([53.5060])
#
# 	 EPOCH 410, totalloss: 52.981, tensor([52.9810])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 411, totalloss: 54.828, tensor([54.8280])
#
# 	 EPOCH 412, totalloss: 53.006, tensor([53.0060])
#
# 	 EPOCH 413, totalloss: 53.446, tensor([53.4460])
#
# 	 EPOCH 414, totalloss: 53.758, tensor([53.7580])
#
# 	 EPOCH 415, totalloss: 53.374, tensor([53.3740])
#
# 	 EPOCH 416, totalloss: 53.893, tensor([53.8930])
#
# 	 EPOCH 417, totalloss: 53.362, tensor([53.3620])
#
# 	 EPOCH 418, totalloss: 52.574, tensor([52.5740])
#
# 	 EPOCH 419, totalloss: 53.168, tensor([53.1680])
#
# 	 EPOCH 420, totalloss: 54.55, tensor([54.5500])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 421, totalloss: 54.99, tensor([54.9900])
#
# 	 EPOCH 422, totalloss: 52.902, tensor([52.9020])
#
# 	 EPOCH 423, totalloss: 52.972, tensor([52.9720])
#
# 	 EPOCH 424, totalloss: 56.455, tensor([56.4550])
#
# 	 EPOCH 425, totalloss: 56.194, tensor([56.1940])
#
# 	 EPOCH 426, totalloss: 50.629, tensor([50.6290])
#
# 	 EPOCH 427, totalloss: 52.839, tensor([52.8390])
#
# 	 EPOCH 428, totalloss: 54.681, tensor([54.6810])
#
# 	 EPOCH 429, totalloss: 53.465, tensor([53.4650])
#
# 	 EPOCH 430, totalloss: 53.551, tensor([53.5510])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 431, totalloss: 52.515, tensor([52.5150])
#
# 	 EPOCH 432, totalloss: 54.137, tensor([54.1370])
#
# 	 EPOCH 433, totalloss: 52.761, tensor([52.7610])
#
# 	 EPOCH 434, totalloss: 52.806, tensor([52.8060])
#
# 	 EPOCH 435, totalloss: 54.852, tensor([54.8520])
#
# 	 EPOCH 436, totalloss: 56.071, tensor([56.0710])
#
# 	 EPOCH 437, totalloss: 54.548, tensor([54.5480])
#
# 	 EPOCH 438, totalloss: 52.784, tensor([52.7840])
#
# 	 EPOCH 439, totalloss: 52.234, tensor([52.2340])
#
# 	 EPOCH 440, totalloss: 52.836, tensor([52.8360])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 441, totalloss: 52.407, tensor([52.4070])
#
# 	 EPOCH 442, totalloss: 54.372, tensor([54.3720])
#
# 	 EPOCH 443, totalloss: 52.136, tensor([52.1360])
#
# 	 EPOCH 444, totalloss: 53.528, tensor([53.5280])
#
# 	 EPOCH 445, totalloss: 52.748, tensor([52.7480])
#
# 	 EPOCH 446, totalloss: 52.064, tensor([52.0640])
#
# 	 EPOCH 447, totalloss: 51.322, tensor([51.3220])
#
# 	 EPOCH 448, totalloss: 53.255, tensor([53.2550])
#
# 	 EPOCH 449, totalloss: 54.128, tensor([54.1280])
#
# 	 EPOCH 450, totalloss: 54.146, tensor([54.1460])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 451, totalloss: 51.046, tensor([51.0460])
#
# 	 EPOCH 452, totalloss: 50.978, tensor([50.9780])
#
# 	 EPOCH 453, totalloss: 50.992, tensor([50.9920])
#
# 	 EPOCH 454, totalloss: 53.302, tensor([53.3020])
#
# 	 EPOCH 455, totalloss: 52.777, tensor([52.7770])
#
# 	 EPOCH 456, totalloss: 51.9, tensor([51.9000])
#
# 	 EPOCH 457, totalloss: 52.038, tensor([52.0380])
#
# 	 EPOCH 458, totalloss: 51.428, tensor([51.4280])
#
# 	 EPOCH 459, totalloss: 53.073, tensor([53.0730])
#
# 	 EPOCH 460, totalloss: 51.608, tensor([51.6080])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 461, totalloss: 52.163, tensor([52.1630])
#
# 	 EPOCH 462, totalloss: 51.688, tensor([51.6880])
#
# 	 EPOCH 463, totalloss: 53.464, tensor([53.4640])
#
# 	 EPOCH 464, totalloss: 51.825, tensor([51.8250])
#
# 	 EPOCH 465, totalloss: 52.064, tensor([52.0640])
#
# 	 EPOCH 466, totalloss: 51.676, tensor([51.6760])
#
# 	 EPOCH 467, totalloss: 50.626, tensor([50.6260])
#
# 	 EPOCH 468, totalloss: 53.258, tensor([53.2580])
#
# 	 EPOCH 469, totalloss: 53.803, tensor([53.8030])
#
# 	 EPOCH 470, totalloss: 52.388, tensor([52.3880])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 471, totalloss: 51.491, tensor([51.4910])
#
# 	 EPOCH 472, totalloss: 51.939, tensor([51.9390])
#
# 	 EPOCH 473, totalloss: 50.662, tensor([50.6620])
#
# 	 EPOCH 474, totalloss: 50.56, tensor([50.5600])
#
# 	 EPOCH 475, totalloss: 53.417, tensor([53.4170])
#
# 	 EPOCH 476, totalloss: 50.345, tensor([50.3450])
#
# 	 EPOCH 477, totalloss: 52.89, tensor([52.8900])
#
# 	 EPOCH 478, totalloss: 51.21, tensor([51.2100])
#
# 	 EPOCH 479, totalloss: 49.855, tensor([49.8550])
#
# 	 EPOCH 480, totalloss: 51.031, tensor([51.0310])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 481, totalloss: 53.721, tensor([53.7210])
#
# 	 EPOCH 482, totalloss: 50.269, tensor([50.2690])
#
# 	 EPOCH 483, totalloss: 52.579, tensor([52.5790])
#
# 	 EPOCH 484, totalloss: 53.256, tensor([53.2560])
#
# 	 EPOCH 485, totalloss: 51.16, tensor([51.1600])
#
# 	 EPOCH 486, totalloss: 52.712, tensor([52.7120])
#
# 	 EPOCH 487, totalloss: 50.251, tensor([50.2510])
#
# 	 EPOCH 488, totalloss: 53.508, tensor([53.5080])
#
# 	 EPOCH 489, totalloss: 50.414, tensor([50.4140])
#
# 	 EPOCH 490, totalloss: 52.633, tensor([52.6330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 491, totalloss: 49.918, tensor([49.9180])
#
# 	 EPOCH 492, totalloss: 50.533, tensor([50.5330])
#
# 	 EPOCH 493, totalloss: 49.409, tensor([49.4090])
#
# 	 EPOCH 494, totalloss: 49.7, tensor([49.7000])
#
# 	 EPOCH 495, totalloss: 51.603, tensor([51.6030])
#
# 	 EPOCH 496, totalloss: 49.861, tensor([49.8610])
#
# 	 EPOCH 497, totalloss: 49.143, tensor([49.1430])
#
# 	 EPOCH 498, totalloss: 49.836, tensor([49.8360])
#
# 	 EPOCH 499, totalloss: 52.761, tensor([52.7610])
#
# 	 EPOCH 500, totalloss: 50.188, tensor([50.1880])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 501, totalloss: 49.196, tensor([49.1960])
#
# 	 EPOCH 502, totalloss: 50.385, tensor([50.3850])
#
# 	 EPOCH 503, totalloss: 50.419, tensor([50.4190])
#
# 	 EPOCH 504, totalloss: 52.45, tensor([52.4500])
#
# 	 EPOCH 505, totalloss: 50.645, tensor([50.6450])
#
# 	 EPOCH 506, totalloss: 48.403, tensor([48.4030])
#
# 	 EPOCH 507, totalloss: 50.679, tensor([50.6790])
#
# 	 EPOCH 508, totalloss: 49.459, tensor([49.4590])
#
# 	 EPOCH 509, totalloss: 50.953, tensor([50.9530])
#
# 	 EPOCH 510, totalloss: 52.422, tensor([52.4220])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 511, totalloss: 51.173, tensor([51.1730])
#
# 	 EPOCH 512, totalloss: 49.489, tensor([49.4890])
#
# 	 EPOCH 513, totalloss: 50.55, tensor([50.5500])
#
# 	 EPOCH 514, totalloss: 50.576, tensor([50.5760])
#
# 	 EPOCH 515, totalloss: 50.674, tensor([50.6740])
#
# 	 EPOCH 516, totalloss: 53.283, tensor([53.2830])
#
# 	 EPOCH 517, totalloss: 49.803, tensor([49.8030])
#
# 	 EPOCH 518, totalloss: 51.066, tensor([51.0660])
#
# 	 EPOCH 519, totalloss: 49.876, tensor([49.8760])
#
# 	 EPOCH 520, totalloss: 50.267, tensor([50.2670])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 521, totalloss: 49.771, tensor([49.7710])
#
# 	 EPOCH 522, totalloss: 49.689, tensor([49.6890])
#
# 	 EPOCH 523, totalloss: 48.075, tensor([48.0750])
#
# 	 EPOCH 524, totalloss: 49.167, tensor([49.1670])
#
# 	 EPOCH 525, totalloss: 48.548, tensor([48.5480])
#
# 	 EPOCH 526, totalloss: 49.233, tensor([49.2330])
#
# 	 EPOCH 527, totalloss: 49.356, tensor([49.3560])
#
# 	 EPOCH 528, totalloss: 51.174, tensor([51.1740])
#
# 	 EPOCH 529, totalloss: 48.668, tensor([48.6680])
#
# 	 EPOCH 530, totalloss: 49.059, tensor([49.0590])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 531, totalloss: 48.945, tensor([48.9450])
#
# 	 EPOCH 532, totalloss: 49.468, tensor([49.4680])
#
# 	 EPOCH 533, totalloss: 50.188, tensor([50.1880])
#
# 	 EPOCH 534, totalloss: 48.44, tensor([48.4400])
#
# 	 EPOCH 535, totalloss: 51.217, tensor([51.2170])
#
# 	 EPOCH 536, totalloss: 50.487, tensor([50.4870])
#
# 	 EPOCH 537, totalloss: 50.056, tensor([50.0560])
#
# 	 EPOCH 538, totalloss: 48.223, tensor([48.2230])
#
# 	 EPOCH 539, totalloss: 48.014, tensor([48.0140])
#
# 	 EPOCH 540, totalloss: 47.623, tensor([47.6230])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
# 	 EPOCH 541, totalloss: 49.673, tensor([49.6730])
#
# 	 EPOCH 542, totalloss: 48.265, tensor([48.2650])
#
# 	 EPOCH 543, totalloss: 48.84, tensor([48.8400])
#
# 	 EPOCH 544, totalloss: 49.352, tensor([49.3520])
#
# 	 EPOCH 545, totalloss: 48.888, tensor([48.8880])
#
# 	 EPOCH 546, totalloss: 47.538, tensor([47.5380])
#
# 	 EPOCH 547, totalloss: 49.976, tensor([49.9760])
#
# 	 EPOCH 548, totalloss: 47.854, tensor([47.8540])
#
# 	 EPOCH 549, totalloss: 50.402, tensor([50.4020])
#
# 	 EPOCH 550, totalloss: 51.0, tensor([51.])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 551, totalloss: 49.602, tensor([49.6020])
#
# 	 EPOCH 552, totalloss: 48.603, tensor([48.6030])
#
# 	 EPOCH 553, totalloss: 49.41, tensor([49.4100])
#
# 	 EPOCH 554, totalloss: 49.285, tensor([49.2850])
#
# 	 EPOCH 555, totalloss: 47.199, tensor([47.1990])
#
# 	 EPOCH 556, totalloss: 47.262, tensor([47.2620])
#
# 	 EPOCH 557, totalloss: 47.738, tensor([47.7380])
#
# 	 EPOCH 558, totalloss: 49.227, tensor([49.2270])
#
# 	 EPOCH 559, totalloss: 49.494, tensor([49.4940])
#
# 	 EPOCH 560, totalloss: 49.354, tensor([49.3540])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 561, totalloss: 47.269, tensor([47.2690])
#
# 	 EPOCH 562, totalloss: 49.091, tensor([49.0910])
#
# 	 EPOCH 563, totalloss: 48.276, tensor([48.2760])
#
# 	 EPOCH 564, totalloss: 50.925, tensor([50.9250])
#
# 	 EPOCH 565, totalloss: 48.609, tensor([48.6090])
#
# 	 EPOCH 566, totalloss: 47.998, tensor([47.9980])
#
# 	 EPOCH 567, totalloss: 48.831, tensor([48.8310])
#
# 	 EPOCH 568, totalloss: 48.629, tensor([48.6290])
#
# 	 EPOCH 569, totalloss: 48.852, tensor([48.8520])
#
# 	 EPOCH 570, totalloss: 46.628, tensor([46.6280])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 571, totalloss: 48.302, tensor([48.3020])
#
# 	 EPOCH 572, totalloss: 49.849, tensor([49.8490])
#
# 	 EPOCH 573, totalloss: 47.526, tensor([47.5260])
#
# 	 EPOCH 574, totalloss: 48.762, tensor([48.7620])
#
# 	 EPOCH 575, totalloss: 49.305, tensor([49.3050])
#
# 	 EPOCH 576, totalloss: 48.99, tensor([48.9900])
#
# 	 EPOCH 577, totalloss: 48.541, tensor([48.5410])
#
# 	 EPOCH 578, totalloss: 50.046, tensor([50.0460])
#
# 	 EPOCH 579, totalloss: 48.345, tensor([48.3450])
#
# 	 EPOCH 580, totalloss: 49.091, tensor([49.0910])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 581, totalloss: 48.075, tensor([48.0750])
#
# 	 EPOCH 582, totalloss: 50.171, tensor([50.1710])
#
# 	 EPOCH 583, totalloss: 50.399, tensor([50.3990])
#
# 	 EPOCH 584, totalloss: 48.322, tensor([48.3220])
#
# 	 EPOCH 585, totalloss: 48.044, tensor([48.0440])
#
# 	 EPOCH 586, totalloss: 48.57, tensor([48.5700])
#
# 	 EPOCH 587, totalloss: 47.476, tensor([47.4760])
#
# 	 EPOCH 588, totalloss: 48.427, tensor([48.4270])
#
# 	 EPOCH 589, totalloss: 47.989, tensor([47.9890])
#
# 	 EPOCH 590, totalloss: 48.07, tensor([48.0700])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 591, totalloss: 47.758, tensor([47.7580])
#
# 	 EPOCH 592, totalloss: 47.639, tensor([47.6390])
#
# 	 EPOCH 593, totalloss: 45.814, tensor([45.8140])
#
# 	 EPOCH 594, totalloss: 48.922, tensor([48.9220])
#
# 	 EPOCH 595, totalloss: 48.126, tensor([48.1260])
#
# 	 EPOCH 596, totalloss: 46.93, tensor([46.9300])
#
# 	 EPOCH 597, totalloss: 46.84, tensor([46.8400])
#
# 	 EPOCH 598, totalloss: 48.962, tensor([48.9620])
#
# 	 EPOCH 599, totalloss: 49.397, tensor([49.3970])
#
# 	 EPOCH 600, totalloss: 47.586, tensor([47.5860])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 601, totalloss: 49.163, tensor([49.1630])
#
# 	 EPOCH 602, totalloss: 48.419, tensor([48.4190])
#
# 	 EPOCH 603, totalloss: 47.769, tensor([47.7690])
#
# 	 EPOCH 604, totalloss: 47.834, tensor([47.8340])
#
# 	 EPOCH 605, totalloss: 45.48, tensor([45.4800])
#
# 	 EPOCH 606, totalloss: 44.8, tensor([44.8000])
#
# 	 EPOCH 607, totalloss: 48.124, tensor([48.1240])
#
# 	 EPOCH 608, totalloss: 47.223, tensor([47.2230])
#
# 	 EPOCH 609, totalloss: 46.775, tensor([46.7750])
#
# 	 EPOCH 610, totalloss: 46.253, tensor([46.2530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 611, totalloss: 48.428, tensor([48.4280])
#
# 	 EPOCH 612, totalloss: 47.401, tensor([47.4010])
#
# 	 EPOCH 613, totalloss: 48.757, tensor([48.7570])
#
# 	 EPOCH 614, totalloss: 49.252, tensor([49.2520])
#
# 	 EPOCH 615, totalloss: 48.152, tensor([48.1520])
#
# 	 EPOCH 616, totalloss: 46.841, tensor([46.8410])
#
# 	 EPOCH 617, totalloss: 46.939, tensor([46.9390])
#
# 	 EPOCH 618, totalloss: 46.632, tensor([46.6320])
#
# 	 EPOCH 619, totalloss: 46.439, tensor([46.4390])
#
# 	 EPOCH 620, totalloss: 46.93, tensor([46.9300])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 621, totalloss: 47.346, tensor([47.3460])
#
# 	 EPOCH 622, totalloss: 47.942, tensor([47.9420])
#
# 	 EPOCH 623, totalloss: 45.753, tensor([45.7530])
#
# 	 EPOCH 624, totalloss: 45.714, tensor([45.7140])
#
# 	 EPOCH 625, totalloss: 47.48, tensor([47.4800])
#
# 	 EPOCH 626, totalloss: 48.735, tensor([48.7350])
#
# 	 EPOCH 627, totalloss: 47.039, tensor([47.0390])
#
# 	 EPOCH 628, totalloss: 45.5, tensor([45.5000])
#
# 	 EPOCH 629, totalloss: 46.167, tensor([46.1680])
#
# 	 EPOCH 630, totalloss: 46.38, tensor([46.3800])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 631, totalloss: 46.307, tensor([46.3070])
#
# 	 EPOCH 632, totalloss: 48.226, tensor([48.2260])
#
# 	 EPOCH 633, totalloss: 46.553, tensor([46.5530])
#
# 	 EPOCH 634, totalloss: 46.723, tensor([46.7230])
#
# ...
#
# 	 EPOCH 787, totalloss: 44.396, tensor([44.3960])
#
# 	 EPOCH 788, totalloss: 42.933, tensor([42.9330])
#
# 	 EPOCH 789, totalloss: 43.917, tensor([43.9170])
#
# 	 EPOCH 790, totalloss: 43.228, tensor([43.2280])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 791, totalloss: 42.925, tensor([42.9250])
#
# 	 EPOCH 792, totalloss: 43.52, tensor([43.5200])
#
# 	 EPOCH 793, totalloss: 44.285, tensor([44.2850])
#
# 	 EPOCH 794, totalloss: 42.576, tensor([42.5760])
#
# 	 EPOCH 795, totalloss: 44.257, tensor([44.2570])
#
# 	 EPOCH 796, totalloss: 43.884, tensor([43.8840])
#
# 	 EPOCH 797, totalloss: 42.504, tensor([42.5040])
#
# 	 EPOCH 798, totalloss: 42.419, tensor([42.4190])
#
# 	 EPOCH 799, totalloss: 41.848, tensor([41.8480])
#
# 	 EPOCH 800, totalloss: 41.756, tensor([41.7560])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 801, totalloss: 42.22, tensor([42.2200])
#
# 	 EPOCH 802, totalloss: 42.218, tensor([42.2180])
#
# 	 EPOCH 803, totalloss: 41.966, tensor([41.9660])
#
# 	 EPOCH 804, totalloss: 42.464, tensor([42.4640])
#
# 	 EPOCH 805, totalloss: 42.192, tensor([42.1920])
#
# 	 EPOCH 806, totalloss: 43.608, tensor([43.6080])
#
# 	 EPOCH 807, totalloss: 43.008, tensor([43.0080])
#
# 	 EPOCH 808, totalloss: 42.427, tensor([42.4270])
#
# 	 EPOCH 809, totalloss: 44.317, tensor([44.3170])
#
# 	 EPOCH 810, totalloss: 44.353, tensor([44.3530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 811, totalloss: 44.412, tensor([44.4120])
#
# 	 EPOCH 812, totalloss: 42.967, tensor([42.9670])
#
# 	 EPOCH 813, totalloss: 43.669, tensor([43.6690])
#
# 	 EPOCH 814, totalloss: 42.797, tensor([42.7970])
#
# 	 EPOCH 815, totalloss: 41.458, tensor([41.4580])
#
# 	 EPOCH 816, totalloss: 43.591, tensor([43.5910])
#
# 	 EPOCH 817, totalloss: 43.446, tensor([43.4460])
#
# 	 EPOCH 818, totalloss: 43.019, tensor([43.0190])
#
# 	 EPOCH 819, totalloss: 43.75, tensor([43.7500])
#
# 	 EPOCH 820, totalloss: 42.059, tensor([42.0590])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 821, totalloss: 42.401, tensor([42.4010])
#
# 	 EPOCH 822, totalloss: 43.13, tensor([43.1300])
#
# 	 EPOCH 823, totalloss: 43.045, tensor([43.0450])
#
# 	 EPOCH 824, totalloss: 44.377, tensor([44.3770])
#
# 	 EPOCH 825, totalloss: 43.425, tensor([43.4250])
#
# 	 EPOCH 826, totalloss: 45.607, tensor([45.6060])
#
# 	 EPOCH 827, totalloss: 40.153, tensor([40.1530])
#
# 	 EPOCH 828, totalloss: 41.124, tensor([41.1240])
#
# 	 EPOCH 829, totalloss: 41.845, tensor([41.8450])
#
# 	 EPOCH 830, totalloss: 42.553, tensor([42.5530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 831, totalloss: 42.268, tensor([42.2680])
#
# 	 EPOCH 832, totalloss: 43.228, tensor([43.2280])
#
# 	 EPOCH 833, totalloss: 44.819, tensor([44.8190])
#
# 	 EPOCH 834, totalloss: 42.605, tensor([42.6050])
#
# 	 EPOCH 835, totalloss: 43.321, tensor([43.3210])
#
# 	 EPOCH 836, totalloss: 43.53, tensor([43.5300])
#
# 	 EPOCH 837, totalloss: 41.35, tensor([41.3500])
#
# 	 EPOCH 838, totalloss: 41.861, tensor([41.8610])
#
# 	 EPOCH 839, totalloss: 42.746, tensor([42.7460])
#
# 	 EPOCH 840, totalloss: 41.873, tensor([41.8730])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 841, totalloss: 40.28, tensor([40.2800])
#
# 	 EPOCH 842, totalloss: 42.854, tensor([42.8540])
#
# 	 EPOCH 843, totalloss: 42.909, tensor([42.9090])
#
# 	 EPOCH 844, totalloss: 41.895, tensor([41.8950])
#
# 	 EPOCH 845, totalloss: 41.674, tensor([41.6740])
#
# 	 EPOCH 846, totalloss: 44.032, tensor([44.0320])
#
# 	 EPOCH 847, totalloss: 41.814, tensor([41.8140])
#
# 	 EPOCH 848, totalloss: 42.4, tensor([42.4000])
#
# 	 EPOCH 849, totalloss: 41.949, tensor([41.9490])
#
# 	 EPOCH 850, totalloss: 41.974, tensor([41.9740])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 851, totalloss: 42.735, tensor([42.7350])
#
# 	 EPOCH 852, totalloss: 42.922, tensor([42.9220])
#
# 	 EPOCH 853, totalloss: 44.213, tensor([44.2130])
#
# 	 EPOCH 854, totalloss: 42.209, tensor([42.2090])
#
# 	 EPOCH 855, totalloss: 40.808, tensor([40.8080])
#
# 	 EPOCH 856, totalloss: 40.957, tensor([40.9570])
#
# 	 EPOCH 857, totalloss: 42.329, tensor([42.3290])
#
# 	 EPOCH 858, totalloss: 41.962, tensor([41.9620])
#
# 	 EPOCH 859, totalloss: 40.393, tensor([40.3930])
#
# 	 EPOCH 860, totalloss: 40.953, tensor([40.9530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 861, totalloss: 42.222, tensor([42.2220])
#
# 	 EPOCH 862, totalloss: 41.342, tensor([41.3420])
#
# 	 EPOCH 863, totalloss: 40.038, tensor([40.0380])
#
# 	 EPOCH 864, totalloss: 42.122, tensor([42.1220])
#
# 	 EPOCH 865, totalloss: 40.941, tensor([40.9410])
#
# 	 EPOCH 866, totalloss: 40.579, tensor([40.5790])
#
# 	 EPOCH 867, totalloss: 42.723, tensor([42.7230])
#
# 	 EPOCH 868, totalloss: 41.431, tensor([41.4310])
#
# 	 EPOCH 869, totalloss: 41.227, tensor([41.2270])
#
# 	 EPOCH 870, totalloss: 41.018, tensor([41.0180])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 871, totalloss: 41.244, tensor([41.2440])
#
# 	 EPOCH 872, totalloss: 42.827, tensor([42.8270])
#
# 	 EPOCH 873, totalloss: 42.985, tensor([42.9850])
#
# 	 EPOCH 874, totalloss: 41.864, tensor([41.8640])
#
# 	 EPOCH 875, totalloss: 41.577, tensor([41.5770])
#
# 	 EPOCH 876, totalloss: 40.115, tensor([40.1150])
#
# 	 EPOCH 877, totalloss: 42.2, tensor([42.2000])
#
# 	 EPOCH 878, totalloss: 40.877, tensor([40.8770])
#
# 	 EPOCH 879, totalloss: 42.126, tensor([42.1260])
# 	 EPOCH 880, totalloss: 41.541, tensor([41.5410])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 881, totalloss: 41.071, tensor([41.0710])
#
# 	 EPOCH 882, totalloss: 40.466, tensor([40.4660])
#
# 	 EPOCH 883, totalloss: 41.778, tensor([41.7780])
#
# 	 EPOCH 884, totalloss: 42.38, tensor([42.3800])
#
# 	 EPOCH 885, totalloss: 41.273, tensor([41.2730])
#
# 	 EPOCH 886, totalloss: 42.089, tensor([42.0890])
#
# 	 EPOCH 887, totalloss: 39.738, tensor([39.7380])
#
# 	 EPOCH 888, totalloss: 40.842, tensor([40.8420])
#
# 	 EPOCH 889, totalloss: 41.044, tensor([41.0440])
#
# 	 EPOCH 890, totalloss: 41.948, tensor([41.9480])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 891, totalloss: 41.806, tensor([41.8060])
#
# 	 EPOCH 892, totalloss: 41.534, tensor([41.5340])
#
# 	 EPOCH 893, totalloss: 40.418, tensor([40.4180])
#
# 	 EPOCH 894, totalloss: 40.868, tensor([40.8680])
#
# 	 EPOCH 895, totalloss: 40.695, tensor([40.6950])
#
# 	 EPOCH 896, totalloss: 41.473, tensor([41.4730])
#
# 	 EPOCH 897, totalloss: 41.166, tensor([41.1660])
#
# 	 EPOCH 898, totalloss: 40.903, tensor([40.9030])
#
# 	 EPOCH 899, totalloss: 41.716, tensor([41.7160])
#
# 	 EPOCH 900, totalloss: 40.214, tensor([40.2140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 71 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 901, totalloss: 39.874, tensor([39.8740])
#
# 	 EPOCH 902, totalloss: 40.733, tensor([40.7330])
#
# 	 EPOCH 903, totalloss: 41.012, tensor([41.0120])
#
# 	 EPOCH 904, totalloss: 40.551, tensor([40.5510])
#
# 	 EPOCH 905, totalloss: 41.594, tensor([41.5940])
#
# 	 EPOCH 906, totalloss: 41.546, tensor([41.5460])
#
# 	 EPOCH 907, totalloss: 42.032, tensor([42.0320])
#
# 	 EPOCH 908, totalloss: 39.716, tensor([39.7160])
#
# 	 EPOCH 909, totalloss: 40.782, tensor([40.7820])
#
# 	 EPOCH 910, totalloss: 40.541, tensor([40.5410])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 911, totalloss: 42.961, tensor([42.9610])
#
# 	 EPOCH 912, totalloss: 41.654, tensor([41.6540])
#
# 	 EPOCH 913, totalloss: 40.699, tensor([40.6990])
#
# 	 EPOCH 914, totalloss: 40.533, tensor([40.5330])
#
# 	 EPOCH 915, totalloss: 38.548, tensor([38.5480])
#
# 	 EPOCH 916, totalloss: 40.168, tensor([40.1680])
#
# 	 EPOCH 917, totalloss: 42.216, tensor([42.2160])
#
# 	 EPOCH 918, totalloss: 43.247, tensor([43.2470])
#
# 	 EPOCH 919, totalloss: 40.89, tensor([40.8900])
#
# 	 EPOCH 920, totalloss: 40.744, tensor([40.7440])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 921, totalloss: 40.722, tensor([40.7220])
#
# 	 EPOCH 922, totalloss: 39.979, tensor([39.9790])
#
# 	 EPOCH 923, totalloss: 39.471, tensor([39.4710])
#
# 	 EPOCH 924, totalloss: 40.572, tensor([40.5720])
#
# 	 EPOCH 925, totalloss: 39.422, tensor([39.4220])
#
# 	 EPOCH 926, totalloss: 41.914, tensor([41.9140])
#
# 	 EPOCH 927, totalloss: 40.435, tensor([40.4350])
#
# 	 EPOCH 928, totalloss: 41.031, tensor([41.0310])
#
# 	 EPOCH 929, totalloss: 40.924, tensor([40.9240])
#
# 	 EPOCH 930, totalloss: 41.897, tensor([41.8970])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 931, totalloss: 40.968, tensor([40.9680])
#
# 	 EPOCH 932, totalloss: 41.485, tensor([41.4850])
#
# 	 EPOCH 933, totalloss: 41.201, tensor([41.2010])
#
# 	 EPOCH 934, totalloss: 42.03, tensor([42.0300])
#
# 	 EPOCH 935, totalloss: 40.96, tensor([40.9600])
#
# 	 EPOCH 936, totalloss: 41.553, tensor([41.5530])
#
# 	 EPOCH 937, totalloss: 39.971, tensor([39.9710])
#
# 	 EPOCH 938, totalloss: 42.021, tensor([42.0210])
#
# 	 EPOCH 939, totalloss: 39.031, tensor([39.0310])
#
# 	 EPOCH 940, totalloss: 39.524, tensor([39.5240])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 941, totalloss: 40.351, tensor([40.3510])
#
# 	 EPOCH 942, totalloss: 39.799, tensor([39.7990])
#
# 	 EPOCH 943, totalloss: 40.213, tensor([40.2130])
#
# 	 EPOCH 944, totalloss: 40.118, tensor([40.1180])
#
# 	 EPOCH 945, totalloss: 41.021, tensor([41.0210])
#
# 	 EPOCH 946, totalloss: 40.197, tensor([40.1970])
#
# 	 EPOCH 947, totalloss: 42.784, tensor([42.7840])
#
# 	 EPOCH 948, totalloss: 39.424, tensor([39.4240])
#
# 	 EPOCH 949, totalloss: 39.624, tensor([39.6240])
#
# 	 EPOCH 950, totalloss: 40.104, tensor([40.1030])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 951, totalloss: 41.293, tensor([41.2930])
#
# 	 EPOCH 952, totalloss: 40.228, tensor([40.2280])
#
# 	 EPOCH 953, totalloss: 39.342, tensor([39.3420])
#
# 	 EPOCH 954, totalloss: 39.611, tensor([39.6110])
#
# 	 EPOCH 955, totalloss: 39.281, tensor([39.2810])
#
# 	 EPOCH 956, totalloss: 41.795, tensor([41.7950])
#
# 	 EPOCH 957, totalloss: 40.352, tensor([40.3520])
#
# 	 EPOCH 958, totalloss: 39.248, tensor([39.2480])
#
# 	 EPOCH 959, totalloss: 40.548, tensor([40.5480])
#
# 	 EPOCH 960, totalloss: 39.55, tensor([39.5500])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 961, totalloss: 40.368, tensor([40.3680])
#
# 	 EPOCH 962, totalloss: 40.666, tensor([40.6660])
#
# 	 EPOCH 963, totalloss: 38.981, tensor([38.9810])
#
# 	 EPOCH 964, totalloss: 39.027, tensor([39.0270])
#
# 	 EPOCH 965, totalloss: 37.724, tensor([37.7240])
#
# 	 EPOCH 966, totalloss: 38.037, tensor([38.0370])
#
# 	 EPOCH 967, totalloss: 40.989, tensor([40.9890])
#
# 	 EPOCH 968, totalloss: 39.278, tensor([39.2780])
#
# 	 EPOCH 969, totalloss: 39.996, tensor([39.9960])
#
# 	 EPOCH 970, totalloss: 38.384, tensor([38.3840])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 971, totalloss: 39.805, tensor([39.8050])
#
# 	 EPOCH 972, totalloss: 38.422, tensor([38.4220])
#
# 	 EPOCH 973, totalloss: 42.248, tensor([42.2480])
#
# 	 EPOCH 974, totalloss: 41.28, tensor([41.2800])
#
# 	 EPOCH 975, totalloss: 40.718, tensor([40.7180])
#
# 	 EPOCH 976, totalloss: 38.377, tensor([38.3770])
#
# 	 EPOCH 977, totalloss: 40.015, tensor([40.0150])
#
# 	 EPOCH 978, totalloss: 39.501, tensor([39.5010])
#
# 	 EPOCH 979, totalloss: 39.856, tensor([39.8560])
#
# 	 EPOCH 980, totalloss: 39.512, tensor([39.5120])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 981, totalloss: 38.507, tensor([38.5070])
#
# 	 EPOCH 982, totalloss: 39.64, tensor([39.6400])
#
# 	 EPOCH 983, totalloss: 39.578, tensor([39.5780])
#
# 	 EPOCH 984, totalloss: 38.78, tensor([38.7800])
#
# 	 EPOCH 985, totalloss: 38.071, tensor([38.0710])
#
# 	 EPOCH 986, totalloss: 39.891, tensor([39.8910])
#
# 	 EPOCH 987, totalloss: 39.782, tensor([39.7820])
#
# 	 EPOCH 988, totalloss: 40.788, tensor([40.7880])
#
# 	 EPOCH 989, totalloss: 39.235, tensor([39.2350])
#
# 	 EPOCH 990, totalloss: 39.971, tensor([39.9710])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set aesthetic: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 991, totalloss: 39.356, tensor([39.3560])
#
# 	 EPOCH 992, totalloss: 41.652, tensor([41.6520])
#
# 	 EPOCH 993, totalloss: 40.141, tensor([40.1410])
#
# 	 EPOCH 994, totalloss: 39.285, tensor([39.2850])
#
# 	 EPOCH 995, totalloss: 40.618, tensor([40.6180])
#
# 	 EPOCH 996, totalloss: 39.428, tensor([39.4280])
#
# 	 EPOCH 997, totalloss: 40.3, tensor([40.3000])
#
# 	 EPOCH 998, totalloss: 39.931, tensor([39.9310])
#
# 	 EPOCH 999, totalloss: 39.572, tensor([39.5720])
# Finished Training
# Traceback (most recent call last):
#   File "train_aesthetics.py", line 263, in <module>
#     test_model_acc_all(os.path.join(args['experiment_path'], 'model@epoch%d.pkl' %(epoch)), val_dataloader, _C)
#   File "/tf/notebooks/acadia2020_graphcnn_src/test_aesthetics.py", line 152, in test_model_acc_all
#     pred_semantic = torch.argmax(outputs[1].data,1)
# IndexError: list index out of range

# %%
## test pretrained network
# !python test_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_test.yml"

# %%
## run the optimization framework; hit 'shift+enter' keys to run
## IMPORTANT INFO about running the acoustic optimization script:
## The Command Format for this script: 
## bash run_acousticoptim.sh INPUT_MESH SILHOUETTE_DEFORM_FLAG SILHOUETTE_REF_IMG ACOUSTIC_DEFORM_FLAG WHICH_ACOUSTIC_PARAMS OUTPUT_NAME
## where `INPUT_MESH_FILEPATH` is the absolute filepath of the mesh you would like to deform
##       `TRAINED_GRAPH_FILEPATH` is the filepath to the trained mesh2aesthetic graph convolutional neural network
##       `STYLE_PARAM` is either 'baroque', 'modern', or 'classic' 
##       `SEM_PARAM`  is either 'house' or 'column'
##       `FUNC_PARAM` is an integer number from [1,2,3,4], where 1 is low functionality and 4 is high functionality
##       `AESTH_PARAM` is an integer number from [1,2,3,4], where 1 is poor aesthetics and 5 is good aesthetics 
##       `OUTPUT_FILENAME` is the absolute filepath where you would like the deformed output mesh to be saved.
##       `NUM_ITERS` is the number of iterations to run the optimization.
##       `CFG_FILE` is the absolute path to the configuration file. You will need to change this to the config file path that you used for training the model (see above cell)
##
## Example Command:
#!cd /storage/concerthall && bash run_acousticoptim.sh \
#                            INPUT_MESH_FILEPATH \
#                            TRAINED_GRAPH_FILEPATH \
#                            STYLE_PARAM \
#                            SEM_PARAM \
#                            FUNC_PARAM \
#                            AESTH_PARAM \
#                            OUTPUT_FILENAME \
#                            NUM_ITERS \
#                            CFG_FILE
#
# !cd /storage/acadia2020_graphcnn && bash run_param_optim.sh \
                            "/storage/3Dmodels/bench.obj" \
                            "/storage/acadia2020_graphcnn_training_results/exp_09_26_14_01_06_ai_aesthetics_optim/model_best_loss.pkl" \
                            "modern" \
                            "house" \
                            4 \
                            5 \
                            "test_sil_deform.obj" \
                            250 \
                            "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
