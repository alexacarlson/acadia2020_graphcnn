# %%
## install the pytorch3d package; hit 'shift+enter' keys to run
# !conda create --name pytorch3d --yes
# !conda activate pytorch3d
# !python3 -m pip install --upgrade numpy
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch --yes
# !conda install -c conda-forge -c takatosp1 fvcore --yes
# !conda install pytorch3d -c pytorch3d --yes
# !python3 -m pip install tqdm pandas scipy opencv-python 
# !python3 -m pip install --upgrade matplotlib --ignore-installed certifi

# %%
## download the concerthall optimization code base; hit 'shift+enter' keys to run
#!rm -rf /storage/acadia2020_graphcnn
#!git clone https://github.com/alexacarlson/acadia2020_graphcnn.git /storage/acadia2020_graphcnn

## check size of dataset/verts etc
# !python check_dataset.py

# %%
## Train the graph convolutional neural network; hit 'shift+enter' keys to run
## NOTES on Training the Graph Convolutional Neural network to map 3D meshes --> aesthetic and functionality parameters:
## To train your own graph convolutional network, you first need to create a folder in paperspace storage 
## at `/storage/concert_dataset` upload your data there. All of your meshes should be `.obj` files and
## should exist in a subdirectory of the dataset: `/storage/acadia2020_graphcnn_dataset/Separated/`. 
## You will need to have a csv file of label/parameters (where each line is in the format `mesh.obj label1 label2 ... label10`) 
## located at and named `/storage/acadia2020_graphcnn_dataset/NamingBookV2.csv`.
## The results (network weights and training loss values) will be saved to `/storage/acadia2020_graphcnn_training_results`.
##
## Note that this function takes in the absolute filepath of a configuration file (CFG_PATH) that sets up the network architecture.
## ## To train on 4 labels:
#!cd /storage/acadia2020_graphcnn && bash run_train_graphconv_regression.sh "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
#!cd /tf/notebooks/acadia2020_graphcnn_src && bash run_train_graphconv_regression.sh "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"

#!CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"
# !CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train3.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: all
#   WHICH_TASK: all
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf3
# OPTIM:
#   BATCH_SIZE: 32
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 2500
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_23_12_33_50_ai_aesthetics_optim_nettype-GraphConvClf3_class-all
#   full_experiment_name: exp_11_23_12_33_50_ai_aesthetics_optim_nettype-GraphConvClf3_class-all
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train3.yml
# config_override     : []
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# number of training samples: 2076
# Training Samples: 65
# Validation Samples: 100
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 30.227, tensor([9.2000e-01, 6.0000e-03, 1.3412e+01, 1.5889e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 69 %
# Accuracy of the network on validation model set SEMANTIC: 79 %
# Accuracy of the network on validation model set FUNCTIONALITY: 41 %
# Accuracy of the network on validation model set AESTHETICS: 26 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 29.328, tensor([7.9500e-01, 4.0000e-03, 1.2925e+01, 1.5603e+01])
#
# 	 EPOCH 2, totalloss: 29.119, tensor([7.7000e-01, 4.0000e-03, 1.2841e+01, 1.5505e+01])
#
# 	 EPOCH 3, totalloss: 28.942, tensor([7.5400e-01, 4.0000e-03, 1.2754e+01, 1.5430e+01])
#
# 	 EPOCH 4, totalloss: 28.699, tensor([7.5200e-01, 4.0000e-03, 1.2643e+01, 1.5300e+01])
#
# 	 EPOCH 5, totalloss: 28.685, tensor([7.5100e-01, 4.0000e-03, 1.2694e+01, 1.5235e+01])
#
# 	 EPOCH 6, totalloss: 28.441, tensor([7.3700e-01, 3.0000e-03, 1.2535e+01, 1.5165e+01])
#
# 	 EPOCH 7, totalloss: 28.276, tensor([7.3400e-01, 3.0000e-03, 1.2488e+01, 1.5051e+01])
#
# 	 EPOCH 8, totalloss: 28.225, tensor([7.3200e-01, 3.0000e-03, 1.2501e+01, 1.4989e+01])
#
# 	 EPOCH 9, totalloss: 28.385, tensor([7.3600e-01, 3.0000e-03, 1.2530e+01, 1.5117e+01])
#
# 	 EPOCH 10, totalloss: 28.029, tensor([7.2900e-01, 3.0000e-03, 1.2374e+01, 1.4923e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 69 %
# Accuracy of the network on validation model set SEMANTIC: 82 %
# Accuracy of the network on validation model set FUNCTIONALITY: 51 %
# Accuracy of the network on validation model set AESTHETICS: 29 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 11, totalloss: 28.098, tensor([7.2600e-01, 3.0000e-03, 1.2413e+01, 1.4957e+01])
#
# 	 EPOCH 12, totalloss: 28.221, tensor([7.0900e-01, 3.0000e-03, 1.2395e+01, 1.5115e+01])
#
# 	 EPOCH 13, totalloss: 27.92, tensor([7.0700e-01, 3.0000e-03, 1.2307e+01, 1.4903e+01])
#
# 	 EPOCH 14, totalloss: 27.676, tensor([6.9600e-01, 3.0000e-03, 1.2298e+01, 1.4680e+01])
#
# 	 EPOCH 15, totalloss: 27.612, tensor([6.9300e-01, 2.0000e-03, 1.2191e+01, 1.4726e+01])
#
# 	 EPOCH 16, totalloss: 27.538, tensor([6.9800e-01, 3.0000e-03, 1.2211e+01, 1.4627e+01])
#
# 	 EPOCH 17, totalloss: 27.584, tensor([6.7900e-01, 2.0000e-03, 1.2247e+01, 1.4656e+01])
#
# 	 EPOCH 18, totalloss: 27.307, tensor([6.6400e-01, 2.0000e-03, 1.2094e+01, 1.4547e+01])
#
# 	 EPOCH 19, totalloss: 27.548, tensor([6.7200e-01, 2.0000e-03, 1.2167e+01, 1.4707e+01])
#
# 	 EPOCH 20, totalloss: 27.168, tensor([6.6200e-01, 2.0000e-03, 1.2083e+01, 1.4420e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 72 %
# Accuracy of the network on validation model set SEMANTIC: 93 %
# Accuracy of the network on validation model set FUNCTIONALITY: 44 %
# Accuracy of the network on validation model set AESTHETICS: 29 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 21, totalloss: 27.105, tensor([6.4600e-01, 2.0000e-03, 1.2015e+01, 1.4442e+01])
#
# 	 EPOCH 22, totalloss: 26.977, tensor([6.5100e-01, 2.0000e-03, 1.1992e+01, 1.4331e+01])
#
# 	 EPOCH 23, totalloss: 26.753, tensor([6.3900e-01, 2.0000e-03, 1.1872e+01, 1.4240e+01])
#
# 	 EPOCH 24, totalloss: 26.853, tensor([6.3800e-01, 2.0000e-03, 1.1893e+01, 1.4320e+01])
#
# 	 EPOCH 25, totalloss: 26.844, tensor([6.3300e-01, 2.0000e-03, 1.1921e+01, 1.4289e+01])
#
# 	 EPOCH 26, totalloss: 26.526, tensor([6.3300e-01, 2.0000e-03, 1.1777e+01, 1.4115e+01])
#
# 	 EPOCH 27, totalloss: 26.631, tensor([6.3300e-01, 2.0000e-03, 1.1844e+01, 1.4152e+01])
#
# 	 EPOCH 28, totalloss: 26.422, tensor([6.1000e-01, 2.0000e-03, 1.1762e+01, 1.4048e+01])
#
# 	 EPOCH 29, totalloss: 26.616, tensor([6.1300e-01, 2.0000e-03, 1.1854e+01, 1.4147e+01])
#
# 	 EPOCH 30, totalloss: 26.405, tensor([6.0700e-01, 2.0000e-03, 1.1833e+01, 1.3963e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 69 %
# Accuracy of the network on validation model set SEMANTIC: 93 %
# Accuracy of the network on validation model set FUNCTIONALITY: 47 %
# Accuracy of the network on validation model set AESTHETICS: 30 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 31, totalloss: 26.433, tensor([5.9400e-01, 2.0000e-03, 1.1810e+01, 1.4027e+01])
#
# 	 EPOCH 32, totalloss: 25.939, tensor([6.0100e-01, 2.0000e-03, 1.1536e+01, 1.3801e+01])
#
# 	 EPOCH 33, totalloss: 26.038, tensor([5.9200e-01, 2.0000e-03, 1.1686e+01, 1.3759e+01])
#
# 	 EPOCH 34, totalloss: 26.146, tensor([6.1200e-01, 2.0000e-03, 1.1629e+01, 1.3903e+01])
#
# 	 EPOCH 35, totalloss: 26.036, tensor([5.8300e-01, 2.0000e-03, 1.1610e+01, 1.3841e+01])
#
# 	 EPOCH 36, totalloss: 25.763, tensor([5.9100e-01, 2.0000e-03, 1.1504e+01, 1.3667e+01])
#
# 	 EPOCH 37, totalloss: 26.142, tensor([5.8500e-01, 2.0000e-03, 1.1732e+01, 1.3823e+01])
#
# 	 EPOCH 38, totalloss: 25.677, tensor([5.8500e-01, 2.0000e-03, 1.1405e+01, 1.3686e+01])
#
# 	 EPOCH 39, totalloss: 25.561, tensor([5.5500e-01, 2.0000e-03, 1.1378e+01, 1.3627e+01])
#
# 	 EPOCH 40, totalloss: 25.75, tensor([5.7300e-01, 2.0000e-03, 1.1513e+01, 1.3662e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 76 %
# Accuracy of the network on validation model set SEMANTIC: 93 %
# Accuracy of the network on validation model set FUNCTIONALITY: 43 %
# Accuracy of the network on validation model set AESTHETICS: 35 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 41, totalloss: 25.606, tensor([5.4700e-01, 2.0000e-03, 1.1392e+01, 1.3665e+01])
#
# 	 EPOCH 42, totalloss: 25.531, tensor([5.5800e-01, 2.0000e-03, 1.1396e+01, 1.3575e+01])
#
# 	 EPOCH 43, totalloss: 25.469, tensor([5.5500e-01, 2.0000e-03, 1.1318e+01, 1.3594e+01])
#
# 	 EPOCH 44, totalloss: 25.242, tensor([5.3500e-01, 2.0000e-03, 1.1313e+01, 1.3392e+01])
#
# 	 EPOCH 45, totalloss: 25.522, tensor([5.4300e-01, 2.0000e-03, 1.1408e+01, 1.3569e+01])
#
# 	 EPOCH 46, totalloss: 25.189, tensor([5.3400e-01, 2.0000e-03, 1.1216e+01, 1.3437e+01])
#
# 	 EPOCH 47, totalloss: 25.228, tensor([5.2400e-01, 2.0000e-03, 1.1294e+01, 1.3408e+01])
#
# 	 EPOCH 48, totalloss: 24.996, tensor([5.1900e-01, 2.0000e-03, 1.1152e+01, 1.3325e+01])
#
# 	 EPOCH 49, totalloss: 24.859, tensor([5.0300e-01, 2.0000e-03, 1.1011e+01, 1.3343e+01])
#
# 	 EPOCH 50, totalloss: 24.988, tensor([5.1500e-01, 2.0000e-03, 1.1105e+01, 1.3366e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 79 %
# Accuracy of the network on validation model set SEMANTIC: 91 %
# Accuracy of the network on validation model set FUNCTIONALITY: 48 %
# Accuracy of the network on validation model set AESTHETICS: 30 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 51, totalloss: 24.995, tensor([5.1500e-01, 2.0000e-03, 1.1077e+01, 1.3401e+01])
#
# 	 EPOCH 52, totalloss: 24.686, tensor([5.0300e-01, 1.0000e-03, 1.0994e+01, 1.3188e+01])
# 	 EPOCH 53, totalloss: 25.076, tensor([4.9200e-01, 1.0000e-03, 1.1176e+01, 1.3407e+01])
#
# 	 EPOCH 54, totalloss: 24.69, tensor([4.8500e-01, 2.0000e-03, 1.1050e+01, 1.3154e+01])
#
# 	 EPOCH 55, totalloss: 24.681, tensor([4.9400e-01, 2.0000e-03, 1.0947e+01, 1.3237e+01])
#
# 	 EPOCH 56, totalloss: 24.947, tensor([5.0100e-01, 2.0000e-03, 1.1092e+01, 1.3352e+01])
#
# 	 EPOCH 57, totalloss: 24.612, tensor([4.5900e-01, 1.0000e-03, 1.0860e+01, 1.3293e+01])
#
# 	 EPOCH 58, totalloss: 24.505, tensor([4.8100e-01, 2.0000e-03, 1.0718e+01, 1.3305e+01])
#
# 	 EPOCH 59, totalloss: 24.67, tensor([4.7900e-01, 2.0000e-03, 1.0992e+01, 1.3197e+01])
#
# 	 EPOCH 60, totalloss: 24.445, tensor([4.6400e-01, 2.0000e-03, 1.0824e+01, 1.3156e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 77 %
# Accuracy of the network on validation model set SEMANTIC: 93 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 41 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 61, totalloss: 24.206, tensor([4.6200e-01, 1.0000e-03, 1.0660e+01, 1.3082e+01])
#
# 	 EPOCH 62, totalloss: 23.947, tensor([4.5900e-01, 1.0000e-03, 1.0569e+01, 1.2917e+01])
#
# 	 EPOCH 63, totalloss: 24.071, tensor([4.5600e-01, 1.0000e-03, 1.0612e+01, 1.3002e+01])
#
# 	 EPOCH 64, totalloss: 24.078, tensor([4.3900e-01, 1.0000e-03, 1.0708e+01, 1.2930e+01])
#
# 	 EPOCH 65, totalloss: 24.298, tensor([4.3500e-01, 2.0000e-03, 1.0834e+01, 1.3027e+01])
#
# 	 EPOCH 66, totalloss: 23.909, tensor([4.5200e-01, 1.0000e-03, 1.0598e+01, 1.2858e+01])
#
# 	 EPOCH 67, totalloss: 23.737, tensor([4.2000e-01, 1.0000e-03, 1.0527e+01, 1.2789e+01])
#
# 	 EPOCH 68, totalloss: 23.795, tensor([4.3800e-01, 1.0000e-03, 1.0505e+01, 1.2851e+01])
#
# 	 EPOCH 69, totalloss: 24.057, tensor([4.3800e-01, 1.0000e-03, 1.0607e+01, 1.3011e+01])
#
# 	 EPOCH 70, totalloss: 23.757, tensor([4.0800e-01, 1.0000e-03, 1.0562e+01, 1.2786e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 81 %
# Accuracy of the network on validation model set SEMANTIC: 97 %
# Accuracy of the network on validation model set FUNCTIONALITY: 59 %
# Accuracy of the network on validation model set AESTHETICS: 40 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 71, totalloss: 23.768, tensor([4.1900e-01, 1.0000e-03, 1.0504e+01, 1.2844e+01])
#
# 	 EPOCH 72, totalloss: 23.543, tensor([4.2200e-01, 1.0000e-03, 1.0557e+01, 1.2563e+01])
#
# 	 EPOCH 73, totalloss: 23.381, tensor([4.1400e-01, 1.0000e-03, 1.0372e+01, 1.2594e+01])
#
# 	 EPOCH 74, totalloss: 23.804, tensor([4.1600e-01, 1.0000e-03, 1.0559e+01, 1.2827e+01])
#
# 	 EPOCH 75, totalloss: 23.694, tensor([4.1200e-01, 1.0000e-03, 1.0490e+01, 1.2792e+01])
#
# 	 EPOCH 76, totalloss: 23.828, tensor([4.3500e-01, 1.0000e-03, 1.0531e+01, 1.2861e+01])
#
# 	 EPOCH 77, totalloss: 23.359, tensor([4.1800e-01, 1.0000e-03, 1.0350e+01, 1.2589e+01])
#
# 	 EPOCH 78, totalloss: 23.263, tensor([3.9900e-01, 1.0000e-03, 1.0321e+01, 1.2541e+01])
#
# 	 EPOCH 79, totalloss: 23.345, tensor([3.9900e-01, 1.0000e-03, 1.0317e+01, 1.2627e+01])
#
# 	 EPOCH 80, totalloss: 23.315, tensor([3.8100e-01, 1.0000e-03, 1.0313e+01, 1.2620e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 84 %
# Accuracy of the network on validation model set SEMANTIC: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 63 %
# Accuracy of the network on validation model set AESTHETICS: 39 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 81, totalloss: 23.121, tensor([3.9900e-01, 1.0000e-03, 1.0238e+01, 1.2484e+01])
#
# 	 EPOCH 82, totalloss: 23.178, tensor([3.7900e-01, 1.0000e-03, 1.0256e+01, 1.2542e+01])
#
# 	 EPOCH 83, totalloss: 23.307, tensor([3.6900e-01, 1.0000e-03, 1.0349e+01, 1.2588e+01])
#
# 	 EPOCH 84, totalloss: 22.728, tensor([3.5800e-01, 1.0000e-03, 1.0085e+01, 1.2284e+01])
#
# 	 EPOCH 85, totalloss: 22.872, tensor([3.6300e-01, 1.0000e-03, 1.0112e+01, 1.2397e+01])
#
# 	 EPOCH 86, totalloss: 23.434, tensor([3.7300e-01, 1.0000e-03, 1.0393e+01, 1.2667e+01])
#
# 	 EPOCH 87, totalloss: 22.858, tensor([3.6100e-01, 1.0000e-03, 1.0186e+01, 1.2310e+01])
#
# 	 EPOCH 88, totalloss: 22.715, tensor([3.5000e-01, 1.0000e-03, 1.0044e+01, 1.2320e+01])
#
# 	 EPOCH 89, totalloss: 22.953, tensor([3.8700e-01, 1.0000e-03, 1.0211e+01, 1.2354e+01])
#
# 	 EPOCH 90, totalloss: 22.5, tensor([3.6500e-01, 1.0000e-03, 9.9200e+00, 1.2214e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 89 %
# Accuracy of the network on validation model set SEMANTIC: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 47 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 91, totalloss: 22.403, tensor([3.4000e-01, 1.0000e-03, 9.8770e+00, 1.2185e+01])
#
# 	 EPOCH 92, totalloss: 22.593, tensor([3.4300e-01, 1.0000e-03, 1.0092e+01, 1.2156e+01])
#
# 	 EPOCH 93, totalloss: 22.746, tensor([3.4400e-01, 1.0000e-03, 1.0055e+01, 1.2346e+01])
#
# 	 EPOCH 94, totalloss: 22.392, tensor([3.1800e-01, 1.0000e-03, 1.0010e+01, 1.2063e+01])
#
# 	 EPOCH 95, totalloss: 22.45, tensor([3.4700e-01, 1.0000e-03, 1.0051e+01, 1.2052e+01])
#
# 	 EPOCH 96, totalloss: 22.581, tensor([3.2700e-01, 1.0000e-03, 9.9960e+00, 1.2257e+01])
#
# 	 EPOCH 97, totalloss: 22.531, tensor([3.3100e-01, 1.0000e-03, 1.0043e+01, 1.2156e+01])
#
# 	 EPOCH 98, totalloss: 22.63, tensor([3.3800e-01, 1.0000e-03, 1.0038e+01, 1.2253e+01])
#
# 	 EPOCH 99, totalloss: 22.197, tensor([ 0.3240,  0.0000,  9.7980, 12.0740])
#
# 	 EPOCH 100, totalloss: 22.262, tensor([3.1200e-01, 1.0000e-03, 9.9150e+00, 1.2034e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 89 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 59 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 101, totalloss: 22.459, tensor([ 0.3370,  0.0000,  9.9170, 12.2050])
#
# 	 EPOCH 102, totalloss: 22.112, tensor([3.1400e-01, 1.0000e-03, 9.7420e+00, 1.2055e+01])
#
# 	 EPOCH 103, totalloss: 22.046, tensor([3.3000e-01, 1.0000e-03, 9.7410e+00, 1.1974e+01])
#
# 	 EPOCH 104, totalloss: 22.011, tensor([ 0.3070,  0.0000,  9.6740, 12.0310])
#
# 	 EPOCH 105, totalloss: 22.108, tensor([ 0.3170,  0.0000,  9.8690, 11.9220])
#
# 	 EPOCH 106, totalloss: 21.768, tensor([ 0.2940,  0.0000,  9.6900, 11.7840])
#
# 	 EPOCH 107, totalloss: 21.704, tensor([ 0.2870,  0.0000,  9.7240, 11.6920])
#
# 	 EPOCH 108, totalloss: 21.691, tensor([2.6900e-01, 1.0000e-03, 9.5810e+00, 1.1839e+01])
#
# 	 EPOCH 109, totalloss: 21.88, tensor([3.1700e-01, 1.0000e-03, 9.6670e+00, 1.1895e+01])
#
# 	 EPOCH 110, totalloss: 21.996, tensor([2.9000e-01, 1.0000e-03, 9.7020e+00, 1.2003e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 91 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 61 %
# Accuracy of the network on validation model set AESTHETICS: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 111, totalloss: 21.571, tensor([ 0.2800,  0.0000,  9.4940, 11.7970])
#
# 	 EPOCH 112, totalloss: 21.95, tensor([2.8600e-01, 1.0000e-03, 9.7940e+00, 1.1869e+01])
#
# 	 EPOCH 113, totalloss: 21.585, tensor([ 0.2610,  0.0000,  9.6360, 11.6860])
#
# 	 EPOCH 114, totalloss: 21.595, tensor([2.6200e-01, 1.0000e-03, 9.7230e+00, 1.1609e+01])
#
# 	 EPOCH 115, totalloss: 21.395, tensor([ 0.2920,  0.0000,  9.3930, 11.7100])
#
# 	 EPOCH 116, totalloss: 21.791, tensor([3.1100e-01, 1.0000e-03, 9.6440e+00, 1.1834e+01])
#
# 	 EPOCH 117, totalloss: 21.706, tensor([2.9500e-01, 1.0000e-03, 9.7030e+00, 1.1708e+01])
# 	 EPOCH 118, totalloss: 21.341, tensor([ 0.2740,  0.0000,  9.5250, 11.5420])
#
# 	 EPOCH 119, totalloss: 21.428, tensor([ 0.2780,  0.0000,  9.5640, 11.5860])
#
# 	 EPOCH 120, totalloss: 21.096, tensor([ 0.2520,  0.0000,  9.3370, 11.5060])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 89 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 58 %
# Accuracy of the network on validation model set AESTHETICS: 44 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 121, totalloss: 21.335, tensor([ 0.2760,  0.0000,  9.4630, 11.5960])
#
# 	 EPOCH 122, totalloss: 21.362, tensor([ 0.2570,  0.0000,  9.5370, 11.5680])
#
# 	 EPOCH 123, totalloss: 21.036, tensor([ 0.2560,  0.0000,  9.2860, 11.4920])
#
# 	 EPOCH 124, totalloss: 21.192, tensor([2.6600e-01, 1.0000e-03, 9.4620e+00, 1.1463e+01])
#
# 	 EPOCH 125, totalloss: 21.055, tensor([ 0.2520,  0.0000,  9.3500, 11.4540])
#
# 	 EPOCH 126, totalloss: 21.913, tensor([2.8100e-01, 1.0000e-03, 9.7660e+00, 1.1865e+01])
#
# 	 EPOCH 127, totalloss: 21.229, tensor([ 0.2460,  0.0000,  9.4160, 11.5670])
#
# 	 EPOCH 128, totalloss: 20.981, tensor([ 0.2620,  0.0000,  9.3310, 11.3880])
#
# 	 EPOCH 129, totalloss: 21.245, tensor([ 0.2580,  0.0000,  9.4100, 11.5760])
#
# 	 EPOCH 130, totalloss: 20.974, tensor([ 0.2230,  0.0000,  9.4280, 11.3220])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 77 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 59 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 131, totalloss: 20.965, tensor([ 0.2150,  0.0000,  9.3820, 11.3680])
#
# 	 EPOCH 132, totalloss: 20.845, tensor([ 0.2200,  0.0000,  9.2750, 11.3500])
#
# 	 EPOCH 133, totalloss: 20.855, tensor([ 0.2270,  0.0000,  9.2030, 11.4250])
#
# 	 EPOCH 134, totalloss: 20.652, tensor([ 0.2140,  0.0000,  9.1450, 11.2940])
#
# 	 EPOCH 135, totalloss: 20.977, tensor([ 0.2410,  0.0000,  9.3730, 11.3630])
#
# 	 EPOCH 136, totalloss: 21.001, tensor([ 0.2450,  0.0000,  9.4130, 11.3410])
#
# 	 EPOCH 137, totalloss: 20.747, tensor([2.3400e-01, 1.0000e-03, 9.3390e+00, 1.1173e+01])
#
# 	 EPOCH 138, totalloss: 20.914, tensor([ 0.2400,  0.0000,  9.2990, 11.3750])
#
# 	 EPOCH 139, totalloss: 20.756, tensor([ 0.2280,  0.0000,  9.1710, 11.3580])
#
# 	 EPOCH 140, totalloss: 20.451, tensor([ 0.2210,  0.0000,  9.0970, 11.1320])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 141, totalloss: 21.068, tensor([ 0.2650,  0.0000,  9.3310, 11.4720])
#
# 	 EPOCH 142, totalloss: 20.656, tensor([ 0.2200,  0.0000,  9.2110, 11.2250])
#
# 	 EPOCH 143, totalloss: 20.421, tensor([ 0.2150,  0.0000,  9.1080, 11.0980])
#
# 	 EPOCH 144, totalloss: 20.749, tensor([ 0.2080,  0.0000,  9.3370, 11.2030])
#
# 	 EPOCH 145, totalloss: 20.67, tensor([ 0.2010,  0.0000,  9.1530, 11.3160])
#
# 	 EPOCH 146, totalloss: 20.371, tensor([ 0.2020,  0.0000,  9.1050, 11.0630])
#
# 	 EPOCH 147, totalloss: 21.254, tensor([ 0.2330,  0.0000,  9.4920, 11.5280])
#
# 	 EPOCH 148, totalloss: 20.576, tensor([ 0.2090,  0.0000,  9.1530, 11.2140])
#
# 	 EPOCH 149, totalloss: 20.168, tensor([ 0.2060,  0.0000,  8.9800, 10.9820])
#
# 	 EPOCH 150, totalloss: 20.157, tensor([ 0.1830,  0.0000,  8.9050, 11.0680])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 86 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 151, totalloss: 20.402, tensor([ 0.2160,  0.0000,  9.0420, 11.1440])
#
# 	 EPOCH 152, totalloss: 20.542, tensor([ 0.2180,  0.0000,  9.0440, 11.2800])
#
# 	 EPOCH 153, totalloss: 20.508, tensor([ 0.2150,  0.0000,  9.2730, 11.0200])
#
# 	 EPOCH 154, totalloss: 20.035, tensor([1.8400e-01, 1.0000e-03, 9.0020e+00, 1.0848e+01])
#
# 	 EPOCH 155, totalloss: 20.29, tensor([ 0.1960,  0.0000,  9.0610, 11.0340])
#
# 	 EPOCH 156, totalloss: 20.435, tensor([ 0.1970,  0.0000,  9.0960, 11.1400])
#
# 	 EPOCH 157, totalloss: 20.053, tensor([ 0.1870,  0.0000,  8.9040, 10.9620])
#
# 	 EPOCH 158, totalloss: 20.354, tensor([ 0.2040,  0.0000,  9.0940, 11.0560])
#
# 	 EPOCH 159, totalloss: 20.364, tensor([ 0.2000,  0.0000,  9.0990, 11.0640])
#
# 	 EPOCH 160, totalloss: 19.872, tensor([ 0.1650,  0.0000,  8.8750, 10.8330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 60 %
# Accuracy of the network on validation model set AESTHETICS: 44 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 161, totalloss: 20.068, tensor([ 0.1880,  0.0000,  9.0270, 10.8530])
#
# 	 EPOCH 162, totalloss: 19.925, tensor([ 0.1720,  0.0000,  8.8580, 10.8950])
#
# 	 EPOCH 163, totalloss: 19.994, tensor([ 0.1870,  0.0000,  8.9030, 10.9040])
#
# 	 EPOCH 164, totalloss: 20.187, tensor([ 0.1670,  0.0000,  9.0770, 10.9430])
#
# 	 EPOCH 165, totalloss: 20.019, tensor([ 0.2100,  0.0000,  9.0180, 10.7910])
#
# 	 EPOCH 166, totalloss: 19.91, tensor([ 0.1650,  0.0000,  8.8300, 10.9140])
#
# 	 EPOCH 167, totalloss: 19.733, tensor([ 0.1660,  0.0000,  8.7660, 10.8010])
#
# 	 EPOCH 168, totalloss: 19.636, tensor([ 0.1510,  0.0000,  8.6740, 10.8110])
#
# 	 EPOCH 169, totalloss: 20.277, tensor([ 0.2200,  0.0000,  9.0310, 11.0250])
#
# 	 EPOCH 170, totalloss: 19.793, tensor([ 0.1680,  0.0000,  8.8800, 10.7450])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 49 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 171, totalloss: 19.87, tensor([ 0.1630,  0.0000,  8.8150, 10.8920])
#
# 	 EPOCH 172, totalloss: 19.682, tensor([ 0.1910,  0.0000,  8.8390, 10.6520])
#
# 	 EPOCH 173, totalloss: 19.759, tensor([ 0.1840,  0.0000,  8.8440, 10.7310])
#
# 	 EPOCH 174, totalloss: 19.803, tensor([ 0.1770,  0.0000,  8.8560, 10.7700])
#
# 	 EPOCH 175, totalloss: 19.8, tensor([ 0.1680,  0.0000,  8.8330, 10.7990])
#
# 	 EPOCH 176, totalloss: 19.929, tensor([ 0.1660,  0.0000,  8.9340, 10.8290])
#
# 	 EPOCH 177, totalloss: 19.926, tensor([ 0.1650,  0.0000,  8.9270, 10.8340])
#
# 	 EPOCH 178, totalloss: 19.648, tensor([ 0.1580,  0.0000,  8.7050, 10.7850])
#
# 	 EPOCH 179, totalloss: 19.418, tensor([ 0.1540,  0.0000,  8.7490, 10.5150])
#
# 	 EPOCH 180, totalloss: 19.368, tensor([ 0.1400,  0.0000,  8.7270, 10.5010])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 91 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 181, totalloss: 19.557, tensor([ 0.1550,  0.0000,  8.7340, 10.6680])
#
# 	 EPOCH 182, totalloss: 19.507, tensor([ 0.1750,  0.0000,  8.5900, 10.7410])
#
# 	 EPOCH 183, totalloss: 19.924, tensor([ 0.1680,  0.0000,  8.8370, 10.9190])
#
# 	 EPOCH 184, totalloss: 19.548, tensor([ 0.1630,  0.0000,  8.6650, 10.7200])
# 	 EPOCH 185, totalloss: 19.974, tensor([ 0.1680,  0.0000,  8.9120, 10.8940])
#
# 	 EPOCH 186, totalloss: 19.739, tensor([ 0.1710,  0.0000,  8.7280, 10.8390])
#
# 	 EPOCH 187, totalloss: 19.182, tensor([ 0.1630,  0.0000,  8.4990, 10.5200])
#
# 	 EPOCH 188, totalloss: 19.71, tensor([ 0.1980,  0.0000,  8.7330, 10.7790])
#
# 	 EPOCH 189, totalloss: 19.812, tensor([ 0.1790,  0.0000,  8.8040, 10.8290])
#
# 	 EPOCH 190, totalloss: 19.342, tensor([ 0.1420,  0.0000,  8.6710, 10.5290])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 88 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 56 %
# Accuracy of the network on validation model set AESTHETICS: 51 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 191, totalloss: 19.402, tensor([ 0.1440,  0.0000,  8.7320, 10.5260])
#
# 	 EPOCH 192, totalloss: 19.111, tensor([ 0.1630,  0.0000,  8.5390, 10.4100])
#
# 	 EPOCH 193, totalloss: 19.393, tensor([ 0.1630,  0.0000,  8.7320, 10.4980])
#
# 	 EPOCH 194, totalloss: 19.483, tensor([ 0.1470,  0.0000,  8.6780, 10.6570])
#
# 	 EPOCH 195, totalloss: 18.952, tensor([ 0.1430,  0.0000,  8.4150, 10.3940])
#
# 	 EPOCH 196, totalloss: 19.235, tensor([ 0.1630,  0.0000,  8.6100, 10.4620])
#
# 	 EPOCH 197, totalloss: 19.266, tensor([ 0.1980,  0.0000,  8.5940, 10.4740])
#
# 	 EPOCH 198, totalloss: 19.072, tensor([ 0.1420,  0.0000,  8.6240, 10.3050])
#
# 	 EPOCH 199, totalloss: 19.364, tensor([ 0.1670,  0.0000,  8.6270, 10.5710])
#
# 	 EPOCH 200, totalloss: 18.838, tensor([ 0.1260,  0.0000,  8.3480, 10.3640])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 63 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 201, totalloss: 19.482, tensor([ 0.1790,  0.0000,  8.6770, 10.6260])
#
# 	 EPOCH 202, totalloss: 18.956, tensor([ 0.1580,  0.0000,  8.5100, 10.2880])
#
# 	 EPOCH 203, totalloss: 19.178, tensor([ 0.1410,  0.0000,  8.6070, 10.4300])
#
# 	 EPOCH 204, totalloss: 19.321, tensor([ 0.1710,  0.0000,  8.6040, 10.5450])
#
# 	 EPOCH 205, totalloss: 19.204, tensor([ 0.1470,  0.0000,  8.5950, 10.4620])
#
# 	 EPOCH 206, totalloss: 19.119, tensor([ 0.1240,  0.0000,  8.5880, 10.4070])
#
# 	 EPOCH 207, totalloss: 18.793, tensor([ 0.1420,  0.0000,  8.3700, 10.2810])
#
# 	 EPOCH 208, totalloss: 18.977, tensor([ 0.1500,  0.0000,  8.4540, 10.3730])
#
# 	 EPOCH 209, totalloss: 19.282, tensor([1.3600e-01, 1.0000e-03, 8.5560e+00, 1.0589e+01])
#
# 	 EPOCH 210, totalloss: 19.45, tensor([ 0.1590,  0.0000,  8.7710, 10.5200])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 65 %
# Accuracy of the network on validation model set AESTHETICS: 49 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 211, totalloss: 19.156, tensor([ 0.1490,  0.0000,  8.5620, 10.4450])
#
# 	 EPOCH 212, totalloss: 18.851, tensor([ 0.1420,  0.0000,  8.4450, 10.2630])
#
# 	 EPOCH 213, totalloss: 18.579, tensor([ 0.1340,  0.0000,  8.2870, 10.1590])
#
# 	 EPOCH 214, totalloss: 18.889, tensor([ 0.1610,  0.0000,  8.3130, 10.4150])
#
# 	 EPOCH 215, totalloss: 18.525, tensor([ 0.1230,  0.0000,  8.2430, 10.1590])
#
# 	 EPOCH 216, totalloss: 18.799, tensor([ 0.1390,  0.0000,  8.3380, 10.3230])
#
# 	 EPOCH 217, totalloss: 19.268, tensor([ 0.1590,  0.0000,  8.5560, 10.5530])
#
# 	 EPOCH 218, totalloss: 18.983, tensor([ 0.1250,  0.0000,  8.5180, 10.3390])
#
# 	 EPOCH 219, totalloss: 18.622, tensor([ 0.1390,  0.0000,  8.3510, 10.1320])
#
# 	 EPOCH 220, totalloss: 18.714, tensor([ 0.1220,  0.0000,  8.3700, 10.2220])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 57 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 221, totalloss: 18.281, tensor([0.1170, 0.0000, 8.2060, 9.9580])
#
# 	 EPOCH 222, totalloss: 18.868, tensor([ 0.1390,  0.0000,  8.4320, 10.2970])
#
# 	 EPOCH 223, totalloss: 18.75, tensor([ 0.1450,  0.0000,  8.3890, 10.2160])
#
# 	 EPOCH 224, totalloss: 19.02, tensor([ 0.1300,  0.0000,  8.5660, 10.3240])
#
# 	 EPOCH 225, totalloss: 18.448, tensor([ 0.1320,  0.0000,  8.2200, 10.0960])
#
# 	 EPOCH 226, totalloss: 19.442, tensor([ 0.1660,  0.0000,  8.6810, 10.5940])
#
# 	 EPOCH 227, totalloss: 18.684, tensor([ 0.1310,  0.0000,  8.2670, 10.2860])
#
# 	 EPOCH 228, totalloss: 18.941, tensor([ 0.1250,  0.0000,  8.4970, 10.3190])
#
# 	 EPOCH 229, totalloss: 18.792, tensor([ 0.1240,  0.0000,  8.3200, 10.3470])
#
# 	 EPOCH 230, totalloss: 18.874, tensor([ 0.1370,  0.0000,  8.4030, 10.3330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 65 %
# Accuracy of the network on validation model set AESTHETICS: 51 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 231, totalloss: 18.602, tensor([ 0.1260,  0.0000,  8.3300, 10.1460])
#
# 	 EPOCH 232, totalloss: 18.661, tensor([ 0.1190,  0.0000,  8.3640, 10.1780])
#
# 	 EPOCH 233, totalloss: 18.465, tensor([ 0.1050,  0.0000,  8.2510, 10.1080])
#
# 	 EPOCH 234, totalloss: 18.679, tensor([ 0.1460,  0.0000,  8.3660, 10.1680])
#
# 	 EPOCH 235, totalloss: 18.479, tensor([ 0.1300,  0.0000,  8.3240, 10.0250])
#
# 	 EPOCH 236, totalloss: 18.468, tensor([ 0.1140,  0.0000,  8.2270, 10.1260])
#
# 	 EPOCH 237, totalloss: 18.154, tensor([0.1130, 0.0000, 8.1060, 9.9350])
#
# 	 EPOCH 238, totalloss: 18.975, tensor([ 0.1550,  0.0000,  8.4920, 10.3280])
#
# 	 EPOCH 239, totalloss: 18.298, tensor([ 0.1160,  0.0000,  8.1580, 10.0240])
#
# 	 EPOCH 240, totalloss: 18.469, tensor([ 0.1340,  0.0000,  8.2600, 10.0750])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 93 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 241, totalloss: 18.188, tensor([0.1330, 0.0000, 8.0770, 9.9780])
#
# 	 EPOCH 242, totalloss: 18.429, tensor([ 0.1330,  0.0000,  8.2880, 10.0060])
#
# 	 EPOCH 243, totalloss: 18.426, tensor([ 0.1320,  0.0000,  8.2600, 10.0340])
#
# 	 EPOCH 244, totalloss: 17.791, tensor([0.1090, 0.0000, 7.9980, 9.6840])
#
# 	 EPOCH 245, totalloss: 18.831, tensor([ 0.1370,  0.0000,  8.3970, 10.2970])
#
# 	 EPOCH 246, totalloss: 18.146, tensor([0.1150, 0.0000, 8.1360, 9.8950])
#
# 	 EPOCH 247, totalloss: 18.14, tensor([0.1080, 0.0000, 8.1650, 9.8670])
#
# 	 EPOCH 248, totalloss: 18.033, tensor([0.1070, 0.0000, 8.0500, 9.8760])
#
# 	 EPOCH 249, totalloss: 17.791, tensor([0.0990, 0.0000, 7.9090, 9.7820])
#
# 	 EPOCH 250, totalloss: 18.313, tensor([ 0.1250,  0.0000,  8.1690, 10.0180])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 251, totalloss: 18.433, tensor([ 0.1060,  0.0000,  8.2480, 10.0780])
#
# 	 EPOCH 252, totalloss: 18.456, tensor([ 0.1280,  0.0000,  8.1520, 10.1750])
# 	 EPOCH 253, totalloss: 18.384, tensor([ 0.1250,  0.0000,  8.2220, 10.0370])
#
# 	 EPOCH 254, totalloss: 18.064, tensor([0.1160, 0.0000, 8.0920, 9.8560])
#
# 	 EPOCH 255, totalloss: 18.14, tensor([0.1380, 0.0000, 8.0520, 9.9490])
#
# 	 EPOCH 256, totalloss: 18.254, tensor([0.1280, 0.0000, 8.1830, 9.9430])
#
# 	 EPOCH 257, totalloss: 18.569, tensor([ 0.1410,  0.0000,  8.3380, 10.0900])
#
# 	 EPOCH 258, totalloss: 17.995, tensor([0.1030, 0.0000, 8.0420, 9.8500])
#
# 	 EPOCH 259, totalloss: 17.831, tensor([0.1220, 0.0000, 8.0320, 9.6770])
#
# 	 EPOCH 260, totalloss: 17.726, tensor([0.1130, 0.0000, 8.0200, 9.5930])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 261, totalloss: 18.405, tensor([ 0.1120,  0.0000,  8.2680, 10.0250])
#
# 	 EPOCH 262, totalloss: 17.842, tensor([0.1080, 0.0000, 8.0810, 9.6530])
#
# 	 EPOCH 263, totalloss: 17.876, tensor([0.0980, 0.0000, 8.0130, 9.7650])
#
# 	 EPOCH 264, totalloss: 17.84, tensor([0.1120, 0.0000, 8.0370, 9.6910])
#
# 	 EPOCH 265, totalloss: 17.596, tensor([0.1010, 0.0000, 7.8290, 9.6660])
#
# 	 EPOCH 266, totalloss: 17.625, tensor([0.0980, 0.0000, 7.8380, 9.6890])
#
# 	 EPOCH 267, totalloss: 17.883, tensor([0.1170, 0.0000, 8.0980, 9.6670])
#
# 	 EPOCH 268, totalloss: 18.077, tensor([0.1000, 0.0000, 8.1390, 9.8390])
#
# 	 EPOCH 269, totalloss: 17.933, tensor([0.1200, 0.0000, 8.0410, 9.7720])
#
# 	 EPOCH 270, totalloss: 18.025, tensor([0.1430, 0.0000, 8.0040, 9.8780])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 57 %
# Accuracy of the network on validation model set AESTHETICS: 51 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 271, totalloss: 17.666, tensor([0.1220, 0.0000, 7.9210, 9.6220])
#
# 	 EPOCH 272, totalloss: 18.243, tensor([0.1240, 0.0000, 8.2010, 9.9180])
#
# 	 EPOCH 273, totalloss: 17.737, tensor([0.0930, 0.0000, 8.0710, 9.5740])
#
# 	 EPOCH 274, totalloss: 18.122, tensor([0.1110, 0.0000, 8.0630, 9.9480])
#
# 	 EPOCH 275, totalloss: 17.611, tensor([0.1230, 0.0000, 7.8260, 9.6620])
#
# 	 EPOCH 276, totalloss: 17.037, tensor([0.0900, 0.0000, 7.6020, 9.3450])
#
# 	 EPOCH 277, totalloss: 17.718, tensor([0.0930, 0.0000, 7.8270, 9.7980])
#
# 	 EPOCH 278, totalloss: 17.617, tensor([0.1090, 0.0000, 7.9170, 9.5910])
#
# 	 EPOCH 279, totalloss: 17.567, tensor([0.1330, 0.0000, 7.7280, 9.7060])
#
# 	 EPOCH 280, totalloss: 17.571, tensor([0.1100, 0.0000, 7.8840, 9.5760])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 95 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 67 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 281, totalloss: 17.46, tensor([0.0910, 0.0000, 7.7900, 9.5790])
#
# 	 EPOCH 282, totalloss: 17.86, tensor([0.1000, 0.0000, 7.9220, 9.8370])
#
# 	 EPOCH 283, totalloss: 17.762, tensor([0.1230, 0.0000, 8.0540, 9.5840])
#
# 	 EPOCH 284, totalloss: 17.564, tensor([0.1100, 0.0000, 7.9030, 9.5510])
#
# 	 EPOCH 285, totalloss: 17.229, tensor([0.0900, 0.0000, 7.7850, 9.3540])
#
# 	 EPOCH 286, totalloss: 17.255, tensor([0.0930, 0.0000, 7.6970, 9.4650])
#
# 	 EPOCH 287, totalloss: 17.251, tensor([0.0980, 0.0000, 7.7210, 9.4310])
#
# 	 EPOCH 288, totalloss: 17.256, tensor([0.1030, 0.0000, 7.6380, 9.5150])
#
# 	 EPOCH 289, totalloss: 17.461, tensor([0.1050, 0.0000, 7.7720, 9.5850])
#
# 	 EPOCH 290, totalloss: 17.504, tensor([0.1220, 0.0000, 7.8700, 9.5120])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 63 %
# Accuracy of the network on validation model set AESTHETICS: 51 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 291, totalloss: 17.355, tensor([0.0930, 0.0000, 7.7230, 9.5400])
#
# 	 EPOCH 292, totalloss: 17.263, tensor([0.1010, 0.0000, 7.6880, 9.4750])
#
# 	 EPOCH 293, totalloss: 17.782, tensor([0.1280, 0.0000, 7.9080, 9.7460])
#
# 	 EPOCH 294, totalloss: 17.579, tensor([0.1290, 0.0000, 7.8480, 9.6010])
#
# 	 EPOCH 295, totalloss: 17.254, tensor([0.0950, 0.0000, 7.6560, 9.5030])
#
# 	 EPOCH 296, totalloss: 17.198, tensor([0.1040, 0.0000, 7.6420, 9.4520])
#
# 	 EPOCH 297, totalloss: 17.343, tensor([0.1170, 0.0000, 7.6810, 9.5450])
#
# 	 EPOCH 298, totalloss: 17.098, tensor([0.1000, 0.0000, 7.6890, 9.3080])
#
# 	 EPOCH 299, totalloss: 17.459, tensor([0.1090, 0.0000, 7.7870, 9.5630])
#
# 	 EPOCH 300, totalloss: 17.483, tensor([0.1100, 0.0000, 7.8960, 9.4760])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 89 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 58 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 301, totalloss: 17.773, tensor([0.1130, 0.0000, 7.9180, 9.7410])
#
# 	 EPOCH 302, totalloss: 17.467, tensor([0.1250, 0.0000, 7.6720, 9.6690])
#
# 	 EPOCH 303, totalloss: 16.831, tensor([0.0830, 0.0000, 7.4740, 9.2740])
#
# 	 EPOCH 304, totalloss: 17.061, tensor([0.0830, 0.0000, 7.6370, 9.3420])
#
# 	 EPOCH 305, totalloss: 17.027, tensor([0.1070, 0.0000, 7.6430, 9.2760])
#
# 	 EPOCH 306, totalloss: 17.294, tensor([0.0890, 0.0000, 7.6670, 9.5380])
#
# 	 EPOCH 307, totalloss: 17.234, tensor([0.0990, 0.0000, 7.7850, 9.3500])
#
# 	 EPOCH 308, totalloss: 17.033, tensor([0.1080, 0.0000, 7.6530, 9.2730])
#
# 	 EPOCH 309, totalloss: 17.342, tensor([0.1050, 0.0000, 7.7060, 9.5300])
#
# 	 EPOCH 310, totalloss: 17.19, tensor([0.1000, 0.0000, 7.6640, 9.4250])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 311, totalloss: 17.22, tensor([0.1070, 0.0000, 7.7010, 9.4120])
#
# 	 EPOCH 312, totalloss: 17.139, tensor([0.1000, 0.0000, 7.7440, 9.2950])
#
# 	 EPOCH 313, totalloss: 17.287, tensor([0.0980, 0.0000, 7.7320, 9.4570])
#
# 	 EPOCH 314, totalloss: 16.904, tensor([0.0830, 0.0000, 7.4810, 9.3400])
#
# 	 EPOCH 315, totalloss: 17.018, tensor([0.0890, 0.0000, 7.5800, 9.3490])
#
# 	 EPOCH 316, totalloss: 17.545, tensor([0.0940, 0.0000, 7.8300, 9.6200])
#
# 	 EPOCH 317, totalloss: 16.563, tensor([0.0730, 0.0000, 7.3800, 9.1100])
#
# 	 EPOCH 318, totalloss: 17.019, tensor([0.1010, 0.0000, 7.5390, 9.3780])
#
# 	 EPOCH 319, totalloss: 16.801, tensor([0.0910, 0.0000, 7.4630, 9.2470])
#
# 	 EPOCH 320, totalloss: 16.753, tensor([0.0890, 0.0000, 7.4950, 9.1680])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 63 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 321, totalloss: 17.127, tensor([0.1050, 0.0000, 7.5340, 9.4880])
#
# 	 EPOCH 322, totalloss: 17.431, tensor([0.1090, 0.0000, 7.6920, 9.6300])
#
# 	 EPOCH 323, totalloss: 17.054, tensor([0.1010, 0.0000, 7.6780, 9.2750])
# 	 EPOCH 324, totalloss: 17.01, tensor([0.0850, 0.0000, 7.5930, 9.3330])
#
# 	 EPOCH 325, totalloss: 17.217, tensor([0.1010, 0.0000, 7.6950, 9.4210])
#
# 	 EPOCH 326, totalloss: 16.435, tensor([0.0800, 0.0000, 7.3140, 9.0400])
#
# 	 EPOCH 327, totalloss: 16.514, tensor([0.0880, 0.0000, 7.3220, 9.1050])
#
# 	 EPOCH 328, totalloss: 16.732, tensor([0.0830, 0.0000, 7.4250, 9.2230])
#
# 	 EPOCH 329, totalloss: 16.462, tensor([0.0840, 0.0000, 7.3220, 9.0550])
#
# 	 EPOCH 330, totalloss: 16.489, tensor([0.0910, 0.0000, 7.4330, 8.9650])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 61 %
# Accuracy of the network on validation model set AESTHETICS: 47 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 331, totalloss: 16.638, tensor([0.0960, 0.0000, 7.4140, 9.1270])
#
# 	 EPOCH 332, totalloss: 16.483, tensor([0.0810, 0.0000, 7.2480, 9.1540])
#
# 	 EPOCH 333, totalloss: 17.2, tensor([0.1050, 0.0000, 7.6190, 9.4750])
#
# 	 EPOCH 334, totalloss: 16.659, tensor([0.0860, 0.0000, 7.3740, 9.1990])
#
# 	 EPOCH 335, totalloss: 17.138, tensor([0.0870, 0.0000, 7.6890, 9.3610])
#
# 	 EPOCH 336, totalloss: 16.363, tensor([0.0810, 0.0000, 7.3130, 8.9680])
#
# 	 EPOCH 337, totalloss: 16.639, tensor([0.0930, 0.0000, 7.4240, 9.1210])
#
# 	 EPOCH 338, totalloss: 16.52, tensor([0.0860, 0.0000, 7.3740, 9.0600])
#
# 	 EPOCH 339, totalloss: 16.307, tensor([0.0810, 0.0000, 7.2980, 8.9280])
#
# 	 EPOCH 340, totalloss: 16.594, tensor([0.0920, 0.0000, 7.5680, 8.9340])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 95 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 61 %
# Accuracy of the network on validation model set AESTHETICS: 51 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 341, totalloss: 16.632, tensor([0.0790, 0.0000, 7.2950, 9.2580])
#
# 	 EPOCH 342, totalloss: 17.046, tensor([0.0880, 0.0000, 7.5480, 9.4100])
#
# 	 EPOCH 343, totalloss: 17.269, tensor([0.0990, 0.0000, 7.7110, 9.4590])
#
# 	 EPOCH 344, totalloss: 16.645, tensor([0.0940, 0.0000, 7.3670, 9.1850])
#
# 	 EPOCH 345, totalloss: 16.71, tensor([0.1090, 0.0000, 7.4470, 9.1540])
#
# 	 EPOCH 346, totalloss: 16.328, tensor([0.0770, 0.0000, 7.2570, 8.9940])
#
# 	 EPOCH 347, totalloss: 16.628, tensor([0.1080, 0.0000, 7.3820, 9.1380])
#
# 	 EPOCH 348, totalloss: 16.508, tensor([0.0990, 0.0000, 7.3420, 9.0680])
#
# 	 EPOCH 349, totalloss: 16.189, tensor([0.0790, 0.0000, 7.2950, 8.8160])
#
# 	 EPOCH 350, totalloss: 16.24, tensor([0.0790, 0.0000, 7.1530, 9.0080])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 95 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 58 %
# Accuracy of the network on validation model set AESTHETICS: 53 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 351, totalloss: 16.415, tensor([0.0830, 0.0000, 7.2680, 9.0630])
#
# 	 EPOCH 352, totalloss: 16.782, tensor([0.1030, 0.0000, 7.5110, 9.1680])
#
# 	 EPOCH 353, totalloss: 16.331, tensor([0.0950, 0.0000, 7.2910, 8.9450])
#
# 	 EPOCH 354, totalloss: 16.505, tensor([0.1030, 0.0000, 7.3340, 9.0680])
#
# 	 EPOCH 355, totalloss: 16.481, tensor([0.0810, 0.0000, 7.4480, 8.9520])
#
# 	 EPOCH 356, totalloss: 16.326, tensor([0.0780, 0.0000, 7.1640, 9.0840])
#
# 	 EPOCH 357, totalloss: 16.442, tensor([0.1100, 0.0000, 7.2840, 9.0470])
#
# 	 EPOCH 358, totalloss: 16.27, tensor([0.0760, 0.0000, 7.2990, 8.8940])
#
# 	 EPOCH 359, totalloss: 15.959, tensor([0.0780, 0.0000, 7.1090, 8.7730])
#
# 	 EPOCH 360, totalloss: 16.262, tensor([0.0830, 0.0000, 7.2200, 8.9580])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 361, totalloss: 16.492, tensor([0.0850, 0.0000, 7.3440, 9.0630])
#
# 	 EPOCH 362, totalloss: 16.37, tensor([0.0950, 0.0000, 7.2580, 9.0160])
#
# 	 EPOCH 363, totalloss: 15.918, tensor([0.0830, 0.0000, 7.0370, 8.7970])
#
# 	 EPOCH 364, totalloss: 16.226, tensor([0.0900, 0.0000, 7.2180, 8.9180])
#
# 	 EPOCH 365, totalloss: 16.239, tensor([0.0860, 0.0000, 7.2700, 8.8830])
#
# 	 EPOCH 366, totalloss: 16.204, tensor([0.0770, 0.0000, 7.2560, 8.8710])
#
# 	 EPOCH 367, totalloss: 16.034, tensor([0.0790, 0.0000, 7.1960, 8.7590])
#
# 	 EPOCH 368, totalloss: 16.457, tensor([0.0790, 0.0000, 7.2900, 9.0880])
#
# 	 EPOCH 369, totalloss: 15.948, tensor([0.0730, 0.0000, 7.0640, 8.8110])
#
# 	 EPOCH 370, totalloss: 16.617, tensor([0.0780, 0.0000, 7.4290, 9.1100])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 371, totalloss: 16.967, tensor([0.0980, 0.0000, 7.5920, 9.2770])
#
# 	 EPOCH 372, totalloss: 16.153, tensor([0.0780, 0.0000, 7.1430, 8.9320])
#
# 	 EPOCH 373, totalloss: 16.253, tensor([0.1020, 0.0000, 7.2800, 8.8710])
#
# 	 EPOCH 374, totalloss: 16.279, tensor([0.0830, 0.0000, 7.2320, 8.9650])
#
# 	 EPOCH 375, totalloss: 15.934, tensor([0.0780, 0.0000, 7.1220, 8.7330])
#
# 	 EPOCH 376, totalloss: 16.484, tensor([0.0900, 0.0000, 7.4020, 8.9920])
#
# 	 EPOCH 377, totalloss: 16.492, tensor([0.0810, 0.0000, 7.3610, 9.0490])
#
# 	 EPOCH 378, totalloss: 15.791, tensor([0.0720, 0.0000, 6.9700, 8.7480])
#
# 	 EPOCH 379, totalloss: 16.497, tensor([0.0970, 0.0000, 7.2780, 9.1220])
#
# 	 EPOCH 380, totalloss: 15.902, tensor([0.0690, 0.0000, 7.0800, 8.7530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 381, totalloss: 15.999, tensor([0.0680, 0.0000, 7.1950, 8.7360])
#
# 	 EPOCH 382, totalloss: 16.162, tensor([0.0870, 0.0000, 7.1310, 8.9450])
#
# ...
#
# 	 EPOCH 767, totalloss: 12.68, tensor([0.0540, 0.0000, 5.5770, 7.0490])
#
# 	 EPOCH 768, totalloss: 12.433, tensor([0.0460, 0.0000, 5.4150, 6.9710])
#
# 	 EPOCH 769, totalloss: 13.122, tensor([0.0570, 0.0000, 5.8510, 7.2140])
#
# 	 EPOCH 770, totalloss: 12.98, tensor([0.0580, 0.0000, 5.7170, 7.2050])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 771, totalloss: 12.411, tensor([0.0380, 0.0000, 5.5730, 6.8000])
#
# 	 EPOCH 772, totalloss: 12.921, tensor([0.0490, 0.0000, 5.7900, 7.0810])
#
# 	 EPOCH 773, totalloss: 12.599, tensor([0.0430, 0.0000, 5.6490, 6.9070])
#
# 	 EPOCH 774, totalloss: 12.829, tensor([0.0500, 0.0000, 5.6610, 7.1190])
#
# 	 EPOCH 775, totalloss: 12.615, tensor([0.0440, 0.0000, 5.5460, 7.0250])
#
# 	 EPOCH 776, totalloss: 12.558, tensor([0.0490, 0.0000, 5.5380, 6.9710])
#
# 	 EPOCH 777, totalloss: 13.362, tensor([0.0490, 0.0000, 5.8680, 7.4450])
#
# 	 EPOCH 778, totalloss: 12.93, tensor([0.0500, 0.0000, 5.7310, 7.1490])
#
# 	 EPOCH 779, totalloss: 12.35, tensor([0.0410, 0.0000, 5.4100, 6.8980])
#
# 	 EPOCH 780, totalloss: 12.307, tensor([0.0430, 0.0000, 5.4310, 6.8330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 63 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 781, totalloss: 12.299, tensor([0.0540, 0.0000, 5.4910, 6.7540])
#
# 	 EPOCH 782, totalloss: 12.325, tensor([0.0450, 0.0000, 5.4580, 6.8220])
#
# 	 EPOCH 783, totalloss: 12.661, tensor([0.0630, 0.0000, 5.6420, 6.9560])
#
# 	 EPOCH 784, totalloss: 12.554, tensor([0.0520, 0.0000, 5.6250, 6.8760])
#
# 	 EPOCH 785, totalloss: 12.726, tensor([0.0530, 0.0000, 5.6260, 7.0470])
#
# 	 EPOCH 786, totalloss: 12.601, tensor([0.0490, 0.0000, 5.6090, 6.9430])
#
# 	 EPOCH 787, totalloss: 12.521, tensor([0.0490, 0.0000, 5.4840, 6.9890])
#
# 	 EPOCH 788, totalloss: 12.101, tensor([0.0390, 0.0000, 5.3700, 6.6920])
#
# 	 EPOCH 789, totalloss: 13.345, tensor([0.0490, 0.0000, 5.7990, 7.4970])
#
# 	 EPOCH 790, totalloss: 12.455, tensor([0.0390, 0.0000, 5.5340, 6.8820])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 791, totalloss: 12.46, tensor([0.0450, 0.0000, 5.4520, 6.9630])
#
# 	 EPOCH 792, totalloss: 12.347, tensor([0.0470, 0.0000, 5.5220, 6.7790])
#
# 	 EPOCH 793, totalloss: 12.478, tensor([0.0440, 0.0000, 5.4450, 6.9890])
#
# 	 EPOCH 794, totalloss: 12.874, tensor([0.0530, 0.0000, 5.7160, 7.1040])
#
# 	 EPOCH 795, totalloss: 12.341, tensor([0.0430, 0.0000, 5.5080, 6.7900])
#
# 	 EPOCH 796, totalloss: 12.727, tensor([0.0500, 0.0000, 5.5410, 7.1360])
#
# 	 EPOCH 797, totalloss: 12.987, tensor([0.0530, 0.0000, 5.7380, 7.1970])
#
# 	 EPOCH 798, totalloss: 12.314, tensor([0.0450, 0.0000, 5.4890, 6.7800])
#
# 	 EPOCH 799, totalloss: 12.729, tensor([0.0400, 0.0000, 5.6780, 7.0110])
#
# 	 EPOCH 800, totalloss: 12.128, tensor([0.0430, 0.0000, 5.3350, 6.7490])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 801, totalloss: 12.776, tensor([0.0550, 0.0000, 5.6500, 7.0710])
#
# 	 EPOCH 802, totalloss: 12.671, tensor([0.0510, 0.0000, 5.4960, 7.1240])
#
# 	 EPOCH 803, totalloss: 12.273, tensor([0.0430, 0.0000, 5.2840, 6.9450])
#
# 	 EPOCH 804, totalloss: 12.486, tensor([0.0480, 0.0000, 5.5570, 6.8810])
#
# 	 EPOCH 805, totalloss: 12.767, tensor([0.0510, 0.0000, 5.7140, 7.0030])
#
# 	 EPOCH 806, totalloss: 12.42, tensor([0.0480, 0.0000, 5.4080, 6.9640])
#
# 	 EPOCH 807, totalloss: 12.126, tensor([0.0460, 0.0000, 5.4380, 6.6430])
#
# 	 EPOCH 808, totalloss: 12.586, tensor([0.0490, 0.0000, 5.4170, 7.1190])
#
# 	 EPOCH 809, totalloss: 13.063, tensor([0.0610, 0.0000, 5.8260, 7.1760])
#
# 	 EPOCH 810, totalloss: 12.273, tensor([0.0440, 0.0000, 5.4480, 6.7810])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 67 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 811, totalloss: 12.723, tensor([0.0410, 0.0000, 5.7890, 6.8930])
#
# 	 EPOCH 812, totalloss: 12.624, tensor([0.0480, 0.0000, 5.6120, 6.9640])
#
# 	 EPOCH 813, totalloss: 12.902, tensor([0.0490, 0.0000, 5.7680, 7.0850])
#
# 	 EPOCH 814, totalloss: 12.547, tensor([0.0460, 0.0000, 5.5050, 6.9950])
#
# 	 EPOCH 815, totalloss: 12.594, tensor([0.0460, 0.0000, 5.5670, 6.9810])
#
# 	 EPOCH 816, totalloss: 12.602, tensor([0.0440, 0.0000, 5.5370, 7.0210])
#
# 	 EPOCH 817, totalloss: 12.21, tensor([0.0420, 0.0000, 5.3830, 6.7850])
#
# 	 EPOCH 818, totalloss: 12.165, tensor([0.0440, 0.0000, 5.3340, 6.7870])
#
# 	 EPOCH 819, totalloss: 12.614, tensor([0.0510, 0.0000, 5.5800, 6.9830])
#
# 	 EPOCH 820, totalloss: 12.272, tensor([0.0510, 0.0000, 5.3390, 6.8820])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 821, totalloss: 12.28, tensor([0.0450, 0.0000, 5.4850, 6.7500])
#
# 	 EPOCH 822, totalloss: 12.078, tensor([0.0420, 0.0000, 5.2820, 6.7540])
#
# 	 EPOCH 823, totalloss: 12.481, tensor([0.0420, 0.0000, 5.5160, 6.9240])
#
# 	 EPOCH 824, totalloss: 12.992, tensor([0.0480, 0.0000, 5.7300, 7.2130])
# 	 EPOCH 825, totalloss: 12.272, tensor([0.0450, 0.0000, 5.4190, 6.8070])
#
# 	 EPOCH 826, totalloss: 12.455, tensor([0.0500, 0.0000, 5.5890, 6.8160])
#
# 	 EPOCH 827, totalloss: 12.044, tensor([0.0400, 0.0000, 5.2850, 6.7200])
#
# 	 EPOCH 828, totalloss: 12.366, tensor([0.0450, 0.0000, 5.5400, 6.7810])
#
# 	 EPOCH 829, totalloss: 12.474, tensor([0.0590, 0.0000, 5.5480, 6.8670])
#
# 	 EPOCH 830, totalloss: 11.884, tensor([0.0370, 0.0000, 5.2640, 6.5840])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 61 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 831, totalloss: 12.012, tensor([0.0430, 0.0000, 5.2710, 6.6980])
#
# 	 EPOCH 832, totalloss: 12.115, tensor([0.0440, 0.0000, 5.4020, 6.6690])
#
# 	 EPOCH 833, totalloss: 12.092, tensor([0.0400, 0.0000, 5.3730, 6.6790])
#
# 	 EPOCH 834, totalloss: 12.472, tensor([0.0540, 0.0000, 5.5300, 6.8870])
#
# 	 EPOCH 835, totalloss: 12.384, tensor([0.0380, 0.0000, 5.4350, 6.9110])
#
# 	 EPOCH 836, totalloss: 12.186, tensor([0.0410, 0.0000, 5.3980, 6.7470])
#
# 	 EPOCH 837, totalloss: 12.102, tensor([0.0420, 0.0000, 5.4240, 6.6360])
#
# 	 EPOCH 838, totalloss: 12.962, tensor([0.0510, 0.0000, 5.6030, 7.3080])
#
# 	 EPOCH 839, totalloss: 12.439, tensor([0.0500, 0.0000, 5.4960, 6.8920])
#
# 	 EPOCH 840, totalloss: 12.293, tensor([0.0430, 0.0000, 5.3370, 6.9120])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 95 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 55 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 841, totalloss: 12.042, tensor([0.0430, 0.0000, 5.3080, 6.6900])
#
# 	 EPOCH 842, totalloss: 12.425, tensor([0.0470, 0.0000, 5.5410, 6.8370])
#
# 	 EPOCH 843, totalloss: 12.403, tensor([0.0450, 0.0000, 5.5590, 6.7990])
#
# 	 EPOCH 844, totalloss: 12.379, tensor([0.0410, 0.0000, 5.5200, 6.8180])
#
# 	 EPOCH 845, totalloss: 12.358, tensor([0.0450, 0.0000, 5.4410, 6.8720])
#
# 	 EPOCH 846, totalloss: 12.206, tensor([0.0480, 0.0000, 5.4030, 6.7540])
#
# 	 EPOCH 847, totalloss: 11.875, tensor([0.0430, 0.0000, 5.2600, 6.5720])
#
# 	 EPOCH 848, totalloss: 11.933, tensor([0.0420, 0.0000, 5.3710, 6.5200])
#
# 	 EPOCH 849, totalloss: 12.283, tensor([0.0490, 0.0000, 5.3700, 6.8650])
#
# 	 EPOCH 850, totalloss: 12.676, tensor([0.0460, 0.0000, 5.6250, 7.0050])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 851, totalloss: 12.366, tensor([0.0460, 0.0000, 5.5160, 6.8040])
#
# 	 EPOCH 852, totalloss: 12.033, tensor([0.0460, 0.0000, 5.2530, 6.7340])
#
# 	 EPOCH 853, totalloss: 12.205, tensor([0.0450, 0.0000, 5.4290, 6.7310])
#
# 	 EPOCH 854, totalloss: 11.871, tensor([0.0420, 0.0000, 5.2280, 6.6010])
#
# 	 EPOCH 855, totalloss: 12.134, tensor([0.0360, 0.0000, 5.3930, 6.7050])
#
# 	 EPOCH 856, totalloss: 11.776, tensor([0.0460, 0.0000, 5.1720, 6.5580])
#
# 	 EPOCH 857, totalloss: 12.766, tensor([0.0430, 0.0000, 5.6770, 7.0460])
#
# 	 EPOCH 858, totalloss: 12.331, tensor([0.0450, 0.0000, 5.4520, 6.8340])
#
# 	 EPOCH 859, totalloss: 12.265, tensor([0.0540, 0.0000, 5.4830, 6.7280])
#
# 	 EPOCH 860, totalloss: 11.952, tensor([0.0490, 0.0000, 5.2630, 6.6390])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 65 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 861, totalloss: 11.875, tensor([0.0430, 0.0000, 5.2950, 6.5370])
#
# 	 EPOCH 862, totalloss: 12.289, tensor([0.0450, 0.0000, 5.5260, 6.7190])
#
# 	 EPOCH 863, totalloss: 11.487, tensor([0.0370, 0.0000, 5.0720, 6.3780])
#
# 	 EPOCH 864, totalloss: 12.329, tensor([0.0480, 0.0000, 5.4990, 6.7820])
#
# 	 EPOCH 865, totalloss: 12.207, tensor([0.0450, 0.0000, 5.4680, 6.6940])
#
# 	 EPOCH 866, totalloss: 12.136, tensor([0.0400, 0.0000, 5.3250, 6.7700])
#
# 	 EPOCH 867, totalloss: 11.838, tensor([0.0420, 0.0000, 5.1680, 6.6270])
#
# 	 EPOCH 868, totalloss: 12.173, tensor([0.0420, 0.0000, 5.3210, 6.8110])
#
# 	 EPOCH 869, totalloss: 11.933, tensor([0.0410, 0.0000, 5.2990, 6.5930])
#
# 	 EPOCH 870, totalloss: 12.186, tensor([0.0450, 0.0000, 5.4040, 6.7370])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 871, totalloss: 11.894, tensor([0.0440, 0.0000, 5.2460, 6.6040])
#
# 	 EPOCH 872, totalloss: 12.308, tensor([0.0490, 0.0000, 5.5190, 6.7400])
#
# 	 EPOCH 873, totalloss: 12.336, tensor([0.0490, 0.0000, 5.4210, 6.8660])
#
# 	 EPOCH 874, totalloss: 11.827, tensor([0.0420, 0.0000, 5.2160, 6.5680])
#
# 	 EPOCH 875, totalloss: 12.021, tensor([0.0460, 0.0000, 5.2590, 6.7170])
#
# 	 EPOCH 876, totalloss: 11.735, tensor([0.0420, 0.0000, 5.1940, 6.5000])
#
# 	 EPOCH 877, totalloss: 11.976, tensor([0.0400, 0.0000, 5.3160, 6.6200])
#
# 	 EPOCH 878, totalloss: 11.78, tensor([0.0410, 0.0000, 5.1640, 6.5750])
#
# 	 EPOCH 879, totalloss: 12.577, tensor([0.0360, 0.0000, 5.5690, 6.9720])
#
# 	 EPOCH 880, totalloss: 11.677, tensor([0.0440, 0.0000, 5.1220, 6.5110])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 61 %
# Accuracy of the network on validation model set AESTHETICS: 55 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 881, totalloss: 12.4, tensor([0.0440, 0.0000, 5.5240, 6.8320])
#
# 	 EPOCH 882, totalloss: 12.2, tensor([0.0430, 0.0000, 5.3630, 6.7940])
#
# 	 EPOCH 883, totalloss: 12.278, tensor([0.0410, 0.0000, 5.4370, 6.7990])
#
# 	 EPOCH 884, totalloss: 11.658, tensor([0.0410, 0.0000, 5.1270, 6.4910])
#
# 	 EPOCH 885, totalloss: 12.05, tensor([0.0470, 0.0000, 5.3870, 6.6160])
#
# 	 EPOCH 886, totalloss: 12.288, tensor([0.0430, 0.0000, 5.4800, 6.7650])
#
# 	 EPOCH 887, totalloss: 12.449, tensor([0.0440, 0.0000, 5.4000, 7.0050])
#
# 	 EPOCH 888, totalloss: 12.163, tensor([0.0460, 0.0000, 5.4190, 6.6980])
#
# 	 EPOCH 889, totalloss: 11.914, tensor([0.0470, 0.0000, 5.3140, 6.5530])
#
# 	 EPOCH 890, totalloss: 11.541, tensor([0.0400, 0.0000, 5.1000, 6.4010])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 891, totalloss: 12.021, tensor([0.0450, 0.0000, 5.3450, 6.6300])
#
# 	 EPOCH 892, totalloss: 11.801, tensor([0.0360, 0.0000, 5.2280, 6.5370])
#
# 	 EPOCH 893, totalloss: 11.818, tensor([0.0340, 0.0000, 5.1510, 6.6330])
#
# 	 EPOCH 894, totalloss: 12.218, tensor([0.0440, 0.0000, 5.3440, 6.8300])
#
# 	 EPOCH 895, totalloss: 11.891, tensor([0.0430, 0.0000, 5.1950, 6.6530])
#
# 	 EPOCH 896, totalloss: 11.588, tensor([0.0440, 0.0000, 5.1780, 6.3650])
# 	 EPOCH 897, totalloss: 11.898, tensor([0.0540, 0.0000, 5.3130, 6.5310])
#
# 	 EPOCH 898, totalloss: 11.771, tensor([0.0440, 0.0000, 5.1640, 6.5630])
#
# 	 EPOCH 899, totalloss: 12.074, tensor([0.0480, 0.0000, 5.3290, 6.6980])
#
# 	 EPOCH 900, totalloss: 11.489, tensor([0.0420, 0.0000, 5.0120, 6.4350])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 901, totalloss: 11.477, tensor([0.0390, 0.0000, 5.1170, 6.3210])
#
# 	 EPOCH 902, totalloss: 11.834, tensor([0.0430, 0.0000, 5.3050, 6.4850])
#
# 	 EPOCH 903, totalloss: 11.868, tensor([0.0420, 0.0000, 5.2480, 6.5780])

# %%
## train on single class: house
# !CUDA_VISIBLE_DEVICES=2 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_house.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: house
#   WHICH_TASK: all
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf_singlesemclass
# OPTIM:
#   BATCH_SIZE: 32
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 2500
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_23_10_12_49_ai_aesthetics_optim_nettype-GraphConvClf_singlesemclass_class-house
#   full_experiment_name: exp_11_23_10_12_49_ai_aesthetics_optim_nettype-GraphConvClf_singlesemclass_class-house
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_house.yml
# config_override     : []
# Splitting Dataset..
# number of training samples: 576
# Training Samples: 18
# Validation Samples: 50
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 30.865, tensor([ 1.0710, 13.7760, 16.0190])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 74 %
# Accuracy of the network on validation model set FUNCTIONALITY: 30 %
# Accuracy of the network on validation model set AESTHETICS: 32 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 29.442, tensor([ 0.7840, 13.1690, 15.4890])
#
# 	 EPOCH 2, totalloss: 28.594, tensor([ 0.5550, 12.8130, 15.2260])
#
# 	 EPOCH 3, totalloss: 27.292, tensor([ 0.5300, 12.2360, 14.5270])
#
# 	 EPOCH 4, totalloss: 26.085, tensor([ 0.4530, 11.7430, 13.8890])
#
# 	 EPOCH 5, totalloss: 24.831, tensor([ 0.4360, 11.1620, 13.2320])
#
# 	 EPOCH 6, totalloss: 24.589, tensor([ 0.3820, 11.1640, 13.0430])
#
# 	 EPOCH 7, totalloss: 24.724, tensor([ 0.3300, 11.2380, 13.1560])
#
# 	 EPOCH 8, totalloss: 24.113, tensor([ 0.2980, 10.8410, 12.9740])
#
# 	 EPOCH 9, totalloss: 23.923, tensor([ 0.2790, 10.8050, 12.8400])
#
# 	 EPOCH 10, totalloss: 23.698, tensor([ 0.2320, 10.7330, 12.7340])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 54 %
# Accuracy of the network on validation model set AESTHETICS: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 11, totalloss: 23.696, tensor([ 0.2340, 10.6890, 12.7730])
#
# 	 EPOCH 12, totalloss: 23.228, tensor([ 0.2180, 10.5080, 12.5020])
#
# 	 EPOCH 13, totalloss: 23.043, tensor([ 0.2250, 10.4580, 12.3600])
#
# 	 EPOCH 14, totalloss: 23.959, tensor([ 0.2230, 10.9980, 12.7380])
#
# 	 EPOCH 15, totalloss: 22.861, tensor([ 0.2080, 10.4290, 12.2240])
#
# 	 EPOCH 16, totalloss: 22.778, tensor([ 0.1900, 10.4350, 12.1540])
#
# 	 EPOCH 17, totalloss: 22.946, tensor([ 0.2040, 10.4460, 12.2950])
#
# 	 EPOCH 18, totalloss: 22.625, tensor([ 0.1900, 10.3040, 12.1310])
#
# 	 EPOCH 19, totalloss: 22.672, tensor([ 0.1940, 10.3310, 12.1470])
#
# 	 EPOCH 20, totalloss: 22.522, tensor([ 0.2010, 10.3160, 12.0040])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 44 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 21, totalloss: 22.614, tensor([ 0.2040, 10.3000, 12.1100])
#
# 	 EPOCH 22, totalloss: 22.002, tensor([ 0.1860, 10.0960, 11.7200])
#
# 	 EPOCH 23, totalloss: 22.26, tensor([ 0.1810, 10.2610, 11.8190])
#
# 	 EPOCH 24, totalloss: 21.832, tensor([ 0.1900, 10.0540, 11.5880])
#
# 	 EPOCH 25, totalloss: 21.645, tensor([ 0.1900,  9.9650, 11.4910])
#
# 	 EPOCH 26, totalloss: 21.59, tensor([ 0.1880,  9.9570, 11.4440])
#
# 	 EPOCH 27, totalloss: 20.983, tensor([ 0.1870,  9.7350, 11.0610])
#
# 	 EPOCH 28, totalloss: 21.479, tensor([ 0.2020, 10.0370, 11.2410])
#
# 	 EPOCH 29, totalloss: 21.53, tensor([ 0.1810,  9.8920, 11.4580])
#
# 	 EPOCH 30, totalloss: 21.304, tensor([ 0.1860,  9.8770, 11.2410])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 48 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 31, totalloss: 20.905, tensor([ 0.1800,  9.8130, 10.9110])
#
# 	 EPOCH 32, totalloss: 20.7, tensor([ 0.1630,  9.8100, 10.7270])
#
# 	 EPOCH 33, totalloss: 20.675, tensor([ 0.1720,  9.4990, 11.0040])
#
# 	 EPOCH 34, totalloss: 20.182, tensor([ 0.1800,  9.4930, 10.5100])
#
# 	 EPOCH 35, totalloss: 21.073, tensor([ 0.1850,  9.7060, 11.1820])
#
# 	 EPOCH 36, totalloss: 20.961, tensor([ 0.1630,  9.6270, 11.1700])
#
# 	 EPOCH 37, totalloss: 20.679, tensor([ 0.1570,  9.5830, 10.9390])
#
# 	 EPOCH 38, totalloss: 19.201, tensor([ 0.1880,  8.8550, 10.1570])
#
# 	 EPOCH 39, totalloss: 20.596, tensor([ 0.2050,  9.4800, 10.9110])
#
# 	 EPOCH 40, totalloss: 19.783, tensor([ 0.1820,  9.1410, 10.4600])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 41, totalloss: 19.218, tensor([ 0.1730,  8.9760, 10.0690])
#
# 	 EPOCH 42, totalloss: 19.468, tensor([ 0.1760,  9.1000, 10.1930])
#
# 	 EPOCH 43, totalloss: 19.476, tensor([ 0.1740,  9.0000, 10.3020])
#
# 	 EPOCH 44, totalloss: 18.212, tensor([0.1690, 8.4670, 9.5750])
#
# 	 EPOCH 45, totalloss: 19.096, tensor([ 0.1720,  8.8730, 10.0510])
#
# 	 EPOCH 46, totalloss: 18.476, tensor([0.1650, 8.3470, 9.9630])
#
# 	 EPOCH 47, totalloss: 18.079, tensor([0.1650, 8.1420, 9.7720])
#
# 	 EPOCH 48, totalloss: 18.069, tensor([0.1580, 8.4040, 9.5060])
#
# 	 EPOCH 49, totalloss: 19.298, tensor([ 0.1820,  8.8230, 10.2920])
#
# 	 EPOCH 50, totalloss: 19.194, tensor([ 0.1650,  8.7810, 10.2490])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 51, totalloss: 17.423, tensor([0.1440, 7.8060, 9.4740])
#
# 	 EPOCH 52, totalloss: 16.934, tensor([0.1450, 7.5980, 9.1910])
#
# 	 EPOCH 53, totalloss: 17.61, tensor([0.1260, 7.9820, 9.5010])
#
# 	 EPOCH 54, totalloss: 17.857, tensor([0.1620, 8.1200, 9.5750])
#
# 	 EPOCH 55, totalloss: 18.539, tensor([0.1490, 8.4620, 9.9280])
#
# 	 EPOCH 56, totalloss: 17.461, tensor([0.1630, 7.6180, 9.6810])
#
# 	 EPOCH 57, totalloss: 17.101, tensor([0.1380, 7.7560, 9.2080])
#
# 	 EPOCH 58, totalloss: 17.084, tensor([0.1460, 7.5980, 9.3390])
#
# 	 EPOCH 59, totalloss: 17.605, tensor([0.1410, 7.8450, 9.6180])
#
# 	 EPOCH 60, totalloss: 16.672, tensor([0.1330, 7.3450, 9.1930])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 61, totalloss: 17.363, tensor([0.1690, 7.7940, 9.3990])
#
# 	 EPOCH 62, totalloss: 16.887, tensor([0.1340, 7.6350, 9.1170])
#
# 	 EPOCH 63, totalloss: 17.785, tensor([0.1800, 7.7210, 9.8850])
#
# 	 EPOCH 64, totalloss: 16.78, tensor([0.1280, 7.3740, 9.2790])
#
# 	 EPOCH 65, totalloss: 17.585, tensor([0.1420, 7.5960, 9.8470])
#
# 	 EPOCH 66, totalloss: 17.052, tensor([0.1580, 7.5880, 9.3060])
#
# 	 EPOCH 67, totalloss: 17.173, tensor([0.1710, 7.6240, 9.3780])
#
# 	 EPOCH 68, totalloss: 16.547, tensor([0.1420, 7.4170, 8.9890])
#
# 	 EPOCH 69, totalloss: 15.893, tensor([0.1550, 7.1190, 8.6190])
# 	 EPOCH 70, totalloss: 16.075, tensor([0.1410, 7.1060, 8.8280])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 71, totalloss: 17.309, tensor([0.1440, 7.8330, 9.3320])
#
# 	 EPOCH 72, totalloss: 16.473, tensor([0.1910, 7.2720, 9.0100])
#
# 	 EPOCH 73, totalloss: 15.736, tensor([0.1470, 7.0570, 8.5330])
#
# 	 EPOCH 74, totalloss: 15.842, tensor([0.1300, 7.2000, 8.5130])
#
# 	 EPOCH 75, totalloss: 16.012, tensor([0.1370, 7.0050, 8.8710])
#
# 	 EPOCH 76, totalloss: 15.994, tensor([0.1300, 7.1680, 8.6960])
#
# 	 EPOCH 77, totalloss: 15.993, tensor([0.1240, 6.9870, 8.8830])
#
# 	 EPOCH 78, totalloss: 14.857, tensor([0.1350, 6.4190, 8.3030])
#
# 	 EPOCH 79, totalloss: 15.412, tensor([0.1220, 6.9120, 8.3780])
#
# 	 EPOCH 80, totalloss: 14.743, tensor([0.1270, 6.3690, 8.2480])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 81, totalloss: 15.393, tensor([0.1410, 6.7220, 8.5290])
#
# 	 EPOCH 82, totalloss: 14.635, tensor([0.1230, 6.3680, 8.1440])
#
# 	 EPOCH 83, totalloss: 15.05, tensor([0.1950, 6.7470, 8.1090])
#
# 	 EPOCH 84, totalloss: 15.842, tensor([0.1150, 6.9340, 8.7920])
#
# 	 EPOCH 85, totalloss: 16.306, tensor([0.1490, 7.0960, 9.0610])
#
# 	 EPOCH 86, totalloss: 14.394, tensor([0.1150, 6.2990, 7.9800])
#
# 	 EPOCH 87, totalloss: 14.55, tensor([0.1220, 6.3060, 8.1220])
#
# 	 EPOCH 88, totalloss: 14.85, tensor([0.1220, 6.5100, 8.2170])
#
# 	 EPOCH 89, totalloss: 13.868, tensor([0.1510, 6.2580, 7.4590])
#
# 	 EPOCH 90, totalloss: 14.902, tensor([0.1480, 6.5030, 8.2510])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 91, totalloss: 14.394, tensor([0.1300, 6.1700, 8.0950])
#
# 	 EPOCH 92, totalloss: 15.497, tensor([0.1320, 6.8650, 8.5000])
#
# 	 EPOCH 93, totalloss: 15.175, tensor([0.1360, 6.5460, 8.4930])
#
# 	 EPOCH 94, totalloss: 14.283, tensor([0.1160, 6.1090, 8.0590])
#
# 	 EPOCH 95, totalloss: 14.132, tensor([0.1210, 6.1270, 7.8850])
#
# 	 EPOCH 96, totalloss: 14.024, tensor([0.0980, 6.2980, 7.6270])
#
# 	 EPOCH 97, totalloss: 13.992, tensor([0.1300, 6.1990, 7.6630])
#
# 	 EPOCH 98, totalloss: 14.716, tensor([0.1420, 6.4210, 8.1530])
#
# 	 EPOCH 99, totalloss: 14.982, tensor([0.1200, 6.5990, 8.2630])
#
# 	 EPOCH 100, totalloss: 15.552, tensor([0.1250, 6.7610, 8.6670])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 101, totalloss: 14.893, tensor([0.1300, 6.7180, 8.0460])
#
# 	 EPOCH 102, totalloss: 13.796, tensor([0.1430, 6.0980, 7.5550])
#
# 	 EPOCH 103, totalloss: 14.601, tensor([0.1130, 6.3260, 8.1620])
#
# 	 EPOCH 104, totalloss: 14.024, tensor([0.1140, 6.0450, 7.8640])
#
# 	 EPOCH 105, totalloss: 13.033, tensor([0.1050, 5.7500, 7.1780])
#
# 	 EPOCH 106, totalloss: 13.735, tensor([0.1340, 5.7530, 7.8480])
#
# 	 EPOCH 107, totalloss: 14.454, tensor([0.1520, 6.4660, 7.8370])
#
# 	 EPOCH 108, totalloss: 13.819, tensor([0.1040, 5.9030, 7.8130])
#
# 	 EPOCH 109, totalloss: 15.369, tensor([0.1500, 6.7420, 8.4780])
#
# 	 EPOCH 110, totalloss: 13.84, tensor([0.1260, 6.1270, 7.5870])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 111, totalloss: 14.067, tensor([0.1140, 5.9850, 7.9680])
#
# 	 EPOCH 112, totalloss: 13.374, tensor([0.1120, 5.7560, 7.5070])
#
# 	 EPOCH 113, totalloss: 13.385, tensor([0.1110, 5.7480, 7.5260])
#
# 	 EPOCH 114, totalloss: 14.013, tensor([0.1220, 6.0700, 7.8210])
#
# 	 EPOCH 115, totalloss: 15.173, tensor([0.1250, 6.6710, 8.3770])
#
# 	 EPOCH 116, totalloss: 15.347, tensor([0.1260, 6.6810, 8.5410])
#
# 	 EPOCH 117, totalloss: 12.861, tensor([0.1120, 5.5980, 7.1500])
#
# 	 EPOCH 118, totalloss: 13.281, tensor([0.1070, 5.7850, 7.3890])
#
# 	 EPOCH 119, totalloss: 13.169, tensor([0.1040, 5.8350, 7.2290])
#
# 	 EPOCH 120, totalloss: 13.775, tensor([0.1100, 5.7760, 7.8890])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 90 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 121, totalloss: 14.08, tensor([0.1200, 6.1530, 7.8080])
#
# 	 EPOCH 122, totalloss: 14.342, tensor([0.1130, 6.5390, 7.6900])
#
# 	 EPOCH 123, totalloss: 13.129, tensor([0.1200, 5.5460, 7.4640])
#
# 	 EPOCH 124, totalloss: 13.029, tensor([0.1290, 5.6540, 7.2460])
#
# 	 EPOCH 125, totalloss: 13.465, tensor([0.1470, 5.9330, 7.3840])
#
# 	 EPOCH 126, totalloss: 13.504, tensor([0.1570, 5.8810, 7.4660])
#
# 	 EPOCH 127, totalloss: 13.901, tensor([0.1260, 6.0460, 7.7280])
#
# 	 EPOCH 128, totalloss: 13.759, tensor([0.1200, 6.0650, 7.5730])
#
# 	 EPOCH 129, totalloss: 13.128, tensor([0.1000, 5.8550, 7.1720])
#
# 	 EPOCH 130, totalloss: 13.483, tensor([0.1150, 5.9630, 7.4060])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 131, totalloss: 12.49, tensor([0.1250, 5.3570, 7.0070])
#
# 	 EPOCH 132, totalloss: 12.881, tensor([0.1060, 5.5370, 7.2380])
#
# 	 EPOCH 133, totalloss: 14.004, tensor([0.1030, 6.0120, 7.8900])
#
# 	 EPOCH 134, totalloss: 14.257, tensor([0.1080, 6.0060, 8.1440])
#
# 	 EPOCH 135, totalloss: 13.075, tensor([0.1310, 5.5840, 7.3600])
#
# 	 EPOCH 136, totalloss: 12.872, tensor([0.0990, 5.7300, 7.0430])
#
# 	 EPOCH 137, totalloss: 12.23, tensor([0.0990, 5.1660, 6.9650])
#
# 	 EPOCH 138, totalloss: 12.965, tensor([0.1160, 5.5230, 7.3260])
#
# 	 EPOCH 139, totalloss: 11.898, tensor([0.1110, 5.2180, 6.5690])
#
# 	 EPOCH 140, totalloss: 12.431, tensor([0.0910, 5.4560, 6.8840])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 48 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 141, totalloss: 12.667, tensor([0.1160, 5.3160, 7.2360])
#
# 	 EPOCH 142, totalloss: 13.934, tensor([0.1110, 6.0420, 7.7810])
#
# 	 EPOCH 143, totalloss: 13.86, tensor([0.1220, 5.8970, 7.8400])
#
# 	 EPOCH 144, totalloss: 12.659, tensor([0.1230, 5.7020, 6.8340])
#
# 	 EPOCH 145, totalloss: 13.13, tensor([0.0980, 5.5750, 7.4570])
#
# 	 EPOCH 146, totalloss: 12.142, tensor([0.0990, 5.1810, 6.8620])
#
# 	 EPOCH 147, totalloss: 12.245, tensor([0.1090, 5.2520, 6.8840])
#
# 	 EPOCH 148, totalloss: 12.18, tensor([0.0990, 5.2010, 6.8790])
#
# 	 EPOCH 149, totalloss: 13.137, tensor([0.1320, 5.7990, 7.2050])
#
# 	 EPOCH 150, totalloss: 12.635, tensor([0.1100, 5.4730, 7.0520])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 151, totalloss: 11.989, tensor([0.0950, 5.1810, 6.7140])
#
# 	 EPOCH 152, totalloss: 13.758, tensor([0.1030, 6.0390, 7.6160])
#
# 	 EPOCH 153, totalloss: 13.645, tensor([0.0940, 6.0820, 7.4690])
#
# 	 EPOCH 154, totalloss: 13.336, tensor([0.1060, 5.7100, 7.5200])
#
# 	 EPOCH 155, totalloss: 14.281, tensor([0.1220, 6.0550, 8.1040])
#
# 	 EPOCH 156, totalloss: 12.863, tensor([0.1050, 5.5110, 7.2470])
#
# 	 EPOCH 157, totalloss: 11.674, tensor([0.0970, 5.0310, 6.5450])
#
# 	 EPOCH 158, totalloss: 12.353, tensor([0.0960, 5.3180, 6.9390])
#
# 	 EPOCH 159, totalloss: 13.306, tensor([0.1370, 5.6700, 7.4990])
#
# 	 EPOCH 160, totalloss: 11.91, tensor([0.0960, 5.1790, 6.6350])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 161, totalloss: 12.604, tensor([0.1230, 5.2480, 7.2320])
#
# 	 EPOCH 162, totalloss: 14.073, tensor([0.1110, 6.3000, 7.6620])
#
# 	 EPOCH 163, totalloss: 12.661, tensor([0.0980, 5.4010, 7.1620])
#
# 	 EPOCH 164, totalloss: 13.212, tensor([0.0990, 5.8050, 7.3080])
#
# 	 EPOCH 165, totalloss: 12.377, tensor([0.1080, 5.3690, 6.9010])
#
# 	 EPOCH 166, totalloss: 13.429, tensor([0.1070, 5.8530, 7.4680])
#
# 	 EPOCH 167, totalloss: 11.796, tensor([0.0940, 4.9590, 6.7430])
#
# 	 EPOCH 168, totalloss: 11.293, tensor([0.0940, 4.6840, 6.5160])
#
# 	 EPOCH 169, totalloss: 12.527, tensor([0.1540, 5.7130, 6.6590])
#
# 	 EPOCH 170, totalloss: 13.142, tensor([0.1060, 5.6110, 7.4250])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 171, totalloss: 12.627, tensor([0.0950, 5.4170, 7.1150])
#
# 	 EPOCH 172, totalloss: 12.332, tensor([0.1070, 5.3740, 6.8510])
#
# 	 EPOCH 173, totalloss: 12.051, tensor([0.1010, 5.2070, 6.7430])
#
# 	 EPOCH 174, totalloss: 12.075, tensor([0.0990, 5.4580, 6.5180])
#
# 	 EPOCH 175, totalloss: 11.52, tensor([0.0860, 4.9440, 6.4900])
#
# 	 EPOCH 176, totalloss: 11.892, tensor([0.0960, 5.1180, 6.6780])
#
# 	 EPOCH 177, totalloss: 11.906, tensor([0.0920, 5.1530, 6.6600])
#
# 	 EPOCH 178, totalloss: 12.364, tensor([0.0940, 5.4070, 6.8620])
#
# 	 EPOCH 179, totalloss: 12.703, tensor([0.0930, 5.3750, 7.2350])
#
# 	 EPOCH 180, totalloss: 12.313, tensor([0.0970, 5.3130, 6.9030])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 181, totalloss: 12.42, tensor([0.1030, 5.4200, 6.8960])
#
# 	 EPOCH 182, totalloss: 12.422, tensor([0.0950, 5.2870, 7.0400])
#
# 	 EPOCH 183, totalloss: 13.405, tensor([0.1120, 5.9790, 7.3140])
#
# 	 EPOCH 184, totalloss: 12.143, tensor([0.1090, 5.2880, 6.7460])
#
# 	 EPOCH 185, totalloss: 11.753, tensor([0.1050, 5.0890, 6.5590])
#
# 	 EPOCH 186, totalloss: 12.577, tensor([0.1030, 5.5370, 6.9360])
#
# 	 EPOCH 187, totalloss: 12.634, tensor([0.0930, 5.4770, 7.0630])
#
# 	 EPOCH 188, totalloss: 11.816, tensor([0.0860, 4.9050, 6.8250])
#
# 	 EPOCH 189, totalloss: 11.858, tensor([0.0890, 5.1420, 6.6270])
#
# 	 EPOCH 190, totalloss: 11.674, tensor([0.0890, 4.9940, 6.5910])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 191, totalloss: 12.096, tensor([0.0900, 5.2480, 6.7590])
#
# 	 EPOCH 192, totalloss: 11.973, tensor([0.0890, 5.1990, 6.6850])
#
# 	 EPOCH 193, totalloss: 12.368, tensor([0.1160, 5.5010, 6.7510])
#
# 	 EPOCH 194, totalloss: 12.106, tensor([0.0930, 5.3100, 6.7040])
#
# 	 EPOCH 195, totalloss: 11.782, tensor([0.1000, 4.9380, 6.7440])
#
# 	 EPOCH 196, totalloss: 11.703, tensor([0.0910, 5.0190, 6.5930])
#
# 	 EPOCH 197, totalloss: 11.894, tensor([0.0840, 5.1230, 6.6870])
#
# 	 EPOCH 198, totalloss: 12.482, tensor([0.1000, 5.3740, 7.0080])
#
# 	 EPOCH 199, totalloss: 11.6, tensor([0.1010, 4.8980, 6.6010])
#
# 	 EPOCH 200, totalloss: 12.172, tensor([0.0990, 5.3570, 6.7150])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 201, totalloss: 11.399, tensor([0.0930, 4.7800, 6.5260])
#
# 	 EPOCH 202, totalloss: 11.776, tensor([0.0970, 5.0250, 6.6540])
#
# 	 EPOCH 203, totalloss: 11.025, tensor([0.0910, 4.6330, 6.3010])
#
# 	 EPOCH 204, totalloss: 11.719, tensor([0.0850, 5.0910, 6.5430])
#
# 	 EPOCH 205, totalloss: 11.67, tensor([0.0810, 5.0400, 6.5490])
#
# 	 EPOCH 206, totalloss: 12.009, tensor([0.0880, 5.1760, 6.7450])
#
# 	 EPOCH 207, totalloss: 13.443, tensor([0.1580, 5.8030, 7.4820])
#
# 	 EPOCH 208, totalloss: 13.204, tensor([0.0980, 6.0160, 7.0900])
#
# 	 EPOCH 209, totalloss: 11.924, tensor([0.1000, 5.2160, 6.6080])
#
# 	 EPOCH 210, totalloss: 11.586, tensor([0.0970, 5.0700, 6.4190])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 211, totalloss: 11.771, tensor([0.1040, 5.0550, 6.6130])
#
# 	 EPOCH 212, totalloss: 10.973, tensor([0.0940, 4.5910, 6.2880])
#
# 	 EPOCH 213, totalloss: 10.817, tensor([0.0840, 4.5310, 6.2020])
#
# 	 EPOCH 214, totalloss: 11.713, tensor([0.0860, 5.0730, 6.5540])
#
# 	 EPOCH 215, totalloss: 11.426, tensor([0.0870, 4.7030, 6.6360])
#
# 	 EPOCH 216, totalloss: 12.427, tensor([0.1010, 5.5020, 6.8240])
#
# 	 EPOCH 217, totalloss: 11.655, tensor([0.0860, 5.2480, 6.3210])
#
# 	 EPOCH 218, totalloss: 11.543, tensor([0.0970, 4.7310, 6.7160])
#
# 	 EPOCH 219, totalloss: 11.153, tensor([0.0920, 4.6620, 6.3990])
#
# 	 EPOCH 220, totalloss: 11.646, tensor([0.0960, 5.1150, 6.4350])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 221, totalloss: 11.489, tensor([0.0810, 4.8090, 6.5990])
#
# 	 EPOCH 222, totalloss: 11.785, tensor([0.0880, 5.1210, 6.5760])
#
# 	 EPOCH 223, totalloss: 10.959, tensor([0.0850, 4.7530, 6.1210])
#
# 	 EPOCH 224, totalloss: 11.223, tensor([0.0810, 4.8660, 6.2760])
#
# 	 EPOCH 225, totalloss: 10.338, tensor([0.0890, 4.3400, 5.9090])
#
# 	 EPOCH 226, totalloss: 11.607, tensor([0.0850, 5.1320, 6.3900])
#
# 	 EPOCH 227, totalloss: 11.198, tensor([0.0850, 4.7290, 6.3840])
#
# 	 EPOCH 228, totalloss: 10.938, tensor([0.0880, 4.5440, 6.3060])
#
# 	 EPOCH 229, totalloss: 11.379, tensor([0.0840, 4.8480, 6.4470])
#
# 	 EPOCH 230, totalloss: 11.302, tensor([0.0830, 4.7240, 6.4950])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
# 	 EPOCH 231, totalloss: 10.958, tensor([0.0800, 4.7260, 6.1510])
#
# 	 EPOCH 232, totalloss: 10.87, tensor([0.0870, 4.5340, 6.2490])
#
# 	 EPOCH 233, totalloss: 10.467, tensor([0.0840, 4.2120, 6.1710])
#
# 	 EPOCH 234, totalloss: 11.04, tensor([0.1030, 4.6780, 6.2590])
#
# 	 EPOCH 235, totalloss: 11.731, tensor([0.0820, 4.8980, 6.7520])
#
# 	 EPOCH 236, totalloss: 11.149, tensor([0.0780, 4.8660, 6.2040])
#
# 	 EPOCH 237, totalloss: 10.987, tensor([0.0850, 4.7890, 6.1130])
#
# 	 EPOCH 238, totalloss: 11.377, tensor([0.0810, 4.9750, 6.3220])
#
# 	 EPOCH 239, totalloss: 10.684, tensor([0.1030, 4.5020, 6.0790])
#
# 	 EPOCH 240, totalloss: 11.051, tensor([0.0900, 4.8700, 6.0910])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 241, totalloss: 11.55, tensor([0.1020, 4.9090, 6.5390])
#
# 	 EPOCH 242, totalloss: 11.013, tensor([0.0810, 4.7680, 6.1640])
#
# 	 EPOCH 243, totalloss: 10.463, tensor([0.0780, 4.2770, 6.1080])
#
# 	 EPOCH 244, totalloss: 11.416, tensor([0.0790, 4.9020, 6.4360])
#
# 	 EPOCH 245, totalloss: 12.057, tensor([0.1020, 5.2490, 6.7050])
#
# 	 EPOCH 246, totalloss: 10.794, tensor([0.0920, 4.6480, 6.0530])
#
# 	 EPOCH 247, totalloss: 11.302, tensor([0.1170, 4.6620, 6.5230])
#
# 	 EPOCH 248, totalloss: 11.393, tensor([0.0890, 4.7930, 6.5110])
#
# 	 EPOCH 249, totalloss: 10.967, tensor([0.0790, 4.6160, 6.2720])
#
# 	 EPOCH 250, totalloss: 10.685, tensor([0.1160, 4.6430, 5.9260])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 251, totalloss: 11.533, tensor([0.1050, 4.7270, 6.7010])
#
# 	 EPOCH 252, totalloss: 9.885, tensor([0.0840, 4.2290, 5.5710])
#
# 	 EPOCH 253, totalloss: 10.107, tensor([0.0780, 4.3490, 5.6800])
#
# 	 EPOCH 254, totalloss: 11.132, tensor([0.0900, 4.8050, 6.2370])
#
# 	 EPOCH 255, totalloss: 10.295, tensor([0.0720, 4.4570, 5.7660])
#
# 	 EPOCH 256, totalloss: 10.318, tensor([0.0830, 4.2740, 5.9600])
#
# 	 EPOCH 257, totalloss: 11.057, tensor([0.0850, 4.7320, 6.2400])
#
# 	 EPOCH 258, totalloss: 10.403, tensor([0.0780, 4.1770, 6.1480])
#
# 	 EPOCH 259, totalloss: 10.339, tensor([0.0710, 4.4780, 5.7900])
#
# 	 EPOCH 260, totalloss: 10.295, tensor([0.0820, 4.4460, 5.7670])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 261, totalloss: 10.772, tensor([0.1060, 4.7690, 5.8970])
#
# 	 EPOCH 262, totalloss: 10.236, tensor([0.0820, 4.3140, 5.8400])
#
# 	 EPOCH 263, totalloss: 10.82, tensor([0.0840, 4.4000, 6.3360])
#
# 	 EPOCH 264, totalloss: 10.832, tensor([0.0840, 4.5790, 6.1690])
#
# 	 EPOCH 265, totalloss: 10.447, tensor([0.0690, 4.5300, 5.8480])
#
# 	 EPOCH 266, totalloss: 11.218, tensor([0.0750, 4.9110, 6.2320])
#
# 	 EPOCH 267, totalloss: 11.941, tensor([0.0760, 5.1340, 6.7310])
#
# 	 EPOCH 268, totalloss: 10.899, tensor([0.0820, 4.5930, 6.2240])
#
# 	 EPOCH 269, totalloss: 10.635, tensor([0.0730, 4.4730, 6.0890])
#
# 	 EPOCH 270, totalloss: 10.573, tensor([0.0780, 4.7180, 5.7780])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 271, totalloss: 9.927, tensor([0.0950, 4.1240, 5.7090])
#
# 	 EPOCH 272, totalloss: 10.023, tensor([0.0790, 3.9900, 5.9550])
#
# 	 EPOCH 273, totalloss: 10.042, tensor([0.0710, 4.2720, 5.6990])
#
# 	 EPOCH 274, totalloss: 10.783, tensor([0.0670, 4.8030, 5.9130])
#
# 	 EPOCH 275, totalloss: 10.768, tensor([0.0850, 4.7420, 5.9410])
#
# 	 EPOCH 276, totalloss: 10.504, tensor([0.1110, 4.3330, 6.0600])
#
# 	 EPOCH 277, totalloss: 10.078, tensor([0.0740, 4.2930, 5.7120])
#
# 	 EPOCH 278, totalloss: 10.426, tensor([0.0860, 4.4270, 5.9130])
#
# 	 EPOCH 279, totalloss: 10.699, tensor([0.0750, 4.6510, 5.9730])
#
# 	 EPOCH 280, totalloss: 10.349, tensor([0.0870, 4.3260, 5.9360])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 281, totalloss: 10.459, tensor([0.0730, 4.3470, 6.0380])
#
# 	 EPOCH 282, totalloss: 10.116, tensor([0.0780, 4.1980, 5.8390])
#
# 	 EPOCH 283, totalloss: 10.38, tensor([0.0710, 4.3680, 5.9410])
#
# 	 EPOCH 284, totalloss: 10.512, tensor([0.0780, 4.5230, 5.9120])
#
# 	 EPOCH 285, totalloss: 10.751, tensor([0.0720, 4.5740, 6.1050])
#
# 	 EPOCH 286, totalloss: 10.296, tensor([0.0790, 4.5440, 5.6740])
#
# 	 EPOCH 287, totalloss: 9.724, tensor([0.0830, 4.0920, 5.5490])
#
# 	 EPOCH 288, totalloss: 10.588, tensor([0.0830, 4.5320, 5.9740])
#
# 	 EPOCH 289, totalloss: 11.378, tensor([0.0860, 4.8530, 6.4380])
#
# 	 EPOCH 290, totalloss: 10.469, tensor([0.0780, 4.3630, 6.0290])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 291, totalloss: 11.04, tensor([0.0800, 4.7610, 6.1990])
#
# 	 EPOCH 292, totalloss: 10.141, tensor([0.0940, 4.2480, 5.7990])
#
# 	 EPOCH 293, totalloss: 11.807, tensor([0.0870, 5.2130, 6.5070])
#
# 	 EPOCH 294, totalloss: 9.776, tensor([0.0720, 4.1850, 5.5190])
#
# 	 EPOCH 295, totalloss: 10.431, tensor([0.0660, 4.2860, 6.0780])
#
# 	 EPOCH 296, totalloss: 10.388, tensor([0.0630, 4.3710, 5.9540])
#
# 	 EPOCH 297, totalloss: 10.768, tensor([0.0790, 4.5410, 6.1470])
#
# 	 EPOCH 298, totalloss: 11.049, tensor([0.0870, 4.8560, 6.1060])
#
# 	 EPOCH 299, totalloss: 10.515, tensor([0.0980, 4.3810, 6.0350])
#
# 	 EPOCH 300, totalloss: 10.848, tensor([0.1150, 4.5990, 6.1340])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 301, totalloss: 11.432, tensor([0.0790, 4.9780, 6.3750])
#
# 	 EPOCH 302, totalloss: 9.961, tensor([0.0770, 4.1550, 5.7290])
#
# 	 EPOCH 303, totalloss: 9.944, tensor([0.0720, 4.3070, 5.5650])
#
# 	 EPOCH 304, totalloss: 10.875, tensor([0.0850, 4.6240, 6.1660])
#
# 	 EPOCH 305, totalloss: 10.108, tensor([0.0830, 4.4000, 5.6250])
#
# 	 EPOCH 306, totalloss: 10.227, tensor([0.0700, 4.3360, 5.8200])
#
# 	 EPOCH 307, totalloss: 9.585, tensor([0.0730, 4.0490, 5.4630])
#
# 	 EPOCH 308, totalloss: 10.35, tensor([0.0770, 4.3920, 5.8810])
#
# 	 EPOCH 309, totalloss: 9.716, tensor([0.0780, 3.9380, 5.7000])
#
# 	 EPOCH 310, totalloss: 10.869, tensor([0.0910, 4.8100, 5.9680])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 311, totalloss: 9.857, tensor([0.0700, 4.1450, 5.6410])
#
# 	 EPOCH 312, totalloss: 11.129, tensor([0.0810, 4.7800, 6.2690])
# 	 EPOCH 313, totalloss: 9.537, tensor([0.0700, 3.9500, 5.5170])
#
# 	 EPOCH 314, totalloss: 10.043, tensor([0.0900, 4.1880, 5.7650])
#
# 	 EPOCH 315, totalloss: 10.343, tensor([0.0740, 4.5850, 5.6840])
#
# 	 EPOCH 316, totalloss: 9.5, tensor([0.0620, 4.3500, 5.0880])
#
# 	 EPOCH 317, totalloss: 9.857, tensor([0.0910, 4.1940, 5.5710])
#
# 	 EPOCH 318, totalloss: 10.556, tensor([0.0700, 4.6320, 5.8550])
#
# 	 EPOCH 319, totalloss: 10.133, tensor([0.0650, 4.5400, 5.5280])
#
# 	 EPOCH 320, totalloss: 9.893, tensor([0.0740, 4.2490, 5.5700])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 321, totalloss: 9.766, tensor([0.0730, 4.2360, 5.4570])
#
# 	 EPOCH 322, totalloss: 9.968, tensor([0.0810, 4.2120, 5.6740])
#
# 	 EPOCH 323, totalloss: 9.862, tensor([0.0640, 4.2240, 5.5740])
#
# 	 EPOCH 324, totalloss: 9.755, tensor([0.0640, 4.0590, 5.6310])
#
# 	 EPOCH 325, totalloss: 9.196, tensor([0.0600, 3.8300, 5.3060])
#
# 	 EPOCH 326, totalloss: 9.43, tensor([0.0850, 4.0510, 5.2940])
#
# 	 EPOCH 327, totalloss: 11.04, tensor([0.0550, 4.7420, 6.2430])
#
# 	 EPOCH 328, totalloss: 11.318, tensor([0.0830, 5.0330, 6.2020])
#
# 	 EPOCH 329, totalloss: 9.513, tensor([0.0700, 3.9890, 5.4550])
#
# 	 EPOCH 330, totalloss: 10.603, tensor([0.0610, 4.7440, 5.7980])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 331, totalloss: 9.301, tensor([0.0730, 3.8410, 5.3870])
#
# 	 EPOCH 332, totalloss: 9.855, tensor([0.0770, 3.9830, 5.7960])
#
# 	 EPOCH 333, totalloss: 9.666, tensor([0.0580, 4.0530, 5.5540])
#
# 	 EPOCH 334, totalloss: 9.51, tensor([0.0790, 3.8420, 5.5890])
#
# 	 EPOCH 335, totalloss: 10.215, tensor([0.0750, 4.4320, 5.7070])
#
# 	 EPOCH 336, totalloss: 9.51, tensor([0.0680, 4.0400, 5.4020])
#
# 	 EPOCH 337, totalloss: 9.223, tensor([0.0670, 4.0030, 5.1530])
#
# 	 EPOCH 338, totalloss: 10.378, tensor([0.0930, 4.3050, 5.9810])
#
# 	 EPOCH 339, totalloss: 10.698, tensor([0.0740, 4.4990, 6.1250])
#
# 	 EPOCH 340, totalloss: 9.003, tensor([0.0720, 3.8160, 5.1160])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 341, totalloss: 9.624, tensor([0.0740, 4.0770, 5.4730])
#
# 	 EPOCH 342, totalloss: 9.756, tensor([0.0760, 4.1320, 5.5480])
#
# 	 EPOCH 343, totalloss: 9.34, tensor([0.0620, 3.9770, 5.3020])
#
# 	 EPOCH 344, totalloss: 9.014, tensor([0.0770, 3.6260, 5.3110])
#
# 	 EPOCH 345, totalloss: 9.426, tensor([0.0530, 3.7530, 5.6190])
#
# 	 EPOCH 346, totalloss: 9.833, tensor([0.0650, 3.9660, 5.8010])
#
# 	 EPOCH 347, totalloss: 10.818, tensor([0.0600, 4.4900, 6.2680])
#
# 	 EPOCH 348, totalloss: 10.565, tensor([0.0630, 4.6020, 5.9000])
#
# 	 EPOCH 349, totalloss: 10.016, tensor([0.0590, 4.4940, 5.4630])
#
# 	 EPOCH 350, totalloss: 9.287, tensor([0.0780, 3.8900, 5.3190])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 351, totalloss: 8.759, tensor([0.0580, 3.7520, 4.9490])
#
# 	 EPOCH 352, totalloss: 9.651, tensor([0.0610, 4.1630, 5.4270])
#
# 	 EPOCH 353, totalloss: 10.454, tensor([0.0710, 4.3170, 6.0660])
#
# 	 EPOCH 354, totalloss: 10.351, tensor([0.0790, 4.3070, 5.9650])
#
# 	 EPOCH 355, totalloss: 9.702, tensor([0.0740, 4.0960, 5.5320])
#
# 	 EPOCH 356, totalloss: 10.051, tensor([0.0640, 4.2030, 5.7840])
#
# 	 EPOCH 357, totalloss: 9.648, tensor([0.0670, 4.0090, 5.5720])
#
# 	 EPOCH 358, totalloss: 9.213, tensor([0.0720, 3.8770, 5.2640])
#
# 	 EPOCH 359, totalloss: 10.94, tensor([0.0730, 4.4960, 6.3720])
#
# 	 EPOCH 360, totalloss: 10.539, tensor([0.0760, 4.5610, 5.9020])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 361, totalloss: 10.257, tensor([0.0690, 4.6780, 5.5100])
#
# 	 EPOCH 362, totalloss: 9.501, tensor([0.0700, 4.2200, 5.2110])
#
# 	 EPOCH 363, totalloss: 8.771, tensor([0.0590, 3.7880, 4.9240])
#
# 	 EPOCH 364, totalloss: 9.264, tensor([0.0610, 3.7510, 5.4520])
#
# 	 EPOCH 365, totalloss: 9.494, tensor([0.0760, 4.2390, 5.1780])
#
# 	 EPOCH 366, totalloss: 8.977, tensor([0.0580, 3.9230, 4.9960])
#
# 	 EPOCH 367, totalloss: 8.964, tensor([0.0540, 3.8020, 5.1080])
#
# 	 EPOCH 368, totalloss: 10.29, tensor([0.0580, 4.5090, 5.7230])
#
# 	 EPOCH 369, totalloss: 8.997, tensor([0.0690, 3.8190, 5.1090])
#
# 	 EPOCH 370, totalloss: 9.031, tensor([0.0580, 3.6800, 5.2940])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 78 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 371, totalloss: 9.829, tensor([0.0640, 4.2850, 5.4800])
#
# 	 EPOCH 372, totalloss: 10.715, tensor([0.0790, 4.7870, 5.8490])
#
# 	 EPOCH 373, totalloss: 9.725, tensor([0.0540, 4.1840, 5.4870])
#
# 	 EPOCH 374, totalloss: 9.782, tensor([0.0550, 4.3150, 5.4120])
#
# 	 EPOCH 375, totalloss: 10.832, tensor([0.0760, 5.0170, 5.7380])
#
# 	 EPOCH 376, totalloss: 9.483, tensor([0.0550, 4.1560, 5.2730])
#
# 	 EPOCH 377, totalloss: 9.607, tensor([0.0670, 4.1050, 5.4340])
#
# 	 EPOCH 378, totalloss: 9.862, tensor([0.0690, 4.2680, 5.5240])
#
# 	 EPOCH 379, totalloss: 9.817, tensor([0.0690, 4.3490, 5.3980])
#
# 	 EPOCH 380, totalloss: 8.958, tensor([0.0670, 3.7760, 5.1150])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 94 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 381, totalloss: 8.9, tensor([0.0580, 3.7060, 5.1360])
#
# 	 EPOCH 382, totalloss: 9.216, tensor([0.0500, 3.9020, 5.2630])
#
# 	 EPOCH 383, totalloss: 8.845, tensor([0.0590, 3.6530, 5.1330])
#
# 	 EPOCH 384, totalloss: 8.518, tensor([0.0530, 3.5330, 4.9330])
#
# 	 EPOCH 385, totalloss: 9.487, tensor([0.0560, 4.0870, 5.3430])
#
# 	 EPOCH 386, totalloss: 11.019, tensor([0.0650, 4.6540, 6.3000])
#
# 	 EPOCH 387, totalloss: 9.518, tensor([0.0560, 4.0410, 5.4210])
#
# 	 EPOCH 388, totalloss: 9.336, tensor([0.0570, 3.9590, 5.3200])
#
# 	 EPOCH 389, totalloss: 9.428, tensor([0.0560, 3.9950, 5.3780])
#
# 	 EPOCH 390, totalloss: 8.865, tensor([0.0620, 3.8380, 4.9650])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 391, totalloss: 9.116, tensor([0.0600, 4.0060, 5.0500])
#
# 	 EPOCH 392, totalloss: 8.622, tensor([0.0630, 3.5540, 5.0050])
#
# 	 EPOCH 393, totalloss: 10.507, tensor([0.0570, 4.5550, 5.8950])
#
# 	 EPOCH 394, totalloss: 9.294, tensor([0.0790, 3.9730, 5.2430])
#
# 	 EPOCH 395, totalloss: 9.586, tensor([0.0610, 3.9540, 5.5710])
# 	 EPOCH 396, totalloss: 8.834, tensor([0.0500, 3.8240, 4.9600])
#
# 	 EPOCH 397, totalloss: 8.585, tensor([0.0500, 3.6790, 4.8560])
#
# 	 EPOCH 398, totalloss: 8.795, tensor([0.0520, 3.5440, 5.1990])
#
# 	 EPOCH 399, totalloss: 9.596, tensor([0.0550, 4.1750, 5.3650])
#
# 	 EPOCH 400, totalloss: 9.485, tensor([0.0460, 4.1470, 5.2920])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 401, totalloss: 10.333, tensor([0.0800, 4.0360, 6.2170])
#
# 	 EPOCH 402, totalloss: 8.613, tensor([0.0620, 3.6180, 4.9330])
#
# 	 EPOCH 403, totalloss: 9.287, tensor([0.0740, 3.8520, 5.3610])
#
# 	 EPOCH 404, totalloss: 9.186, tensor([0.0770, 3.9460, 5.1630])
#
# 	 EPOCH 405, totalloss: 9.426, tensor([0.0580, 3.8520, 5.5160])
#
# 	 EPOCH 406, totalloss: 9.346, tensor([0.0710, 4.0720, 5.2030])
#
# 	 EPOCH 407, totalloss: 9.348, tensor([0.0700, 4.0410, 5.2370])
#
# 	 EPOCH 408, totalloss: 8.823, tensor([0.0500, 3.6360, 5.1360])
#
# 	 EPOCH 409, totalloss: 9.343, tensor([0.0540, 3.8380, 5.4520])
#
# 	 EPOCH 410, totalloss: 8.872, tensor([0.0450, 3.7200, 5.1070])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 411, totalloss: 8.602, tensor([0.0510, 3.5450, 5.0050])
#
# 	 EPOCH 412, totalloss: 9.068, tensor([0.0620, 3.6330, 5.3730])
#
# 	 EPOCH 413, totalloss: 8.857, tensor([0.0690, 3.7420, 5.0460])
#
# 	 EPOCH 414, totalloss: 8.871, tensor([0.0590, 3.7490, 5.0630])
#
# 	 EPOCH 415, totalloss: 9.433, tensor([0.0640, 4.0580, 5.3100])
#
# 	 EPOCH 416, totalloss: 10.068, tensor([0.0520, 4.5650, 5.4510])
#
# 	 EPOCH 417, totalloss: 8.871, tensor([0.0460, 3.7440, 5.0810])
#
# 	 EPOCH 418, totalloss: 11.049, tensor([0.0950, 4.6910, 6.2630])
#
# 	 EPOCH 419, totalloss: 8.866, tensor([0.0480, 3.7710, 5.0480])
#
# 	 EPOCH 420, totalloss: 9.464, tensor([0.0640, 3.9860, 5.4140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 421, totalloss: 9.858, tensor([0.0640, 4.2630, 5.5310])
#
# 	 EPOCH 422, totalloss: 8.75, tensor([0.0610, 3.7380, 4.9510])
#
# 	 EPOCH 423, totalloss: 9.295, tensor([0.0680, 3.9090, 5.3180])
#
# 	 EPOCH 424, totalloss: 8.896, tensor([0.0390, 3.7360, 5.1210])
# ^C
# Exception ignored in: <function _releaseLock at 0x7fda4c852c10>
# Traceback (most recent call last):
#   File "/root/miniconda/lib/python3.8/logging/__init__.py", line 223, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:

# %%
## train on single task: aesthetics
# !CUDA_VISIBLE_DEVICES=2 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singletask_aesthetics.yml"

# %%
## test pretrained network
# !python test_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_test.yml"

# %%
## run the optimization framework; hit 'shift+enter' keys to run
## IMPORTANT INFO about running the acoustic optimization script:
## The Command Format for this script: 
## bash run_acousticoptim.sh INPUT_MESH SILHOUETTE_DEFORM_FLAG SILHOUETTE_REF_IMG ACOUSTIC_DEFORM_FLAG WHICH_ACOUSTIC_PARAMS OUTPUT_NAME
## where `INPUT_MESH_FILEPATH` is the absolute filepath of the mesh you would like to deform
##       `TRAINED_GRAPH_FILEPATH` is the filepath to the trained mesh2aesthetic graph convolutional neural network
##       `STYLE_PARAM` is either 'baroque', 'modern', or 'classic' 
##       `SEM_PARAM`  is either 'house' or 'column'
##       `FUNC_PARAM` is an integer number from [1,2,3,4], where 1 is low functionality and 4 is high functionality
##       `AESTH_PARAM` is an integer number from [1,2,3,4], where 1 is poor aesthetics and 5 is good aesthetics 
##       `OUTPUT_FILENAME` is the absolute filepath where you would like the deformed output mesh to be saved.
##       `NUM_ITERS` is the number of iterations to run the optimization.
##       `CFG_FILE` is the absolute path to the configuration file. You will need to change this to the config file path that you used for training the model (see above cell)
##
## Example Command:
#!cd /storage/concerthall && bash run_acousticoptim.sh \
#                            INPUT_MESH_FILEPATH \
#                            TRAINED_GRAPH_FILEPATH \
#                            STYLE_PARAM \
#                            SEM_PARAM \
#                            FUNC_PARAM \
#                            AESTH_PARAM \
#                            OUTPUT_FILENAME \
#                            NUM_ITERS \
#                            CFG_FILE
#
# !cd /storage/acadia2020_graphcnn && bash run_param_optim.sh \
                            "/storage/3Dmodels/bench.obj" \
                            "/storage/acadia2020_graphcnn_training_results/exp_09_26_14_01_06_ai_aesthetics_optim/model_best_loss.pkl" \
                            "modern" \
                            "house" \
                            4 \
                            5 \
                            "test_sil_deform.obj" \
                            250 \
                            "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
