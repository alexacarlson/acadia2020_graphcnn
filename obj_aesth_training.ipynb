# %%
## install the pytorch3d package; hit 'shift+enter' keys to run
# !conda create --name pytorch3d --yes
# !conda activate pytorch3d
# !python3 -m pip install --upgrade numpy
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch --yes
# !conda install -c conda-forge -c takatosp1 fvcore --yes
# !conda install pytorch3d -c pytorch3d --yes
# !python3 -m pip install tqdm pandas scipy opencv-python 
# !python3 -m pip install --upgrade matplotlib --ignore-installed certifi

# %%
# !apt-get update
# !apt update && apt install -y libsm6 libxext6
# !apt-get install -y libxrender-dev
# !apt-get install ffmpeg libsm6 libxext6  -y
# !pip install opencv-python
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 120 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 120 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libxrender-dev is already the newest version (1:0.9.10-1).
# 0 upgraded, 0 newly installed, 0 to remove and 120 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.2-1).
# libxext6 is already the newest version (2:1.3.3-1).
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 120 not upgraded.
# Requirement already satisfied: opencv-python in /root/miniconda/lib/python3.8/site-packages (4.4.0.46)
# Requirement already satisfied: numpy>=1.17.3 in /root/miniconda/lib/python3.8/site-packages (from opencv-python) (1.19.2)

# %%
# !python make_methodsFig1_dataset.py
# Out:
# getting config
# getting dataset list
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# getting dataset loader
# getting dataset split
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# rendering 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
## download the concerthall optimization code base; hit 'shift+enter' keys to run
#!rm -rf /storage/acadia2020_graphcnn
#!git clone https://github.com/alexacarlson/acadia2020_graphcnn.git /storage/acadia2020_graphcnn

## check size of dataset/verts etc
# !python check_dataset.py

# %%
## Train the graph convolutional neural network; hit 'shift+enter' keys to run
## NOTES on Training the Graph Convolutional Neural network to map 3D meshes --> aesthetic and functionality parameters:
## To train your own graph convolutional network, you first need to create a folder in paperspace storage 
## at `/storage/concert_dataset` upload your data there. All of your meshes should be `.obj` files and
## should exist in a subdirectory of the dataset: `/storage/acadia2020_graphcnn_dataset/Separated/`. 
## You will need to have a csv file of label/parameters (where each line is in the format `mesh.obj label1 label2 ... label10`) 
## located at and named `/storage/acadia2020_graphcnn_dataset/NamingBookV2.csv`.
## The results (network weights and training loss values) will be saved to `/storage/acadia2020_graphcnn_training_results`.
##
## Note that this function takes in the absolute filepath of a configuration file (CFG_PATH) that sets up the network architecture.
## ## To train on 4 labels:
#!cd /storage/acadia2020_graphcnn && bash run_train_graphconv_regression.sh "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
#!cd /tf/notebooks/acadia2020_graphcnn_src && bash run_train_graphconv_regression.sh "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"

#!CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"
# !CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train3.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: all
#   WHICH_TASK: all
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf3
# OPTIM:
#   BATCH_SIZE: 32
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 1000
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_24_13_36_09_ai_aesthetics_optim_centered_bs32_lr2e-4_hd128_256_512_alltasks_nettype-GraphConvClf3_class-all
#   full_experiment_name: exp_11_24_13_36_09_ai_aesthetics_optim_centered_bs32_lr2e-4_hd128_256_512_alltasks_nettype-GraphConvClf3_class-all
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train3.yml
# config_override     : []
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# number of training samples: 2076
# Training Samples: 65
# Validation Samples: 100
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 29.896, tensor([8.7700e-01, 6.0000e-03, 1.3273e+01, 1.5740e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 69 %
# Accuracy of the network on validation model set SEMANTIC: 76 %
# Accuracy of the network on validation model set FUNCTIONALITY: 39 %
# Accuracy of the network on validation model set AESTHETICS: 27 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 29.028, tensor([8.2400e-01, 6.0000e-03, 1.2806e+01, 1.5392e+01])
#
# 	 EPOCH 2, totalloss: 28.521, tensor([7.9300e-01, 5.0000e-03, 1.2513e+01, 1.5211e+01])
#
# 	 EPOCH 3, totalloss: 27.989, tensor([7.7500e-01, 4.0000e-03, 1.2296e+01, 1.4913e+01])
#
# 	 EPOCH 4, totalloss: 27.679, tensor([7.5100e-01, 3.0000e-03, 1.2205e+01, 1.4720e+01])
#
# 	 EPOCH 5, totalloss: 27.316, tensor([7.2300e-01, 3.0000e-03, 1.2000e+01, 1.4591e+01])
#
# 	 EPOCH 6, totalloss: 26.97, tensor([6.9100e-01, 2.0000e-03, 1.1916e+01, 1.4361e+01])
#
# 	 EPOCH 7, totalloss: 26.751, tensor([6.7200e-01, 2.0000e-03, 1.1769e+01, 1.4309e+01])
#
# 	 EPOCH 8, totalloss: 26.299, tensor([6.4200e-01, 2.0000e-03, 1.1458e+01, 1.4197e+01])
#
# 	 EPOCH 9, totalloss: 25.703, tensor([6.0200e-01, 2.0000e-03, 1.1211e+01, 1.3889e+01])
#
# 	 EPOCH 10, totalloss: 25.224, tensor([5.8500e-01, 2.0000e-03, 1.1010e+01, 1.3626e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 79 %
# Accuracy of the network on validation model set SEMANTIC: 89 %
# Accuracy of the network on validation model set FUNCTIONALITY: 51 %
# Accuracy of the network on validation model set AESTHETICS: 29 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 11, totalloss: 24.904, tensor([5.6500e-01, 2.0000e-03, 1.0880e+01, 1.3457e+01])
#
# 	 EPOCH 12, totalloss: 24.688, tensor([5.4900e-01, 2.0000e-03, 1.0789e+01, 1.3348e+01])
#
# 	 EPOCH 13, totalloss: 24.398, tensor([5.4300e-01, 2.0000e-03, 1.0774e+01, 1.3080e+01])
#
# 	 EPOCH 14, totalloss: 23.802, tensor([5.1300e-01, 2.0000e-03, 1.0351e+01, 1.2937e+01])
#
# 	 EPOCH 15, totalloss: 24.323, tensor([5.3200e-01, 2.0000e-03, 1.0715e+01, 1.3074e+01])
#
# 	 EPOCH 16, totalloss: 23.329, tensor([4.8700e-01, 2.0000e-03, 1.0166e+01, 1.2674e+01])
#
# 	 EPOCH 17, totalloss: 23.351, tensor([5.0100e-01, 1.0000e-03, 1.0245e+01, 1.2604e+01])
#
# 	 EPOCH 18, totalloss: 23.104, tensor([4.8000e-01, 1.0000e-03, 1.0109e+01, 1.2514e+01])
#
# 	 EPOCH 19, totalloss: 22.93, tensor([4.6900e-01, 1.0000e-03, 9.9650e+00, 1.2495e+01])
#
# 	 EPOCH 20, totalloss: 22.491, tensor([4.4600e-01, 1.0000e-03, 9.9250e+00, 1.2118e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 85 %
# Accuracy of the network on validation model set SEMANTIC: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 52 %
# Accuracy of the network on validation model set AESTHETICS: 39 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 21, totalloss: 22.274, tensor([4.4700e-01, 1.0000e-03, 9.7020e+00, 1.2124e+01])
#
# 	 EPOCH 22, totalloss: 22.179, tensor([4.2900e-01, 1.0000e-03, 9.6210e+00, 1.2129e+01])
#
# 	 EPOCH 23, totalloss: 21.802, tensor([4.1400e-01, 1.0000e-03, 9.4690e+00, 1.1919e+01])
#
# 	 EPOCH 24, totalloss: 21.676, tensor([4.1000e-01, 1.0000e-03, 9.3310e+00, 1.1934e+01])
#
# 	 EPOCH 25, totalloss: 21.42, tensor([4.0500e-01, 1.0000e-03, 9.1840e+00, 1.1829e+01])
#
# 	 EPOCH 26, totalloss: 21.261, tensor([4.1000e-01, 1.0000e-03, 9.1840e+00, 1.1666e+01])
#
# 	 EPOCH 27, totalloss: 20.831, tensor([3.7500e-01, 1.0000e-03, 8.9580e+00, 1.1497e+01])
#
# 	 EPOCH 28, totalloss: 20.964, tensor([3.7700e-01, 1.0000e-03, 8.9770e+00, 1.1610e+01])
#
# 	 EPOCH 29, totalloss: 20.611, tensor([3.5500e-01, 1.0000e-03, 8.9070e+00, 1.1348e+01])
#
# 	 EPOCH 30, totalloss: 20.843, tensor([3.6600e-01, 1.0000e-03, 9.0170e+00, 1.1459e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 87 %
# Accuracy of the network on validation model set SEMANTIC: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 55 %
# Accuracy of the network on validation model set AESTHETICS: 38 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 31, totalloss: 20.4, tensor([3.4700e-01, 1.0000e-03, 8.7160e+00, 1.1335e+01])
#
# 	 EPOCH 32, totalloss: 20.378, tensor([3.4300e-01, 1.0000e-03, 8.7580e+00, 1.1276e+01])
#
# 	 EPOCH 33, totalloss: 20.089, tensor([3.3600e-01, 1.0000e-03, 8.5350e+00, 1.1218e+01])
#
# 	 EPOCH 34, totalloss: 20.132, tensor([ 0.3410,  0.0000,  8.7700, 11.0210])
#
# 	 EPOCH 35, totalloss: 19.952, tensor([3.1300e-01, 1.0000e-03, 8.5440e+00, 1.1094e+01])
#
# 	 EPOCH 36, totalloss: 19.929, tensor([ 0.3040,  0.0000,  8.5680, 11.0570])
#
# 	 EPOCH 37, totalloss: 19.6, tensor([ 0.3140,  0.0000,  8.3310, 10.9550])
#
# 	 EPOCH 38, totalloss: 19.562, tensor([ 0.3220,  0.0000,  8.4140, 10.8250])
#
# 	 EPOCH 39, totalloss: 19.105, tensor([ 0.2900,  0.0000,  8.2230, 10.5910])
#
# 	 EPOCH 40, totalloss: 19.297, tensor([2.9700e-01, 1.0000e-03, 8.2720e+00, 1.0727e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 88 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 56 %
# Accuracy of the network on validation model set AESTHETICS: 42 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 41, totalloss: 18.81, tensor([ 0.2770,  0.0000,  8.0670, 10.4650])
#
# 	 EPOCH 42, totalloss: 18.861, tensor([ 0.2910,  0.0000,  8.0830, 10.4880])
#
# 	 EPOCH 43, totalloss: 18.974, tensor([ 0.2850,  0.0000,  8.2680, 10.4190])
#
# 	 EPOCH 44, totalloss: 18.685, tensor([ 0.2610,  0.0000,  8.1650, 10.2580])
#
# 	 EPOCH 45, totalloss: 18.354, tensor([ 0.2620,  0.0000,  7.9260, 10.1650])
#
# 	 EPOCH 46, totalloss: 18.396, tensor([ 0.2430,  0.0000,  7.9260, 10.2260])
#
# 	 EPOCH 47, totalloss: 17.88, tensor([0.2410, 0.0000, 7.6630, 9.9760])
#
# 	 EPOCH 48, totalloss: 18.136, tensor([ 0.2450,  0.0000,  7.8770, 10.0140])
#
# 	 EPOCH 49, totalloss: 17.741, tensor([0.2360, 0.0000, 7.6750, 9.8300])
#
# 	 EPOCH 50, totalloss: 17.949, tensor([0.2190, 0.0000, 7.7420, 9.9880])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 50 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 51, totalloss: 17.766, tensor([0.2270, 0.0000, 7.6050, 9.9350])
#
# 	 EPOCH 52, totalloss: 17.662, tensor([0.2050, 0.0000, 7.6620, 9.7940])
#
# 	 EPOCH 53, totalloss: 17.385, tensor([0.2290, 0.0000, 7.5020, 9.6540])
# 	 EPOCH 54, totalloss: 17.373, tensor([0.2110, 0.0000, 7.5460, 9.6160])
#
# 	 EPOCH 55, totalloss: 17.957, tensor([0.2290, 0.0000, 7.8240, 9.9040])
#
# 	 EPOCH 56, totalloss: 17.188, tensor([0.2010, 0.0000, 7.5190, 9.4670])
#
# 	 EPOCH 57, totalloss: 17.05, tensor([0.1990, 0.0000, 7.4840, 9.3670])
#
# 	 EPOCH 58, totalloss: 17.046, tensor([0.1980, 0.0000, 7.2510, 9.5970])
#
# 	 EPOCH 59, totalloss: 16.704, tensor([0.1890, 0.0000, 7.1380, 9.3760])
#
# 	 EPOCH 60, totalloss: 16.849, tensor([0.1760, 0.0000, 7.3690, 9.3040])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 93 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 67 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 61, totalloss: 17.18, tensor([0.2030, 0.0000, 7.3680, 9.6090])
#
# 	 EPOCH 62, totalloss: 17.505, tensor([0.1880, 0.0000, 7.6820, 9.6350])
#
# 	 EPOCH 63, totalloss: 16.645, tensor([0.1570, 0.0000, 7.1580, 9.3300])
#
# 	 EPOCH 64, totalloss: 16.584, tensor([0.1830, 0.0000, 7.1760, 9.2250])
#
# 	 EPOCH 65, totalloss: 16.471, tensor([0.1880, 0.0000, 7.0620, 9.2210])
#
# 	 EPOCH 66, totalloss: 16.182, tensor([0.1640, 0.0000, 7.0240, 8.9940])
#
# 	 EPOCH 67, totalloss: 16.123, tensor([0.1600, 0.0000, 6.9710, 8.9920])
#
# 	 EPOCH 68, totalloss: 16.435, tensor([0.1860, 0.0000, 7.1160, 9.1330])
#
# 	 EPOCH 69, totalloss: 15.892, tensor([0.1540, 0.0000, 6.8790, 8.8600])
#
# 	 EPOCH 70, totalloss: 16.35, tensor([0.1510, 0.0000, 7.1300, 9.0680])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 92 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 44 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 71, totalloss: 16.266, tensor([0.1510, 0.0000, 7.0150, 9.1000])
#
# 	 EPOCH 72, totalloss: 15.719, tensor([0.1490, 0.0000, 6.7800, 8.7910])
#
# 	 EPOCH 73, totalloss: 15.95, tensor([0.1430, 0.0000, 6.9060, 8.9010])
#
# 	 EPOCH 74, totalloss: 15.524, tensor([0.1430, 0.0000, 6.6140, 8.7670])
#
# 	 EPOCH 75, totalloss: 15.574, tensor([0.1450, 0.0000, 6.7170, 8.7120])
#
# 	 EPOCH 76, totalloss: 15.4, tensor([0.1390, 0.0000, 6.6390, 8.6220])
#
# 	 EPOCH 77, totalloss: 15.32, tensor([0.1410, 0.0000, 6.6780, 8.5000])
#
# 	 EPOCH 78, totalloss: 15.998, tensor([0.1280, 0.0000, 6.8530, 9.0170])
#
# 	 EPOCH 79, totalloss: 15.799, tensor([0.1530, 0.0000, 6.8080, 8.8370])
#
# 	 EPOCH 80, totalloss: 15.05, tensor([0.1150, 0.0000, 6.5200, 8.4150])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 81, totalloss: 15.112, tensor([0.1180, 0.0000, 6.6350, 8.3590])
#
# 	 EPOCH 82, totalloss: 15.112, tensor([0.1250, 0.0000, 6.5310, 8.4560])
#
# 	 EPOCH 83, totalloss: 15.509, tensor([0.1220, 0.0000, 6.6940, 8.6930])
#
# 	 EPOCH 84, totalloss: 15.19, tensor([0.1220, 0.0000, 6.5840, 8.4830])
#
# 	 EPOCH 85, totalloss: 14.886, tensor([0.1120, 0.0000, 6.4110, 8.3640])
#
# 	 EPOCH 86, totalloss: 15.162, tensor([0.1240, 0.0000, 6.5550, 8.4830])
#
# 	 EPOCH 87, totalloss: 15.101, tensor([0.1180, 0.0000, 6.5500, 8.4330])
#
# 	 EPOCH 88, totalloss: 14.67, tensor([0.1100, 0.0000, 6.3650, 8.1950])
#
# 	 EPOCH 89, totalloss: 14.88, tensor([0.1140, 0.0000, 6.3470, 8.4200])
#
# 	 EPOCH 90, totalloss: 14.738, tensor([0.1230, 0.0000, 6.2400, 8.3750])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 64 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 91, totalloss: 14.649, tensor([0.1060, 0.0000, 6.2960, 8.2460])
#
# 	 EPOCH 92, totalloss: 14.339, tensor([0.1040, 0.0000, 6.1410, 8.0940])
#
# 	 EPOCH 93, totalloss: 14.418, tensor([0.1000, 0.0000, 6.2220, 8.0960])
#
# 	 EPOCH 94, totalloss: 14.97, tensor([0.0930, 0.0000, 6.6730, 8.2040])
#
# 	 EPOCH 95, totalloss: 14.62, tensor([0.1150, 0.0000, 6.1130, 8.3910])
#
# 	 EPOCH 96, totalloss: 14.473, tensor([0.0830, 0.0000, 6.3710, 8.0190])
#
# 	 EPOCH 97, totalloss: 14.671, tensor([0.0990, 0.0000, 6.3390, 8.2330])
#
# 	 EPOCH 98, totalloss: 14.172, tensor([0.0810, 0.0000, 6.0360, 8.0550])
#
# 	 EPOCH 99, totalloss: 14.249, tensor([0.1000, 0.0000, 6.1950, 7.9540])
#
# 	 EPOCH 100, totalloss: 14.046, tensor([0.0850, 0.0000, 6.1540, 7.8070])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 101, totalloss: 14.251, tensor([0.0860, 0.0000, 6.2120, 7.9530])
#
# 	 EPOCH 102, totalloss: 14.346, tensor([0.0890, 0.0000, 6.2300, 8.0260])
#
# 	 EPOCH 103, totalloss: 13.786, tensor([0.0760, 0.0000, 6.0030, 7.7060])
#
# 	 EPOCH 104, totalloss: 13.992, tensor([0.0880, 0.0000, 6.0360, 7.8690])
#
# 	 EPOCH 105, totalloss: 14.043, tensor([0.0820, 0.0000, 6.0340, 7.9270])
#
# 	 EPOCH 106, totalloss: 14.186, tensor([0.0960, 0.0000, 6.1480, 7.9420])
#
# 	 EPOCH 107, totalloss: 13.56, tensor([0.0860, 0.0000, 5.8660, 7.6080])
#
# 	 EPOCH 108, totalloss: 13.888, tensor([0.0740, 0.0000, 6.1170, 7.6970])
#
# 	 EPOCH 109, totalloss: 13.926, tensor([0.0860, 0.0000, 6.0300, 7.8100])
#
# 	 EPOCH 110, totalloss: 13.446, tensor([0.0700, 0.0000, 5.8900, 7.4860])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 67 %
# Accuracy of the network on validation model set AESTHETICS: 55 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 111, totalloss: 13.633, tensor([0.0890, 0.0000, 5.8070, 7.7370])
#
# 	 EPOCH 112, totalloss: 13.383, tensor([0.0720, 0.0000, 5.7320, 7.5780])
#
# 	 EPOCH 113, totalloss: 13.742, tensor([0.0820, 0.0000, 5.9030, 7.7580])
#
# 	 EPOCH 114, totalloss: 13.727, tensor([0.0950, 0.0000, 5.9990, 7.6330])
#
# 	 EPOCH 115, totalloss: 13.259, tensor([0.0720, 0.0000, 5.7120, 7.4750])
#
# 	 EPOCH 116, totalloss: 13.36, tensor([0.0780, 0.0000, 5.7600, 7.5210])
#
# 	 EPOCH 117, totalloss: 13.542, tensor([0.0750, 0.0000, 5.8870, 7.5800])
#
# 	 EPOCH 118, totalloss: 13.449, tensor([0.0680, 0.0000, 5.7370, 7.6440])
#
# 	 EPOCH 119, totalloss: 13.542, tensor([0.0830, 0.0000, 5.8310, 7.6280])
#
# 	 EPOCH 120, totalloss: 13.503, tensor([0.0720, 0.0000, 5.9250, 7.5060])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 121, totalloss: 13.136, tensor([0.0650, 0.0000, 5.7440, 7.3270])
#
# 	 EPOCH 122, totalloss: 13.287, tensor([0.0660, 0.0000, 5.8100, 7.4100])
#
# 	 EPOCH 123, totalloss: 13.551, tensor([0.0650, 0.0000, 5.8450, 7.6410])
#
# 	 EPOCH 124, totalloss: 13.148, tensor([0.0580, 0.0000, 5.6840, 7.4060])
#
# 	 EPOCH 125, totalloss: 12.805, tensor([0.0680, 0.0000, 5.6510, 7.0860])
# 	 EPOCH 126, totalloss: 13.233, tensor([0.0720, 0.0000, 5.6790, 7.4810])
#
# 	 EPOCH 127, totalloss: 12.774, tensor([0.0720, 0.0000, 5.5960, 7.1060])
#
# 	 EPOCH 128, totalloss: 12.804, tensor([0.0730, 0.0000, 5.5280, 7.2030])
#
# 	 EPOCH 129, totalloss: 12.847, tensor([0.0540, 0.0000, 5.6820, 7.1110])
#
# 	 EPOCH 130, totalloss: 13.004, tensor([0.0560, 0.0000, 5.6950, 7.2530])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 131, totalloss: 12.663, tensor([0.0500, 0.0000, 5.4290, 7.1840])
#
# 	 EPOCH 132, totalloss: 12.663, tensor([0.0590, 0.0000, 5.4470, 7.1570])
#
# 	 EPOCH 133, totalloss: 13.017, tensor([0.0590, 0.0000, 5.7250, 7.2330])
#
# 	 EPOCH 134, totalloss: 13.053, tensor([0.0560, 0.0000, 5.6330, 7.3640])
#
# 	 EPOCH 135, totalloss: 12.57, tensor([0.0710, 0.0000, 5.4490, 7.0500])
#
# 	 EPOCH 136, totalloss: 13.056, tensor([0.0580, 0.0000, 5.6850, 7.3120])
#
# 	 EPOCH 137, totalloss: 12.625, tensor([0.0620, 0.0000, 5.4550, 7.1080])
#
# 	 EPOCH 138, totalloss: 12.342, tensor([0.0500, 0.0000, 5.3260, 6.9660])
#
# 	 EPOCH 139, totalloss: 12.615, tensor([0.0520, 0.0000, 5.4930, 7.0710])
#
# 	 EPOCH 140, totalloss: 12.968, tensor([0.0600, 0.0000, 5.6560, 7.2520])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 141, totalloss: 12.655, tensor([0.0490, 0.0000, 5.4270, 7.1790])
#
# 	 EPOCH 142, totalloss: 12.193, tensor([0.0380, 0.0000, 5.3000, 6.8550])
#
# 	 EPOCH 143, totalloss: 12.404, tensor([0.0490, 0.0000, 5.4050, 6.9500])
#
# 	 EPOCH 144, totalloss: 12.51, tensor([0.0540, 0.0000, 5.5850, 6.8710])
#
# 	 EPOCH 145, totalloss: 12.498, tensor([0.0480, 0.0000, 5.3940, 7.0550])
#
# 	 EPOCH 146, totalloss: 12.341, tensor([0.0430, 0.0000, 5.3450, 6.9530])
#
# 	 EPOCH 147, totalloss: 12.771, tensor([0.0510, 0.0000, 5.3720, 7.3470])
#
# 	 EPOCH 148, totalloss: 12.636, tensor([0.0580, 0.0000, 5.4430, 7.1350])
#
# 	 EPOCH 149, totalloss: 12.777, tensor([0.0520, 0.0000, 5.6200, 7.1060])
#
# 	 EPOCH 150, totalloss: 12.107, tensor([0.0380, 0.0000, 5.3330, 6.7370])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 95 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 151, totalloss: 12.148, tensor([0.0390, 0.0000, 5.2750, 6.8340])
#
# 	 EPOCH 152, totalloss: 12.453, tensor([0.0600, 0.0000, 5.4910, 6.9030])
#
# 	 EPOCH 153, totalloss: 12.26, tensor([0.0430, 0.0000, 5.3850, 6.8320])
#
# 	 EPOCH 154, totalloss: 11.945, tensor([0.0370, 0.0000, 5.2400, 6.6680])
#
# 	 EPOCH 155, totalloss: 12.08, tensor([0.0560, 0.0000, 5.2830, 6.7410])
#
# 	 EPOCH 156, totalloss: 11.783, tensor([0.0480, 0.0000, 5.1070, 6.6280])
#
# 	 EPOCH 157, totalloss: 12.159, tensor([0.0440, 0.0000, 5.3810, 6.7340])
#
# 	 EPOCH 158, totalloss: 12.089, tensor([0.0370, 0.0000, 5.2180, 6.8340])
#
# 	 EPOCH 159, totalloss: 12.21, tensor([0.0390, 0.0000, 5.2610, 6.9090])
#
# 	 EPOCH 160, totalloss: 11.946, tensor([0.0410, 0.0000, 5.2410, 6.6640])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 161, totalloss: 12.151, tensor([0.0290, 0.0000, 5.2620, 6.8590])
#
# 	 EPOCH 162, totalloss: 12.468, tensor([0.0430, 0.0000, 5.4370, 6.9870])
#
# 	 EPOCH 163, totalloss: 12.162, tensor([0.0430, 0.0000, 5.2370, 6.8820])
#
# 	 EPOCH 164, totalloss: 12.011, tensor([0.0430, 0.0000, 5.1680, 6.8000])
#
# 	 EPOCH 165, totalloss: 12.187, tensor([0.0390, 0.0000, 5.2840, 6.8640])
#
# 	 EPOCH 166, totalloss: 11.804, tensor([0.0360, 0.0000, 5.1750, 6.5930])
#
# 	 EPOCH 167, totalloss: 11.963, tensor([0.0370, 0.0000, 5.2510, 6.6750])
#
# 	 EPOCH 168, totalloss: 11.82, tensor([0.0340, 0.0000, 5.0690, 6.7170])
#
# 	 EPOCH 169, totalloss: 11.907, tensor([0.0450, 0.0000, 5.0870, 6.7750])
#
# 	 EPOCH 170, totalloss: 11.72, tensor([0.0360, 0.0000, 5.1390, 6.5450])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 171, totalloss: 11.82, tensor([0.0360, 0.0000, 5.0950, 6.6880])
#
# 	 EPOCH 172, totalloss: 11.503, tensor([0.0390, 0.0000, 5.0410, 6.4230])
#
# 	 EPOCH 173, totalloss: 11.77, tensor([0.0430, 0.0000, 5.1350, 6.5910])
#
# 	 EPOCH 174, totalloss: 11.732, tensor([0.0240, 0.0000, 5.0590, 6.6480])
#
# 	 EPOCH 175, totalloss: 11.478, tensor([0.0330, 0.0000, 4.9590, 6.4850])
#
# 	 EPOCH 176, totalloss: 11.553, tensor([0.0390, 0.0000, 4.9040, 6.6100])
#
# 	 EPOCH 177, totalloss: 11.524, tensor([0.0490, 0.0000, 4.9790, 6.4960])
#
# 	 EPOCH 178, totalloss: 11.71, tensor([0.0350, 0.0000, 5.0310, 6.6440])
#
# 	 EPOCH 179, totalloss: 11.902, tensor([0.0390, 0.0000, 5.2410, 6.6220])
#
# 	 EPOCH 180, totalloss: 11.662, tensor([0.0320, 0.0000, 5.1960, 6.4330])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 181, totalloss: 11.2, tensor([0.0290, 0.0000, 4.8890, 6.2820])
#
# 	 EPOCH 182, totalloss: 11.548, tensor([0.0360, 0.0000, 5.0690, 6.4440])
#
# 	 EPOCH 183, totalloss: 11.464, tensor([0.0440, 0.0000, 5.0420, 6.3770])
#
# 	 EPOCH 184, totalloss: 11.258, tensor([0.0280, 0.0000, 5.0150, 6.2150])
#
# 	 EPOCH 185, totalloss: 11.228, tensor([0.0380, 0.0000, 4.8150, 6.3750])
#
# 	 EPOCH 186, totalloss: 11.261, tensor([0.0280, 0.0000, 4.8770, 6.3560])
#
# 	 EPOCH 187, totalloss: 11.168, tensor([0.0320, 0.0000, 4.8290, 6.3080])
#
# 	 EPOCH 188, totalloss: 11.322, tensor([0.0300, 0.0000, 4.8980, 6.3950])
#
# 	 EPOCH 189, totalloss: 11.399, tensor([0.0370, 0.0000, 5.0660, 6.2950])
#
# 	 EPOCH 190, totalloss: 11.204, tensor([0.0290, 0.0000, 4.8190, 6.3560])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 191, totalloss: 11.505, tensor([0.0380, 0.0000, 5.0510, 6.4160])
#
# 	 EPOCH 192, totalloss: 10.97, tensor([0.0240, 0.0000, 4.7370, 6.2080])
#
# 	 EPOCH 193, totalloss: 11.281, tensor([0.0290, 0.0000, 4.8910, 6.3600])
#
# 	 EPOCH 194, totalloss: 11.168, tensor([0.0330, 0.0000, 4.9010, 6.2330])
#
# 	 EPOCH 195, totalloss: 11.122, tensor([0.0250, 0.0000, 4.9050, 6.1920])
#
# 	 EPOCH 196, totalloss: 11.574, tensor([0.0240, 0.0000, 5.0500, 6.5000])
#
# 	 EPOCH 197, totalloss: 11.316, tensor([0.0250, 0.0000, 4.8820, 6.4080])
# 	 EPOCH 198, totalloss: 10.972, tensor([0.0370, 0.0000, 4.8700, 6.0640])
#
# 	 EPOCH 199, totalloss: 11.057, tensor([0.0280, 0.0000, 4.9580, 6.0710])
#
# 	 EPOCH 200, totalloss: 11.015, tensor([0.0320, 0.0000, 4.7760, 6.2080])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 201, totalloss: 10.869, tensor([0.0270, 0.0000, 4.7300, 6.1120])
#
# 	 EPOCH 202, totalloss: 10.893, tensor([0.0270, 0.0000, 4.7240, 6.1420])
#
# 	 EPOCH 203, totalloss: 10.994, tensor([0.0340, 0.0000, 4.8260, 6.1340])
#
# 	 EPOCH 204, totalloss: 10.861, tensor([0.0320, 0.0000, 4.7650, 6.0640])
#
# 	 EPOCH 205, totalloss: 10.861, tensor([0.0340, 0.0000, 4.7900, 6.0380])
#
# 	 EPOCH 206, totalloss: 12.165, tensor([0.0350, 0.0000, 5.3970, 6.7340])
#
# 	 EPOCH 207, totalloss: 11.276, tensor([0.0410, 0.0000, 4.8650, 6.3700])
#
# 	 EPOCH 208, totalloss: 10.819, tensor([0.0270, 0.0000, 4.8050, 5.9860])
#
# 	 EPOCH 209, totalloss: 10.966, tensor([0.0240, 0.0000, 4.8020, 6.1400])
#
# 	 EPOCH 210, totalloss: 10.774, tensor([0.0260, 0.0000, 4.7960, 5.9520])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 211, totalloss: 10.986, tensor([0.0360, 0.0000, 4.8080, 6.1410])
#
# 	 EPOCH 212, totalloss: 11.121, tensor([0.0310, 0.0000, 4.8230, 6.2660])
#
# 	 EPOCH 213, totalloss: 10.991, tensor([0.0380, 0.0000, 4.7900, 6.1630])
#
# 	 EPOCH 214, totalloss: 10.932, tensor([0.0180, 0.0000, 4.7450, 6.1690])
#
# 	 EPOCH 215, totalloss: 10.685, tensor([0.0260, 0.0000, 4.7400, 5.9190])
#
# 	 EPOCH 216, totalloss: 10.654, tensor([0.0230, 0.0000, 4.6670, 5.9650])
#
# 	 EPOCH 217, totalloss: 10.757, tensor([0.0250, 0.0000, 4.6890, 6.0430])
#
# 	 EPOCH 218, totalloss: 11.038, tensor([0.0250, 0.0000, 4.7990, 6.2140])
#
# 	 EPOCH 219, totalloss: 10.605, tensor([0.0220, 0.0000, 4.6510, 5.9320])
#
# 	 EPOCH 220, totalloss: 10.786, tensor([0.0270, 0.0000, 4.5900, 6.1700])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 221, totalloss: 10.506, tensor([0.0220, 0.0000, 4.6140, 5.8700])
#
# 	 EPOCH 222, totalloss: 10.767, tensor([0.0230, 0.0000, 4.6690, 6.0750])
#
# 	 EPOCH 223, totalloss: 10.292, tensor([0.0230, 0.0000, 4.4730, 5.7960])
#
# 	 EPOCH 224, totalloss: 10.627, tensor([0.0280, 0.0000, 4.6650, 5.9340])
#
# 	 EPOCH 225, totalloss: 10.547, tensor([0.0230, 0.0000, 4.6020, 5.9210])
#
# 	 EPOCH 226, totalloss: 10.597, tensor([0.0250, 0.0000, 4.6180, 5.9540])
#
# 	 EPOCH 227, totalloss: 10.501, tensor([0.0270, 0.0000, 4.5070, 5.9670])
#
# 	 EPOCH 228, totalloss: 10.704, tensor([0.0290, 0.0000, 4.5520, 6.1230])
#
# 	 EPOCH 229, totalloss: 10.38, tensor([0.0190, 0.0000, 4.4760, 5.8850])
#
# 	 EPOCH 230, totalloss: 10.907, tensor([0.0190, 0.0000, 4.8360, 6.0520])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 231, totalloss: 10.351, tensor([0.0200, 0.0000, 4.5560, 5.7750])
#
# 	 EPOCH 232, totalloss: 10.7, tensor([0.0210, 0.0000, 4.6370, 6.0420])
#
# 	 EPOCH 233, totalloss: 10.773, tensor([0.0270, 0.0000, 4.7420, 6.0030])
#
# 	 EPOCH 234, totalloss: 10.575, tensor([0.0170, 0.0000, 4.5700, 5.9880])
#
# 	 EPOCH 235, totalloss: 10.116, tensor([0.0170, 0.0000, 4.3260, 5.7720])
#
# 	 EPOCH 236, totalloss: 10.402, tensor([0.0220, 0.0000, 4.4750, 5.9060])
#
# 	 EPOCH 237, totalloss: 10.312, tensor([0.0250, 0.0000, 4.5740, 5.7140])
#
# 	 EPOCH 238, totalloss: 10.611, tensor([0.0210, 0.0000, 4.5650, 6.0240])
#
# 	 EPOCH 239, totalloss: 11.206, tensor([0.0260, 0.0000, 4.8760, 6.3050])
#
# 	 EPOCH 240, totalloss: 10.832, tensor([0.0300, 0.0000, 4.6260, 6.1760])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 241, totalloss: 10.111, tensor([0.0260, 0.0000, 4.4250, 5.6600])
#
# 	 EPOCH 242, totalloss: 10.572, tensor([0.0170, 0.0000, 4.6300, 5.9250])
#
# 	 EPOCH 243, totalloss: 10.035, tensor([0.0230, 0.0000, 4.3100, 5.7020])
#
# 	 EPOCH 244, totalloss: 10.257, tensor([0.0240, 0.0000, 4.4980, 5.7350])
#
# 	 EPOCH 245, totalloss: 10.353, tensor([0.0220, 0.0000, 4.6080, 5.7230])
#
# 	 EPOCH 246, totalloss: 10.326, tensor([0.0210, 0.0000, 4.5560, 5.7490])
#
# 	 EPOCH 247, totalloss: 10.394, tensor([0.0210, 0.0000, 4.6110, 5.7620])
#
# 	 EPOCH 248, totalloss: 9.99, tensor([0.0170, 0.0000, 4.2940, 5.6800])
#
# 	 EPOCH 249, totalloss: 10.332, tensor([0.0230, 0.0000, 4.6380, 5.6710])
#
# 	 EPOCH 250, totalloss: 10.226, tensor([0.0200, 0.0000, 4.5720, 5.6350])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 251, totalloss: 9.932, tensor([0.0240, 0.0000, 4.3780, 5.5310])
#
# 	 EPOCH 252, totalloss: 10.094, tensor([0.0180, 0.0000, 4.3550, 5.7220])
#
# 	 EPOCH 253, totalloss: 10.365, tensor([0.0250, 0.0000, 4.5500, 5.7910])
#
# 	 EPOCH 254, totalloss: 9.999, tensor([0.0240, 0.0000, 4.3660, 5.6090])
#
# 	 EPOCH 255, totalloss: 10.078, tensor([0.0230, 0.0000, 4.3110, 5.7450])
#
# 	 EPOCH 256, totalloss: 10.345, tensor([0.0170, 0.0000, 4.5500, 5.7780])
#
# 	 EPOCH 257, totalloss: 9.718, tensor([0.0160, 0.0000, 4.2360, 5.4660])
#
# 	 EPOCH 258, totalloss: 10.025, tensor([0.0160, 0.0000, 4.3200, 5.6900])
#
# 	 EPOCH 259, totalloss: 10.204, tensor([0.0310, 0.0000, 4.2880, 5.8850])
#
# 	 EPOCH 260, totalloss: 10.094, tensor([0.0240, 0.0000, 4.3770, 5.6930])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 261, totalloss: 10.134, tensor([0.0190, 0.0000, 4.3950, 5.7200])
#
# 	 EPOCH 262, totalloss: 9.898, tensor([0.0210, 0.0000, 4.2640, 5.6130])
#
# 	 EPOCH 263, totalloss: 10.446, tensor([0.0250, 0.0000, 4.6140, 5.8080])
#
# 	 EPOCH 264, totalloss: 10.025, tensor([0.0190, 0.0000, 4.4420, 5.5630])
#
# 	 EPOCH 265, totalloss: 10.055, tensor([0.0170, 0.0000, 4.5080, 5.5300])
#
# 	 EPOCH 266, totalloss: 9.957, tensor([0.0200, 0.0000, 4.2950, 5.6420])
#
# 	 EPOCH 267, totalloss: 9.949, tensor([0.0240, 0.0000, 4.3720, 5.5530])
#
# 	 EPOCH 268, totalloss: 9.849, tensor([0.0170, 0.0000, 4.2560, 5.5760])
#
# 	 EPOCH 269, totalloss: 9.901, tensor([0.0210, 0.0000, 4.2210, 5.6590])
# 	 EPOCH 270, totalloss: 9.857, tensor([0.0230, 0.0000, 4.2370, 5.5970])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 271, totalloss: 9.878, tensor([0.0180, 0.0000, 4.3920, 5.4680])
#
# 	 EPOCH 272, totalloss: 9.689, tensor([0.0150, 0.0000, 4.2950, 5.3780])
#
# 	 EPOCH 273, totalloss: 9.672, tensor([0.0150, 0.0000, 4.2100, 5.4470])
#
# 	 EPOCH 274, totalloss: 10.122, tensor([0.0170, 0.0000, 4.3100, 5.7960])
#
# 	 EPOCH 275, totalloss: 9.865, tensor([0.0250, 0.0000, 4.3590, 5.4820])
#
# 	 EPOCH 276, totalloss: 9.787, tensor([0.0160, 0.0000, 4.2030, 5.5680])
#
# 	 EPOCH 277, totalloss: 10.047, tensor([0.0220, 0.0000, 4.3380, 5.6860])
#
# 	 EPOCH 278, totalloss: 9.717, tensor([0.0230, 0.0000, 4.2290, 5.4650])
#
# 	 EPOCH 279, totalloss: 9.622, tensor([0.0190, 0.0000, 4.2610, 5.3420])
#
# 	 EPOCH 280, totalloss: 9.935, tensor([0.0160, 0.0000, 4.4050, 5.5140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 281, totalloss: 10.048, tensor([0.0240, 0.0000, 4.3190, 5.7040])
#
# 	 EPOCH 282, totalloss: 9.701, tensor([0.0210, 0.0000, 4.2520, 5.4290])
#
# 	 EPOCH 283, totalloss: 10.109, tensor([0.0240, 0.0000, 4.4670, 5.6170])
#
# 	 EPOCH 284, totalloss: 9.651, tensor([0.0180, 0.0000, 4.2120, 5.4210])
#
# 	 EPOCH 285, totalloss: 9.421, tensor([0.0190, 0.0000, 4.0640, 5.3380])
#
# 	 EPOCH 286, totalloss: 10.109, tensor([0.0250, 0.0000, 4.4690, 5.6150])
#
# 	 EPOCH 287, totalloss: 10.013, tensor([0.0220, 0.0000, 4.4210, 5.5710])
#
# 	 EPOCH 288, totalloss: 10.475, tensor([0.0180, 0.0000, 4.5630, 5.8940])
#
# 	 EPOCH 289, totalloss: 9.983, tensor([0.0210, 0.0000, 4.3240, 5.6390])
#
# 	 EPOCH 290, totalloss: 9.701, tensor([0.0130, 0.0000, 4.2500, 5.4390])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 291, totalloss: 9.758, tensor([0.0150, 0.0000, 4.2950, 5.4480])
#
# 	 EPOCH 292, totalloss: 9.387, tensor([0.0150, 0.0000, 4.1620, 5.2090])
#
# 	 EPOCH 293, totalloss: 9.481, tensor([0.0140, 0.0000, 4.0990, 5.3680])
#
# 	 EPOCH 294, totalloss: 9.439, tensor([0.0130, 0.0000, 4.1220, 5.3040])
#
# 	 EPOCH 295, totalloss: 9.441, tensor([0.0120, 0.0000, 4.0930, 5.3360])
#
# 	 EPOCH 296, totalloss: 9.609, tensor([0.0160, 0.0000, 4.0510, 5.5420])
#
# 	 EPOCH 297, totalloss: 9.68, tensor([0.0180, 0.0000, 4.2810, 5.3810])
#
# 	 EPOCH 298, totalloss: 9.486, tensor([0.0160, 0.0000, 4.0920, 5.3790])
#
# 	 EPOCH 299, totalloss: 9.436, tensor([0.0160, 0.0000, 4.1710, 5.2480])
#
# 	 EPOCH 300, totalloss: 9.78, tensor([0.0120, 0.0000, 4.1630, 5.6040])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 301, totalloss: 9.847, tensor([0.0200, 0.0000, 4.2260, 5.6010])
#
# 	 EPOCH 302, totalloss: 9.272, tensor([0.0120, 0.0000, 4.1650, 5.0950])
#
# 	 EPOCH 303, totalloss: 9.491, tensor([0.0160, 0.0000, 4.0880, 5.3870])
#
# 	 EPOCH 304, totalloss: 9.584, tensor([0.0200, 0.0000, 4.2920, 5.2720])
#
# 	 EPOCH 305, totalloss: 9.487, tensor([0.0140, 0.0000, 4.1840, 5.2900])
#
# 	 EPOCH 306, totalloss: 9.421, tensor([0.0140, 0.0000, 4.1860, 5.2210])
#
# 	 EPOCH 307, totalloss: 9.48, tensor([0.0090, 0.0000, 4.0640, 5.4080])
#
# 	 EPOCH 308, totalloss: 9.725, tensor([0.0120, 0.0000, 4.2100, 5.5030])
#
# 	 EPOCH 309, totalloss: 9.428, tensor([0.0140, 0.0000, 4.1440, 5.2700])
#
# 	 EPOCH 310, totalloss: 9.467, tensor([0.0120, 0.0000, 4.1060, 5.3490])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 311, totalloss: 9.355, tensor([0.0140, 0.0000, 4.1340, 5.2070])
#
# 	 EPOCH 312, totalloss: 9.113, tensor([0.0170, 0.0000, 4.0010, 5.0950])
#
# 	 EPOCH 313, totalloss: 9.688, tensor([0.0230, 0.0000, 4.2450, 5.4210])
#
# 	 EPOCH 314, totalloss: 9.386, tensor([0.0240, 0.0000, 4.1210, 5.2410])
#
# 	 EPOCH 315, totalloss: 9.548, tensor([0.0100, 0.0000, 4.0890, 5.4490])
#
# 	 EPOCH 316, totalloss: 9.259, tensor([0.0120, 0.0000, 4.0250, 5.2220])
#
# 	 EPOCH 317, totalloss: 9.508, tensor([0.0110, 0.0000, 4.0850, 5.4120])
#
# 	 EPOCH 318, totalloss: 9.001, tensor([0.0130, 0.0000, 3.9820, 5.0060])
#
# 	 EPOCH 319, totalloss: 9.408, tensor([0.0140, 0.0000, 4.0910, 5.3030])
#
# 	 EPOCH 320, totalloss: 9.115, tensor([0.0110, 0.0000, 4.0750, 5.0300])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 321, totalloss: 9.462, tensor([0.0170, 0.0000, 4.2610, 5.1840])
#
# 	 EPOCH 322, totalloss: 9.535, tensor([0.0160, 0.0000, 4.1200, 5.3990])
#
# 	 EPOCH 323, totalloss: 8.934, tensor([0.0170, 0.0000, 3.8850, 5.0310])
#
# 	 EPOCH 324, totalloss: 9.291, tensor([0.0190, 0.0000, 4.1090, 5.1630])
#
# 	 EPOCH 325, totalloss: 9.432, tensor([0.0150, 0.0000, 4.0710, 5.3460])
#
# 	 EPOCH 326, totalloss: 9.402, tensor([0.0140, 0.0000, 4.0610, 5.3270])
#
# 	 EPOCH 327, totalloss: 9.136, tensor([0.0140, 0.0000, 3.9550, 5.1670])
#
# 	 EPOCH 328, totalloss: 8.927, tensor([0.0070, 0.0000, 3.8840, 5.0350])
#
# 	 EPOCH 329, totalloss: 8.893, tensor([0.0150, 0.0000, 3.9730, 4.9050])
#
# 	 EPOCH 330, totalloss: 9.347, tensor([0.0230, 0.0000, 4.1430, 5.1810])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 331, totalloss: 9.681, tensor([0.0140, 0.0000, 4.2700, 5.3970])
#
# 	 EPOCH 332, totalloss: 9.136, tensor([0.0120, 0.0000, 3.9460, 5.1770])
#
# 	 EPOCH 333, totalloss: 9.273, tensor([0.0090, 0.0000, 4.1440, 5.1200])
#
# 	 EPOCH 334, totalloss: 8.858, tensor([0.0100, 0.0000, 3.9610, 4.8870])
#
# 	 EPOCH 335, totalloss: 9.207, tensor([0.0160, 0.0000, 4.0720, 5.1190])
#
# 	 EPOCH 336, totalloss: 9.169, tensor([0.0160, 0.0000, 4.0300, 5.1230])
#
# 	 EPOCH 337, totalloss: 9.002, tensor([0.0140, 0.0000, 3.8640, 5.1250])
#
# 	 EPOCH 338, totalloss: 9.09, tensor([0.0130, 0.0000, 3.9440, 5.1340])
#
# 	 EPOCH 339, totalloss: 9.052, tensor([0.0150, 0.0000, 3.9840, 5.0530])
#
# 	 EPOCH 340, totalloss: 8.971, tensor([0.0130, 0.0000, 4.0030, 4.9550])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 341, totalloss: 9.462, tensor([0.0180, 0.0000, 4.1600, 5.2840])
#
# 	 EPOCH 342, totalloss: 9.026, tensor([0.0150, 0.0000, 3.8780, 5.1330])
#
# 	 EPOCH 343, totalloss: 9.04, tensor([0.0080, 0.0000, 4.0220, 5.0100])
#
# 	 EPOCH 344, totalloss: 8.822, tensor([0.0150, 0.0000, 3.9300, 4.8770])
#
# 	 EPOCH 345, totalloss: 8.916, tensor([0.0080, 0.0000, 3.9020, 5.0060])
#
# 	 EPOCH 346, totalloss: 9.08, tensor([0.0100, 0.0000, 4.0290, 5.0410])
#
# 	 EPOCH 347, totalloss: 9.007, tensor([0.0090, 0.0000, 3.9510, 5.0460])
#
# 	 EPOCH 348, totalloss: 9.024, tensor([0.0090, 0.0000, 3.8760, 5.1400])
#
# 	 EPOCH 349, totalloss: 9.097, tensor([0.0090, 0.0000, 3.9900, 5.0980])
#
# 	 EPOCH 350, totalloss: 8.677, tensor([0.0120, 0.0000, 3.8220, 4.8430])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 351, totalloss: 8.79, tensor([0.0120, 0.0000, 3.8810, 4.8970])
#
# 	 EPOCH 352, totalloss: 8.657, tensor([0.0110, 0.0000, 3.7780, 4.8670])
#
# 	 EPOCH 353, totalloss: 9.237, tensor([0.0110, 0.0000, 4.0110, 5.2150])
#
# 	 EPOCH 354, totalloss: 8.839, tensor([0.0080, 0.0000, 3.8300, 5.0000])
#
# 	 EPOCH 355, totalloss: 8.894, tensor([0.0120, 0.0000, 3.8890, 4.9940])
#
# 	 EPOCH 356, totalloss: 8.751, tensor([0.0110, 0.0000, 3.9290, 4.8110])
#
# 	 EPOCH 357, totalloss: 9.18, tensor([0.0100, 0.0000, 4.0760, 5.0940])
#
# 	 EPOCH 358, totalloss: 8.882, tensor([0.0170, 0.0000, 3.8420, 5.0230])
#
# 	 EPOCH 359, totalloss: 8.854, tensor([0.0130, 0.0000, 3.9160, 4.9250])
#
# 	 EPOCH 360, totalloss: 8.761, tensor([0.0140, 0.0000, 3.9050, 4.8430])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 361, totalloss: 8.88, tensor([0.0170, 0.0000, 3.8580, 5.0050])
#
# 	 EPOCH 362, totalloss: 9.013, tensor([0.0130, 0.0000, 3.9310, 5.0690])
#
# 	 EPOCH 363, totalloss: 8.809, tensor([0.0090, 0.0000, 3.8970, 4.9040])
#
# 	 EPOCH 364, totalloss: 8.583, tensor([0.0100, 0.0000, 3.8780, 4.6960])
#
# 	 EPOCH 365, totalloss: 8.717, tensor([0.0100, 0.0000, 3.8630, 4.8440])
#
# 	 EPOCH 366, totalloss: 8.732, tensor([0.0100, 0.0000, 3.7690, 4.9530])
#
# 	 EPOCH 367, totalloss: 8.926, tensor([0.0100, 0.0000, 3.9410, 4.9750])
#
# 	 EPOCH 368, totalloss: 9.087, tensor([0.0140, 0.0000, 3.9260, 5.1460])
#
# 	 EPOCH 369, totalloss: 8.809, tensor([0.0160, 0.0000, 3.8450, 4.9480])
#
# 	 EPOCH 370, totalloss: 8.787, tensor([0.0080, 0.0000, 3.8530, 4.9260])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 371, totalloss: 8.875, tensor([0.0140, 0.0000, 3.7960, 5.0650])
#
# 	 EPOCH 372, totalloss: 8.559, tensor([0.0100, 0.0000, 3.7710, 4.7790])
#
# 	 EPOCH 373, totalloss: 8.47, tensor([0.0090, 0.0000, 3.8120, 4.6490])
#
# 	 EPOCH 374, totalloss: 8.528, tensor([0.0080, 0.0000, 3.7070, 4.8130])
#
# 	 EPOCH 375, totalloss: 8.664, tensor([0.0120, 0.0000, 3.8190, 4.8330])
#
# 	 EPOCH 376, totalloss: 8.544, tensor([0.0070, 0.0000, 3.7880, 4.7490])
#
# 	 EPOCH 377, totalloss: 8.669, tensor([0.0110, 0.0000, 3.8510, 4.8070])
#
# 	 EPOCH 378, totalloss: 8.874, tensor([0.0160, 0.0000, 3.8870, 4.9700])
#
# 	 EPOCH 379, totalloss: 8.722, tensor([0.0120, 0.0000, 3.8830, 4.8280])
#
# 	 EPOCH 380, totalloss: 8.69, tensor([0.0120, 0.0000, 3.8380, 4.8410])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 77 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 381, totalloss: 8.676, tensor([0.0130, 0.0000, 3.8120, 4.8510])
#
# 	 EPOCH 382, totalloss: 8.495, tensor([0.0100, 0.0000, 3.6810, 4.8040])
#
# 	 EPOCH 383, totalloss: 8.69, tensor([0.0070, 0.0000, 3.8050, 4.8770])
#
# 	 EPOCH 384, totalloss: 8.803, tensor([0.0070, 0.0000, 3.8350, 4.9610])
#
# 	 EPOCH 385, totalloss: 8.587, tensor([0.0110, 0.0000, 3.7920, 4.7840])
#
# 	 EPOCH 386, totalloss: 8.79, tensor([0.0120, 0.0000, 3.9630, 4.8140])
#
# 	 EPOCH 387, totalloss: 8.444, tensor([0.0150, 0.0000, 3.6690, 4.7600])
#
# 	 EPOCH 388, totalloss: 8.744, tensor([0.0100, 0.0000, 3.7720, 4.9620])
#
# 	 EPOCH 389, totalloss: 8.742, tensor([0.0140, 0.0000, 3.8400, 4.8890])
#
# 	 EPOCH 390, totalloss: 9.019, tensor([0.0120, 0.0000, 3.8790, 5.1280])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 391, totalloss: 8.942, tensor([0.0110, 0.0000, 3.8850, 5.0460])
#
# 	 EPOCH 392, totalloss: 8.801, tensor([0.0060, 0.0000, 3.8290, 4.9660])
#
# 	 EPOCH 393, totalloss: 8.38, tensor([0.0060, 0.0000, 3.6210, 4.7530])
#
# 	 EPOCH 394, totalloss: 8.921, tensor([0.0130, 0.0000, 4.0780, 4.8290])
#
# 	 EPOCH 395, totalloss: 8.571, tensor([0.0110, 0.0000, 3.7070, 4.8530])
#
# 	 EPOCH 396, totalloss: 8.782, tensor([0.0120, 0.0000, 3.8250, 4.9460])
#
# 	 EPOCH 397, totalloss: 8.391, tensor([0.0110, 0.0000, 3.6920, 4.6880])
#
# 	 EPOCH 398, totalloss: 8.32, tensor([0.0120, 0.0000, 3.6570, 4.6510])
#
# 	 EPOCH 399, totalloss: 8.657, tensor([0.0050, 0.0000, 3.8440, 4.8080])
#
# 	 EPOCH 400, totalloss: 8.164, tensor([0.0090, 0.0000, 3.6740, 4.4810])
# --------------------------------------------------------------------------------
# ...
#
# 	 EPOCH 872, totalloss: 6.336, tensor([0.0060, 0.0000, 2.7690, 3.5610])
#
# 	 EPOCH 873, totalloss: 6.485, tensor([2.0000e-03, 0.0000e+00, 2.7880e+00, 3.6960e+00])
#
# 	 EPOCH 874, totalloss: 6.26, tensor([2.0000e-03, 0.0000e+00, 2.7390e+00, 3.5190e+00])
#
# 	 EPOCH 875, totalloss: 6.178, tensor([3.0000e-03, 0.0000e+00, 2.8500e+00, 3.3250e+00])
#
# 	 EPOCH 876, totalloss: 6.11, tensor([0.0050, 0.0000, 2.6150, 3.4900])
#
# 	 EPOCH 877, totalloss: 6.167, tensor([0.0060, 0.0000, 2.6290, 3.5310])
#
# 	 EPOCH 878, totalloss: 5.919, tensor([0.0070, 0.0000, 2.5770, 3.3350])
#
# 	 EPOCH 879, totalloss: 5.934, tensor([0.0070, 0.0000, 2.7160, 3.2110])
#
# 	 EPOCH 880, totalloss: 6.116, tensor([2.0000e-03, 0.0000e+00, 2.6240e+00, 3.4900e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 68 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 881, totalloss: 6.111, tensor([3.0000e-03, 0.0000e+00, 2.6630e+00, 3.4450e+00])
#
# 	 EPOCH 882, totalloss: 6.102, tensor([3.0000e-03, 0.0000e+00, 2.6160e+00, 3.4830e+00])
#
# 	 EPOCH 883, totalloss: 5.895, tensor([2.0000e-03, 0.0000e+00, 2.6340e+00, 3.2600e+00])
#
# 	 EPOCH 884, totalloss: 6.18, tensor([2.0000e-03, 0.0000e+00, 2.6700e+00, 3.5080e+00])
#
# 	 EPOCH 885, totalloss: 5.998, tensor([3.0000e-03, 0.0000e+00, 2.6310e+00, 3.3650e+00])
#
# 	 EPOCH 886, totalloss: 6.013, tensor([2.0000e-03, 0.0000e+00, 2.5930e+00, 3.4170e+00])
#
# 	 EPOCH 887, totalloss: 5.964, tensor([3.0000e-03, 0.0000e+00, 2.6590e+00, 3.3020e+00])
#
# 	 EPOCH 888, totalloss: 6.2, tensor([0.0060, 0.0000, 2.6900, 3.5040])
#
# 	 EPOCH 889, totalloss: 5.887, tensor([0.0050, 0.0000, 2.5630, 3.3190])
#
# 	 EPOCH 890, totalloss: 5.894, tensor([0.0040, 0.0000, 2.4650, 3.4260])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 891, totalloss: 5.695, tensor([0.0060, 0.0000, 2.4780, 3.2110])
#
# 	 EPOCH 892, totalloss: 6.008, tensor([3.0000e-03, 0.0000e+00, 2.6820e+00, 3.3230e+00])
#
# 	 EPOCH 893, totalloss: 5.877, tensor([1.0000e-03, 0.0000e+00, 2.6040e+00, 3.2720e+00])
#
# 	 EPOCH 894, totalloss: 6.055, tensor([0.0050, 0.0000, 2.7130, 3.3370])
#
# 	 EPOCH 895, totalloss: 6.012, tensor([1.0000e-03, 0.0000e+00, 2.6150e+00, 3.3960e+00])
#
# 	 EPOCH 896, totalloss: 5.895, tensor([0.0040, 0.0000, 2.5730, 3.3190])
#
# 	 EPOCH 897, totalloss: 6.201, tensor([0.0050, 0.0000, 2.8110, 3.3840])
#
# 	 EPOCH 898, totalloss: 5.974, tensor([0.0040, 0.0000, 2.6030, 3.3670])
#
# 	 EPOCH 899, totalloss: 5.89, tensor([2.0000e-03, 0.0000e+00, 2.5540e+00, 3.3330e+00])
#
# 	 EPOCH 900, totalloss: 5.695, tensor([0.0040, 0.0000, 2.5850, 3.1060])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 901, totalloss: 5.965, tensor([0.0040, 0.0000, 2.6060, 3.3550])
#
# 	 EPOCH 902, totalloss: 6.271, tensor([3.0000e-03, 0.0000e+00, 2.8420e+00, 3.4270e+00])
#
# 	 EPOCH 903, totalloss: 6.244, tensor([3.0000e-03, 0.0000e+00, 2.7890e+00, 3.4530e+00])
#
# 	 EPOCH 904, totalloss: 5.944, tensor([3.0000e-03, 0.0000e+00, 2.6070e+00, 3.3330e+00])
#
# 	 EPOCH 905, totalloss: 5.851, tensor([2.0000e-03, 0.0000e+00, 2.5100e+00, 3.3380e+00])
#
# 	 EPOCH 906, totalloss: 5.918, tensor([1.0000e-03, 0.0000e+00, 2.5650e+00, 3.3520e+00])
#
# 	 EPOCH 907, totalloss: 5.903, tensor([0.0050, 0.0000, 2.6070, 3.2920])
#
# 	 EPOCH 908, totalloss: 6.096, tensor([3.0000e-03, 0.0000e+00, 2.6250e+00, 3.4680e+00])
#
# 	 EPOCH 909, totalloss: 5.768, tensor([3.0000e-03, 0.0000e+00, 2.5590e+00, 3.2060e+00])
#
# 	 EPOCH 910, totalloss: 6.038, tensor([0.0040, 0.0000, 2.7250, 3.3090])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 911, totalloss: 6.088, tensor([0.0040, 0.0000, 2.6340, 3.4500])
#
# 	 EPOCH 912, totalloss: 5.911, tensor([1.0000e-03, 0.0000e+00, 2.5250e+00, 3.3840e+00])
#
# 	 EPOCH 913, totalloss: 5.739, tensor([2.0000e-03, 0.0000e+00, 2.5590e+00, 3.1770e+00])
#
# 	 EPOCH 914, totalloss: 6.255, tensor([2.0000e-03, 0.0000e+00, 2.7370e+00, 3.5150e+00])
#
# 	 EPOCH 915, totalloss: 5.853, tensor([3.0000e-03, 0.0000e+00, 2.6590e+00, 3.1910e+00])
#
# 	 EPOCH 916, totalloss: 5.913, tensor([0.0040, 0.0000, 2.6220, 3.2870])
#
# 	 EPOCH 917, totalloss: 5.656, tensor([2.0000e-03, 0.0000e+00, 2.5140e+00, 3.1400e+00])
#
# 	 EPOCH 918, totalloss: 6.173, tensor([0.0070, 0.0000, 2.7230, 3.4430])
#
# 	 EPOCH 919, totalloss: 5.897, tensor([0.0060, 0.0000, 2.6020, 3.2890])
#
# 	 EPOCH 920, totalloss: 5.906, tensor([3.0000e-03, 0.0000e+00, 2.5650e+00, 3.3380e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 921, totalloss: 6.203, tensor([2.0000e-03, 0.0000e+00, 2.7170e+00, 3.4830e+00])
#
# 	 EPOCH 922, totalloss: 5.968, tensor([0.0040, 0.0000, 2.6210, 3.3430])
#
# 	 EPOCH 923, totalloss: 5.751, tensor([0.0040, 0.0000, 2.5080, 3.2390])
#
# 	 EPOCH 924, totalloss: 5.761, tensor([2.0000e-03, 0.0000e+00, 2.5680e+00, 3.1920e+00])
#
# 	 EPOCH 925, totalloss: 5.974, tensor([0.0150, 0.0000, 2.6330, 3.3260])
#
# 	 EPOCH 926, totalloss: 6.224, tensor([0.0040, 0.0000, 2.7110, 3.5090])
#
# 	 EPOCH 927, totalloss: 6.087, tensor([0.0050, 0.0000, 2.7310, 3.3510])
#
# 	 EPOCH 928, totalloss: 5.916, tensor([0.0040, 0.0000, 2.6220, 3.2900])
#
# 	 EPOCH 929, totalloss: 5.856, tensor([2.0000e-03, 0.0000e+00, 2.6000e+00, 3.2540e+00])
#
# 	 EPOCH 930, totalloss: 5.972, tensor([3.0000e-03, 0.0000e+00, 2.6090e+00, 3.3600e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 65 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 931, totalloss: 6.454, tensor([0.0060, 0.0000, 2.8110, 3.6370])
#
# 	 EPOCH 932, totalloss: 5.984, tensor([2.0000e-03, 0.0000e+00, 2.6400e+00, 3.3410e+00])
#
# 	 EPOCH 933, totalloss: 6.148, tensor([0.0060, 0.0000, 2.7140, 3.4280])
#
# 	 EPOCH 934, totalloss: 5.815, tensor([0.0050, 0.0000, 2.5220, 3.2870])
#
# 	 EPOCH 935, totalloss: 5.831, tensor([0.0070, 0.0000, 2.5970, 3.2270])
#
# 	 EPOCH 936, totalloss: 5.9, tensor([1.0000e-03, 0.0000e+00, 2.6310e+00, 3.2680e+00])
#
# 	 EPOCH 937, totalloss: 5.886, tensor([3.0000e-03, 0.0000e+00, 2.6080e+00, 3.2760e+00])
#
# 	 EPOCH 938, totalloss: 5.948, tensor([2.0000e-03, 0.0000e+00, 2.5850e+00, 3.3600e+00])
#
# 	 EPOCH 939, totalloss: 5.684, tensor([3.0000e-03, 0.0000e+00, 2.5350e+00, 3.1460e+00])
#
# 	 EPOCH 940, totalloss: 6.058, tensor([3.0000e-03, 0.0000e+00, 2.6820e+00, 3.3730e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 941, totalloss: 6.058, tensor([2.0000e-03, 0.0000e+00, 2.7590e+00, 3.2960e+00])
#
# 	 EPOCH 942, totalloss: 6.084, tensor([0.0040, 0.0000, 2.5870, 3.4930])
#
# 	 EPOCH 943, totalloss: 6.34, tensor([0.0050, 0.0000, 2.7090, 3.6260])
#
# 	 EPOCH 944, totalloss: 5.773, tensor([0.0040, 0.0000, 2.4850, 3.2830])
#
# 	 EPOCH 945, totalloss: 5.861, tensor([2.0000e-03, 0.0000e+00, 2.6090e+00, 3.2500e+00])
#
# 	 EPOCH 946, totalloss: 5.847, tensor([0.0050, 0.0000, 2.5770, 3.2650])
#
# 	 EPOCH 947, totalloss: 5.79, tensor([2.0000e-03, 0.0000e+00, 2.6170e+00, 3.1700e+00])
#
# 	 EPOCH 948, totalloss: 5.621, tensor([0.0080, 0.0000, 2.4510, 3.1630])
#
# 	 EPOCH 949, totalloss: 6.103, tensor([3.0000e-03, 0.0000e+00, 2.7420e+00, 3.3580e+00])
#
# 	 EPOCH 950, totalloss: 6.091, tensor([2.0000e-03, 0.0000e+00, 2.6930e+00, 3.3960e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 72 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 951, totalloss: 5.643, tensor([0.0060, 0.0000, 2.5810, 3.0560])
#
# 	 EPOCH 952, totalloss: 5.777, tensor([2.0000e-03, 0.0000e+00, 2.6100e+00, 3.1660e+00])
#
# 	 EPOCH 953, totalloss: 5.996, tensor([3.0000e-03, 0.0000e+00, 2.6080e+00, 3.3850e+00])
#
# 	 EPOCH 954, totalloss: 5.764, tensor([3.0000e-03, 0.0000e+00, 2.5000e+00, 3.2600e+00])
#
# 	 EPOCH 955, totalloss: 5.959, tensor([2.0000e-03, 0.0000e+00, 2.6770e+00, 3.2800e+00])
#
# 	 EPOCH 956, totalloss: 5.49, tensor([2.0000e-03, 0.0000e+00, 2.3970e+00, 3.0910e+00])
#
# 	 EPOCH 957, totalloss: 6.044, tensor([3.0000e-03, 0.0000e+00, 2.5890e+00, 3.4530e+00])
#
# 	 EPOCH 958, totalloss: 6.035, tensor([3.0000e-03, 0.0000e+00, 2.6300e+00, 3.4020e+00])
#
# 	 EPOCH 959, totalloss: 5.783, tensor([0.0040, 0.0000, 2.5730, 3.2060])
#
# 	 EPOCH 960, totalloss: 5.804, tensor([0.0040, 0.0000, 2.5130, 3.2870])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 961, totalloss: 5.982, tensor([0.0040, 0.0000, 2.5440, 3.4340])
#
# 	 EPOCH 962, totalloss: 5.849, tensor([3.0000e-03, 0.0000e+00, 2.5160e+00, 3.3300e+00])
#
# 	 EPOCH 963, totalloss: 5.667, tensor([2.0000e-03, 0.0000e+00, 2.5020e+00, 3.1630e+00])
#
# 	 EPOCH 964, totalloss: 5.589, tensor([3.0000e-03, 0.0000e+00, 2.4680e+00, 3.1180e+00])
#
# 	 EPOCH 965, totalloss: 5.84, tensor([1.0000e-03, 0.0000e+00, 2.6140e+00, 3.2240e+00])
# 	 EPOCH 966, totalloss: 6.058, tensor([1.0000e-03, 0.0000e+00, 2.6270e+00, 3.4290e+00])
#
# 	 EPOCH 967, totalloss: 5.79, tensor([0.0050, 0.0000, 2.5420, 3.2420])
#
# 	 EPOCH 968, totalloss: 5.801, tensor([2.0000e-03, 0.0000e+00, 2.6020e+00, 3.1970e+00])
#
# 	 EPOCH 969, totalloss: 5.646, tensor([3.0000e-03, 0.0000e+00, 2.4430e+00, 3.2010e+00])
#
# 	 EPOCH 970, totalloss: 5.821, tensor([3.0000e-03, 0.0000e+00, 2.5870e+00, 3.2310e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 971, totalloss: 5.837, tensor([3.0000e-03, 0.0000e+00, 2.5540e+00, 3.2800e+00])
#
# 	 EPOCH 972, totalloss: 5.734, tensor([0.0050, 0.0000, 2.4710, 3.2590])
#
# 	 EPOCH 973, totalloss: 6.272, tensor([0.0040, 0.0000, 2.8410, 3.4270])
#
# 	 EPOCH 974, totalloss: 6.127, tensor([0.0050, 0.0000, 2.6670, 3.4560])
#
# 	 EPOCH 975, totalloss: 5.885, tensor([3.0000e-03, 0.0000e+00, 2.5740e+00, 3.3080e+00])
#
# 	 EPOCH 976, totalloss: 5.64, tensor([3.0000e-03, 0.0000e+00, 2.4630e+00, 3.1740e+00])
#
# 	 EPOCH 977, totalloss: 5.919, tensor([2.0000e-03, 0.0000e+00, 2.6160e+00, 3.3010e+00])
#
# 	 EPOCH 978, totalloss: 5.756, tensor([2.0000e-03, 0.0000e+00, 2.4870e+00, 3.2670e+00])
#
# 	 EPOCH 979, totalloss: 5.737, tensor([2.0000e-03, 0.0000e+00, 2.5670e+00, 3.1680e+00])
#
# 	 EPOCH 980, totalloss: 5.788, tensor([2.0000e-03, 0.0000e+00, 2.4820e+00, 3.3040e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 981, totalloss: 5.555, tensor([3.0000e-03, 0.0000e+00, 2.4420e+00, 3.1100e+00])
#
# 	 EPOCH 982, totalloss: 5.822, tensor([0.0040, 0.0000, 2.5780, 3.2400])
#
# 	 EPOCH 983, totalloss: 5.684, tensor([2.0000e-03, 0.0000e+00, 2.4930e+00, 3.1890e+00])
#
# 	 EPOCH 984, totalloss: 5.64, tensor([3.0000e-03, 0.0000e+00, 2.5020e+00, 3.1350e+00])
#
# 	 EPOCH 985, totalloss: 5.934, tensor([2.0000e-03, 0.0000e+00, 2.6110e+00, 3.3200e+00])
#
# 	 EPOCH 986, totalloss: 5.693, tensor([2.0000e-03, 0.0000e+00, 2.4740e+00, 3.2170e+00])
#
# 	 EPOCH 987, totalloss: 5.864, tensor([3.0000e-03, 0.0000e+00, 2.5440e+00, 3.3170e+00])
#
# 	 EPOCH 988, totalloss: 5.669, tensor([2.0000e-03, 0.0000e+00, 2.5000e+00, 3.1680e+00])
#
# 	 EPOCH 989, totalloss: 5.902, tensor([3.0000e-03, 0.0000e+00, 2.6030e+00, 3.2960e+00])
#
# 	 EPOCH 990, totalloss: 6.026, tensor([0.0050, 0.0000, 2.6050, 3.4160])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 991, totalloss: 5.85, tensor([3.0000e-03, 0.0000e+00, 2.5770e+00, 3.2700e+00])
#
# 	 EPOCH 992, totalloss: 5.835, tensor([3.0000e-03, 0.0000e+00, 2.5480e+00, 3.2840e+00])
#
# 	 EPOCH 993, totalloss: 5.874, tensor([3.0000e-03, 0.0000e+00, 2.5660e+00, 3.3050e+00])
#
# 	 EPOCH 994, totalloss: 5.616, tensor([2.0000e-03, 0.0000e+00, 2.5000e+00, 3.1140e+00])
#
# 	 EPOCH 995, totalloss: 6.072, tensor([3.0000e-03, 0.0000e+00, 2.7480e+00, 3.3210e+00])
#
# 	 EPOCH 996, totalloss: 5.919, tensor([2.0000e-03, 0.0000e+00, 2.6220e+00, 3.2960e+00])
#
# 	 EPOCH 997, totalloss: 5.748, tensor([3.0000e-03, 0.0000e+00, 2.5710e+00, 3.1740e+00])
#
# 	 EPOCH 998, totalloss: 5.797, tensor([0.0080, 0.0000, 2.4760, 3.3130])
#
# 	 EPOCH 999, totalloss: 5.846, tensor([2.0000e-03, 0.0000e+00, 2.6280e+00, 3.2170e+00])
# Finished Training
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 71 %

# %%
## train on single class: house
# !CUDA_VISIBLE_DEVICES=2 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_house.yml"

# %%
## train on single task: functionality
# !CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singletask_functionality.yml"

# %%
## test pretrained network
# !python test_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_test.yml"

# %%
## run the optimization framework; hit 'shift+enter' keys to run
## IMPORTANT INFO about running the acoustic optimization script:
## The Command Format for this script: 
## bash run_acousticoptim.sh INPUT_MESH SILHOUETTE_DEFORM_FLAG SILHOUETTE_REF_IMG ACOUSTIC_DEFORM_FLAG WHICH_ACOUSTIC_PARAMS OUTPUT_NAME
## where `INPUT_MESH_FILEPATH` is the absolute filepath of the mesh you would like to deform
##       `TRAINED_GRAPH_FILEPATH` is the filepath to the trained mesh2aesthetic graph convolutional neural network
##       `STYLE_PARAM` is either 'baroque', 'modern', or 'classic' 
##       `SEM_PARAM`  is either 'house' or 'column'
##       `FUNC_PARAM` is an integer number from [1,2,3,4], where 1 is low functionality and 4 is high functionality
##       `AESTH_PARAM` is an integer number from [1,2,3,4], where 1 is poor aesthetics and 5 is good aesthetics 
##       `OUTPUT_FILENAME` is the absolute filepath where you would like the deformed output mesh to be saved.
##       `NUM_ITERS` is the number of iterations to run the optimization.
##       `CFG_FILE` is the absolute path to the configuration file. You will need to change this to the config file path that you used for training the model (see above cell)
##
## Example Command:
#!cd /storage/concerthall && bash run_acousticoptim.sh \
#                            INPUT_MESH_FILEPATH \
#                            TRAINED_GRAPH_FILEPATH \
#                            STYLE_PARAM \
#                            SEM_PARAM \
#                            FUNC_PARAM \
#                            AESTH_PARAM \
#                            OUTPUT_FILENAME \
#                            NUM_ITERS \
#                            CFG_FILE
#
# !cd /storage/acadia2020_graphcnn && bash run_param_optim.sh \
                            "/storage/3Dmodels/bench.obj" \
                            "/storage/acadia2020_graphcnn_training_results/exp_09_26_14_01_06_ai_aesthetics_optim/model_best_loss.pkl" \
                            "modern" \
                            "house" \
                            4 \
                            5 \
                            "test_sil_deform.obj" \
                            250 \
                            "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
