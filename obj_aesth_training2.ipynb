# %%
## install the pytorch3d package; hit 'shift+enter' keys to run
# !conda create --name pytorch3d --yes
# !conda activate pytorch3d
# !python3 -m pip install --upgrade numpy
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch --yes
# !conda install -c conda-forge -c takatosp1 fvcore --yes
# !conda install pytorch3d -c pytorch3d --yes
# !python3 -m pip install tqdm pandas scipy opencv-python 
# !python3 -m pip install --upgrade matplotlib --ignore-installed certifi

# %%
## download the concerthall optimization code base; hit 'shift+enter' keys to run
#!rm -rf /storage/acadia2020_graphcnn
#!git clone https://github.com/alexacarlson/acadia2020_graphcnn.git /storage/acadia2020_graphcnn

## check size of dataset/verts etc
# !python check_dataset.py
# Out:
# getting config
# getting dataset list
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# getting dataset loader
# getting dataset split
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# columnsets/set30/column_30.8.obj 92086
# columnsets/set30/column_30.9.obj 92130
# columnsets/set30/column_30.10.obj 92140
# columnsets/set40/column_40.24.obj 58812
# columnsets/set40/column_40.28.obj 157038
# columnsets/set45/column_45.24.obj 58812
# columnsets/set45/column_45.26.obj 78508
# columnsets/set47/column_47.9.obj 92130
# 44
# 157038
# 8

# %%
## Train the graph convolutional neural network; hit 'shift+enter' keys to run
## NOTES on Training the Graph Convolutional Neural network to map 3D meshes --> aesthetic and functionality parameters:
## To train your own graph convolutional network, you first need to create a folder in paperspace storage 
## at `/storage/concert_dataset` upload your data there. All of your meshes should be `.obj` files and
## should exist in a subdirectory of the dataset: `/storage/acadia2020_graphcnn_dataset/Separated/`. 
## You will need to have a csv file of label/parameters (where each line is in the format `mesh.obj label1 label2 ... label10`) 
## located at and named `/storage/acadia2020_graphcnn_dataset/NamingBookV2.csv`.
## The results (network weights and training loss values) will be saved to `/storage/acadia2020_graphcnn_training_results`.
##
## Note that this function takes in the absolute filepath of a configuration file (CFG_PATH) that sets up the network architecture.
## ## To train on 4 labels:
#!cd /storage/acadia2020_graphcnn && bash run_train_graphconv_regression.sh "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
#!cd /tf/notebooks/acadia2020_graphcnn_src && bash run_train_graphconv_regression.sh "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train.yml"

# !CUDA_VISIBLE_DEVICES=1 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train2.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: all
#   WHICH_TASK: all
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf2
# OPTIM:
#   BATCH_SIZE: 64
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 1000
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_24_13_35_55_ai_aesthetics_optim_centered_bs64_lr2e-4_hd128_256_512_nettype-GraphConvClf2_class-all
#   full_experiment_name: exp_11_24_13_35_55_ai_aesthetics_optim_centered_bs64_lr2e-4_hd128_256_512_nettype-GraphConvClf2_class-all
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train2.yml
# config_override     : []
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# number of training samples: 2076
# Training Samples: 33
# Validation Samples: 100
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 29.645, tensor([8.8800e-01, 6.0000e-03, 1.3135e+01, 1.5616e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 69 %
# Accuracy of the network on validation model set SEMANTIC: 76 %
# Accuracy of the network on validation model set FUNCTIONALITY: 36 %
# Accuracy of the network on validation model set AESTHETICS: 20 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 28.557, tensor([7.8800e-01, 4.0000e-03, 1.2584e+01, 1.5180e+01])
#
# 	 EPOCH 2, totalloss: 27.869, tensor([7.4200e-01, 2.0000e-03, 1.2275e+01, 1.4850e+01])
#
# 	 EPOCH 3, totalloss: 27.428, tensor([7.0600e-01, 1.0000e-03, 1.2149e+01, 1.4572e+01])
#
# 	 EPOCH 4, totalloss: 26.75, tensor([6.6900e-01, 1.0000e-03, 1.1836e+01, 1.4244e+01])
#
# 	 EPOCH 5, totalloss: 26.563, tensor([6.2900e-01, 1.0000e-03, 1.1792e+01, 1.4140e+01])
#
# 	 EPOCH 6, totalloss: 25.876, tensor([5.7200e-01, 1.0000e-03, 1.1479e+01, 1.3823e+01])
#
# 	 EPOCH 7, totalloss: 25.509, tensor([5.6200e-01, 1.0000e-03, 1.1282e+01, 1.3664e+01])
#
# 	 EPOCH 8, totalloss: 25.077, tensor([5.1900e-01, 1.0000e-03, 1.1096e+01, 1.3461e+01])
#
# 	 EPOCH 9, totalloss: 24.698, tensor([5.1100e-01, 1.0000e-03, 1.0850e+01, 1.3336e+01])
#
# 	 EPOCH 10, totalloss: 24.534, tensor([4.9300e-01, 1.0000e-03, 1.0725e+01, 1.3315e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 86 %
# Accuracy of the network on validation model set SEMANTIC: 98 %
# Accuracy of the network on validation model set FUNCTIONALITY: 57 %
# Accuracy of the network on validation model set AESTHETICS: 37 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 11, totalloss: 24.249, tensor([4.7100e-01, 1.0000e-03, 1.0686e+01, 1.3092e+01])
#
# 	 EPOCH 12, totalloss: 23.913, tensor([4.5900e-01, 1.0000e-03, 1.0440e+01, 1.3013e+01])
#
# 	 EPOCH 13, totalloss: 23.683, tensor([4.6800e-01, 1.0000e-03, 1.0343e+01, 1.2871e+01])
#
# 	 EPOCH 14, totalloss: 23.777, tensor([4.3900e-01, 1.0000e-03, 1.0507e+01, 1.2830e+01])
#
# 	 EPOCH 15, totalloss: 23.138, tensor([4.3500e-01, 1.0000e-03, 1.0041e+01, 1.2661e+01])
#
# 	 EPOCH 16, totalloss: 23.023, tensor([4.1300e-01, 1.0000e-03, 1.0099e+01, 1.2511e+01])
#
# 	 EPOCH 17, totalloss: 22.65, tensor([ 0.4090,  0.0000,  9.7240, 12.5170])
#
# 	 EPOCH 18, totalloss: 22.17, tensor([ 0.4050,  0.0000,  9.5170, 12.2480])
#
# 	 EPOCH 19, totalloss: 22.434, tensor([3.7900e-01, 1.0000e-03, 9.7850e+00, 1.2269e+01])
#
# 	 EPOCH 20, totalloss: 22.434, tensor([3.7300e-01, 1.0000e-03, 9.9630e+00, 1.2097e+01])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 86 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 62 %
# Accuracy of the network on validation model set AESTHETICS: 43 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 21, totalloss: 21.674, tensor([ 0.3510,  0.0000,  9.2520, 12.0710])
#
# 	 EPOCH 22, totalloss: 21.27, tensor([ 0.3370,  0.0000,  9.1240, 11.8090])
#
# 	 EPOCH 23, totalloss: 21.365, tensor([ 0.3320,  0.0000,  9.1860, 11.8470])
#
# 	 EPOCH 24, totalloss: 21.983, tensor([ 0.3380,  0.0000,  9.7470, 11.8970])
#
# 	 EPOCH 25, totalloss: 20.921, tensor([3.0300e-01, 1.0000e-03, 9.0070e+00, 1.1611e+01])
#
# 	 EPOCH 26, totalloss: 20.686, tensor([ 0.3150,  0.0000,  8.8790, 11.4920])
#
# 	 EPOCH 27, totalloss: 21.469, tensor([ 0.3030,  0.0000,  9.3210, 11.8440])
#
# 	 EPOCH 28, totalloss: 20.427, tensor([ 0.2960,  0.0000,  8.8420, 11.2880])
#
# 	 EPOCH 29, totalloss: 20.951, tensor([ 0.2910,  0.0000,  8.8710, 11.7890])
#
# 	 EPOCH 30, totalloss: 20.271, tensor([ 0.2740,  0.0000,  8.6830, 11.3140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 91 %
# Accuracy of the network on validation model set SEMANTIC: 99 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 43 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 31, totalloss: 20.082, tensor([ 0.2570,  0.0000,  8.5540, 11.2710])
#
# 	 EPOCH 32, totalloss: 20.557, tensor([ 0.2720,  0.0000,  8.7650, 11.5200])
#
# 	 EPOCH 33, totalloss: 20.739, tensor([ 0.2660,  0.0000,  8.9870, 11.4860])
#
# 	 EPOCH 34, totalloss: 19.567, tensor([ 0.2300,  0.0000,  8.2350, 11.1020])
#
# 	 EPOCH 35, totalloss: 19.495, tensor([ 0.2400,  0.0000,  8.2470, 11.0070])
#
# 	 EPOCH 36, totalloss: 19.177, tensor([ 0.2240,  0.0000,  8.1640, 10.7890])
#
# 	 EPOCH 37, totalloss: 19.382, tensor([ 0.2230,  0.0000,  8.3220, 10.8380])
#
# 	 EPOCH 38, totalloss: 19.32, tensor([ 0.2020,  0.0000,  8.2760, 10.8420])
#
# 	 EPOCH 39, totalloss: 19.442, tensor([ 0.2220,  0.0000,  8.3890, 10.8310])
#
# 	 EPOCH 40, totalloss: 19.34, tensor([ 0.2300,  0.0000,  8.1920, 10.9180])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 93 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 43 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 41, totalloss: 18.894, tensor([ 0.1990,  0.0000,  8.0430, 10.6530])
#
# 	 EPOCH 42, totalloss: 18.467, tensor([ 0.1940,  0.0000,  7.8070, 10.4650])
#
# 	 EPOCH 43, totalloss: 18.864, tensor([ 0.1940,  0.0000,  8.0020, 10.6680])
#
# 	 EPOCH 44, totalloss: 18.229, tensor([ 0.1930,  0.0000,  7.7530, 10.2830])
#
# 	 EPOCH 45, totalloss: 18.368, tensor([ 0.1770,  0.0000,  7.7660, 10.4250])
#
# 	 EPOCH 46, totalloss: 18.918, tensor([ 0.1920,  0.0000,  7.9590, 10.7680])
#
# 	 EPOCH 47, totalloss: 18.367, tensor([ 0.1690,  0.0000,  7.6460, 10.5510])
#
# 	 EPOCH 48, totalloss: 18.016, tensor([ 0.1690,  0.0000,  7.5560, 10.2910])
#
# 	 EPOCH 49, totalloss: 18.463, tensor([ 0.1790,  0.0000,  7.9100, 10.3740])
#
# 	 EPOCH 50, totalloss: 18.081, tensor([ 0.1560,  0.0000,  7.5090, 10.4160])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 96 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 47 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 51, totalloss: 18.09, tensor([ 0.1750,  0.0000,  7.6320, 10.2830])
#
# 	 EPOCH 52, totalloss: 17.685, tensor([ 0.1580,  0.0000,  7.5030, 10.0240])
#
# 	 EPOCH 53, totalloss: 18.617, tensor([ 0.1440,  0.0000,  7.9880, 10.4840])
#
# 	 EPOCH 54, totalloss: 18.091, tensor([ 0.1730,  0.0000,  7.6740, 10.2440])
#
# 	 EPOCH 55, totalloss: 18.297, tensor([ 0.1490,  0.0000,  7.9760, 10.1720])
#
# 	 EPOCH 56, totalloss: 17.188, tensor([0.1310, 0.0000, 7.4150, 9.6420])
# 	 EPOCH 57, totalloss: 16.984, tensor([0.1420, 0.0000, 7.2980, 9.5440])
#
# 	 EPOCH 58, totalloss: 17.23, tensor([0.1330, 0.0000, 7.3370, 9.7590])
#
# 	 EPOCH 59, totalloss: 17.344, tensor([0.1330, 0.0000, 7.3960, 9.8150])
#
# 	 EPOCH 60, totalloss: 17.068, tensor([0.1220, 0.0000, 7.2540, 9.6920])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 93 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 58 %
# Accuracy of the network on validation model set AESTHETICS: 46 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 61, totalloss: 17.453, tensor([0.1280, 0.0000, 7.3790, 9.9460])
#
# 	 EPOCH 62, totalloss: 17.149, tensor([0.1200, 0.0000, 7.3240, 9.7050])
#
# 	 EPOCH 63, totalloss: 16.768, tensor([0.1220, 0.0000, 7.2230, 9.4230])
#
# 	 EPOCH 64, totalloss: 17.201, tensor([0.1080, 0.0000, 7.2460, 9.8460])
#
# 	 EPOCH 65, totalloss: 16.848, tensor([0.1130, 0.0000, 7.2540, 9.4820])
#
# 	 EPOCH 66, totalloss: 16.564, tensor([0.1070, 0.0000, 7.1460, 9.3120])
#
# 	 EPOCH 67, totalloss: 16.467, tensor([0.1310, 0.0000, 6.9160, 9.4200])
#
# 	 EPOCH 68, totalloss: 15.858, tensor([0.1100, 0.0000, 6.7190, 9.0290])
#
# 	 EPOCH 69, totalloss: 16.014, tensor([0.0970, 0.0000, 6.9030, 9.0140])
#
# 	 EPOCH 70, totalloss: 16.714, tensor([0.0940, 0.0000, 7.2050, 9.4160])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 52 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 71, totalloss: 16.018, tensor([0.0970, 0.0000, 6.8020, 9.1200])
#
# 	 EPOCH 72, totalloss: 16.01, tensor([0.1030, 0.0000, 6.9060, 9.0020])
#
# 	 EPOCH 73, totalloss: 15.904, tensor([0.0880, 0.0000, 6.8040, 9.0120])
#
# 	 EPOCH 74, totalloss: 15.664, tensor([0.0990, 0.0000, 6.6510, 8.9140])
#
# 	 EPOCH 75, totalloss: 16.482, tensor([0.0920, 0.0000, 7.0520, 9.3380])
#
# 	 EPOCH 76, totalloss: 16.395, tensor([0.0970, 0.0000, 7.0210, 9.2770])
#
# 	 EPOCH 77, totalloss: 16.786, tensor([0.1040, 0.0000, 7.3960, 9.2850])
#
# 	 EPOCH 78, totalloss: 16.056, tensor([0.1040, 0.0000, 6.9410, 9.0110])
#
# 	 EPOCH 79, totalloss: 15.608, tensor([0.0940, 0.0000, 6.6570, 8.8570])
#
# 	 EPOCH 80, totalloss: 15.612, tensor([0.1010, 0.0000, 6.6340, 8.8780])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 97 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 53 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 81, totalloss: 15.507, tensor([0.0890, 0.0000, 6.6990, 8.7180])
#
# 	 EPOCH 82, totalloss: 15.812, tensor([0.0770, 0.0000, 6.7040, 9.0310])
#
# 	 EPOCH 83, totalloss: 16.154, tensor([0.0920, 0.0000, 6.9460, 9.1170])
#
# 	 EPOCH 84, totalloss: 15.321, tensor([0.0980, 0.0000, 6.4800, 8.7440])
#
# 	 EPOCH 85, totalloss: 15.636, tensor([0.0790, 0.0000, 6.6620, 8.8950])
#
# 	 EPOCH 86, totalloss: 15.148, tensor([0.0770, 0.0000, 6.4090, 8.6620])
#
# 	 EPOCH 87, totalloss: 15.153, tensor([0.0720, 0.0000, 6.5090, 8.5710])
#
# 	 EPOCH 88, totalloss: 14.891, tensor([0.0660, 0.0000, 6.4060, 8.4200])
#
# 	 EPOCH 89, totalloss: 15.415, tensor([0.0780, 0.0000, 6.7370, 8.6000])
#
# 	 EPOCH 90, totalloss: 15.22, tensor([0.0740, 0.0000, 6.7540, 8.3920])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 91, totalloss: 15.731, tensor([0.0700, 0.0000, 7.0100, 8.6520])
#
# 	 EPOCH 92, totalloss: 15.036, tensor([0.0620, 0.0000, 6.4050, 8.5700])
#
# 	 EPOCH 93, totalloss: 14.831, tensor([0.0660, 0.0000, 6.3130, 8.4530])
#
# 	 EPOCH 94, totalloss: 14.613, tensor([0.0610, 0.0000, 6.3340, 8.2180])
#
# 	 EPOCH 95, totalloss: 14.484, tensor([0.0610, 0.0000, 6.2850, 8.1380])
#
# 	 EPOCH 96, totalloss: 14.458, tensor([0.0630, 0.0000, 6.1970, 8.1990])
#
# 	 EPOCH 97, totalloss: 15.166, tensor([0.0500, 0.0000, 6.5130, 8.6040])
#
# 	 EPOCH 98, totalloss: 14.857, tensor([0.0620, 0.0000, 6.3090, 8.4860])
#
# 	 EPOCH 99, totalloss: 14.622, tensor([0.0710, 0.0000, 6.2630, 8.2890])
#
# 	 EPOCH 100, totalloss: 14.605, tensor([0.0610, 0.0000, 6.4020, 8.1420])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 54 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 101, totalloss: 14.56, tensor([0.0580, 0.0000, 6.1370, 8.3650])
#
# 	 EPOCH 102, totalloss: 14.597, tensor([0.0550, 0.0000, 6.0880, 8.4540])
#
# 	 EPOCH 103, totalloss: 14.805, tensor([0.0630, 0.0000, 6.3740, 8.3680])
#
# 	 EPOCH 104, totalloss: 14.742, tensor([0.0800, 0.0000, 6.4500, 8.2120])
#
# 	 EPOCH 105, totalloss: 14.113, tensor([0.0730, 0.0000, 5.9190, 8.1210])
#
# 	 EPOCH 106, totalloss: 16.574, tensor([0.1020, 0.0000, 6.9780, 9.4930])
#
# 	 EPOCH 107, totalloss: 14.825, tensor([0.0730, 0.0000, 6.3540, 8.3970])
#
# 	 EPOCH 108, totalloss: 14.92, tensor([0.0560, 0.0000, 6.4630, 8.4010])
#
# 	 EPOCH 109, totalloss: 14.16, tensor([0.0580, 0.0000, 6.1630, 7.9400])
#
# 	 EPOCH 110, totalloss: 14.019, tensor([0.0490, 0.0000, 5.9850, 7.9840])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 111, totalloss: 14.856, tensor([0.0530, 0.0000, 6.3770, 8.4260])
#
# 	 EPOCH 112, totalloss: 14.774, tensor([0.0630, 0.0000, 6.5410, 8.1700])
#
# 	 EPOCH 113, totalloss: 13.684, tensor([0.0460, 0.0000, 5.9640, 7.6740])
#
# 	 EPOCH 114, totalloss: 13.821, tensor([0.0460, 0.0000, 5.9910, 7.7840])
#
# 	 EPOCH 115, totalloss: 14.221, tensor([0.0540, 0.0000, 6.0800, 8.0870])
#
# 	 EPOCH 116, totalloss: 13.397, tensor([0.0460, 0.0000, 5.8160, 7.5350])
#
# 	 EPOCH 117, totalloss: 13.886, tensor([0.0430, 0.0000, 5.9000, 7.9430])
#
# 	 EPOCH 118, totalloss: 14.025, tensor([0.0560, 0.0000, 6.0270, 7.9430])
#
# 	 EPOCH 119, totalloss: 13.59, tensor([0.0520, 0.0000, 5.9670, 7.5710])
#
# 	 EPOCH 120, totalloss: 14.164, tensor([0.0650, 0.0000, 6.2060, 7.8930])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 98 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 121, totalloss: 14.046, tensor([0.0550, 0.0000, 6.2500, 7.7400])
#
# 	 EPOCH 122, totalloss: 13.826, tensor([0.0450, 0.0000, 6.0090, 7.7720])
#
# 	 EPOCH 123, totalloss: 14.38, tensor([0.0500, 0.0000, 6.2550, 8.0760])
#
# 	 EPOCH 124, totalloss: 13.724, tensor([0.0460, 0.0000, 6.0000, 7.6780])
#
# 	 EPOCH 125, totalloss: 13.899, tensor([0.0450, 0.0000, 6.0320, 7.8230])
#
# 	 EPOCH 126, totalloss: 13.345, tensor([0.0420, 0.0000, 5.7560, 7.5460])
#
# 	 EPOCH 127, totalloss: 13.471, tensor([0.0450, 0.0000, 5.9700, 7.4570])
#
# 	 EPOCH 128, totalloss: 13.236, tensor([0.0400, 0.0000, 5.7420, 7.4550])
# 	 EPOCH 129, totalloss: 13.493, tensor([0.0370, 0.0000, 5.9330, 7.5230])
#
# 	 EPOCH 130, totalloss: 13.5, tensor([0.0470, 0.0000, 5.9700, 7.4820])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 55 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 131, totalloss: 13.692, tensor([0.0460, 0.0000, 5.8950, 7.7510])
#
# 	 EPOCH 132, totalloss: 13.618, tensor([0.0350, 0.0000, 5.8920, 7.6910])
#
# 	 EPOCH 133, totalloss: 13.434, tensor([0.0340, 0.0000, 5.8330, 7.5670])
#
# 	 EPOCH 134, totalloss: 13.425, tensor([0.0490, 0.0000, 5.8070, 7.5680])
#
# 	 EPOCH 135, totalloss: 13.609, tensor([0.0490, 0.0000, 5.8710, 7.6890])
#
# 	 EPOCH 136, totalloss: 13.532, tensor([0.0390, 0.0000, 5.9160, 7.5770])
#
# 	 EPOCH 137, totalloss: 13.222, tensor([0.0390, 0.0000, 5.7970, 7.3860])
#
# 	 EPOCH 138, totalloss: 13.474, tensor([0.0360, 0.0000, 5.7140, 7.7240])
#
# 	 EPOCH 139, totalloss: 13.454, tensor([0.0350, 0.0000, 5.9320, 7.4870])
#
# 	 EPOCH 140, totalloss: 13.146, tensor([0.0370, 0.0000, 5.5450, 7.5640])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 141, totalloss: 13.16, tensor([0.0330, 0.0000, 5.7180, 7.4090])
#
# 	 EPOCH 142, totalloss: 13.424, tensor([0.0440, 0.0000, 5.6860, 7.6930])
#
# 	 EPOCH 143, totalloss: 12.769, tensor([0.0360, 0.0000, 5.5660, 7.1670])
#
# 	 EPOCH 144, totalloss: 13.196, tensor([0.0370, 0.0000, 5.7170, 7.4430])
#
# 	 EPOCH 145, totalloss: 13.444, tensor([0.0390, 0.0000, 5.7990, 7.6060])
#
# 	 EPOCH 146, totalloss: 13.247, tensor([0.0390, 0.0000, 5.6480, 7.5600])
#
# 	 EPOCH 147, totalloss: 12.891, tensor([0.0290, 0.0000, 5.5580, 7.3040])
#
# 	 EPOCH 148, totalloss: 13.161, tensor([0.0390, 0.0000, 5.7740, 7.3480])
#
# 	 EPOCH 149, totalloss: 13.328, tensor([0.0300, 0.0000, 5.8490, 7.4500])
#
# 	 EPOCH 150, totalloss: 13.051, tensor([0.0330, 0.0000, 5.6850, 7.3320])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 151, totalloss: 13.159, tensor([0.0390, 0.0000, 5.6550, 7.4650])
#
# 	 EPOCH 152, totalloss: 12.742, tensor([0.0420, 0.0000, 5.5930, 7.1070])
#
# 	 EPOCH 153, totalloss: 12.754, tensor([0.0390, 0.0000, 5.4830, 7.2320])
#
# 	 EPOCH 154, totalloss: 12.382, tensor([0.0260, 0.0000, 5.4480, 6.9080])
#
# 	 EPOCH 155, totalloss: 12.741, tensor([0.0330, 0.0000, 5.4950, 7.2130])
#
# 	 EPOCH 156, totalloss: 12.826, tensor([0.0280, 0.0000, 5.5770, 7.2210])
#
# 	 EPOCH 157, totalloss: 12.442, tensor([0.0330, 0.0000, 5.3200, 7.0900])
#
# 	 EPOCH 158, totalloss: 12.552, tensor([0.0250, 0.0000, 5.4170, 7.1100])
#
# 	 EPOCH 159, totalloss: 12.579, tensor([0.0330, 0.0000, 5.4810, 7.0650])
#
# 	 EPOCH 160, totalloss: 12.888, tensor([0.0430, 0.0000, 5.5300, 7.3150])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 56 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 161, totalloss: 12.456, tensor([0.0280, 0.0000, 5.4090, 7.0190])
#
# 	 EPOCH 162, totalloss: 12.947, tensor([0.0430, 0.0000, 5.6440, 7.2600])
#
# 	 EPOCH 163, totalloss: 12.734, tensor([0.0490, 0.0000, 5.6210, 7.0640])
#
# 	 EPOCH 164, totalloss: 13.063, tensor([0.0350, 0.0000, 5.5700, 7.4580])
#
# 	 EPOCH 165, totalloss: 12.681, tensor([0.0310, 0.0000, 5.5150, 7.1350])
#
# 	 EPOCH 166, totalloss: 12.786, tensor([0.0300, 0.0000, 5.5700, 7.1860])
#
# 	 EPOCH 167, totalloss: 12.313, tensor([0.0290, 0.0000, 5.3210, 6.9630])
#
# 	 EPOCH 168, totalloss: 12.362, tensor([0.0270, 0.0000, 5.3420, 6.9930])
#
# 	 EPOCH 169, totalloss: 12.626, tensor([0.0430, 0.0000, 5.6400, 6.9430])
#
# 	 EPOCH 170, totalloss: 12.624, tensor([0.0370, 0.0000, 5.5480, 7.0400])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 171, totalloss: 12.53, tensor([0.0230, 0.0000, 5.3940, 7.1130])
#
# 	 EPOCH 172, totalloss: 12.066, tensor([0.0280, 0.0000, 5.3080, 6.7290])
#
# 	 EPOCH 173, totalloss: 12.243, tensor([0.0320, 0.0000, 5.2890, 6.9220])
#
# 	 EPOCH 174, totalloss: 12.211, tensor([0.0220, 0.0000, 5.3450, 6.8440])
#
# 	 EPOCH 175, totalloss: 12.294, tensor([0.0350, 0.0000, 5.3190, 6.9400])
#
# 	 EPOCH 176, totalloss: 12.534, tensor([0.0340, 0.0000, 5.3280, 7.1730])
#
# 	 EPOCH 177, totalloss: 12.817, tensor([0.0340, 0.0000, 5.6500, 7.1340])
#
# 	 EPOCH 178, totalloss: 12.084, tensor([0.0320, 0.0000, 5.3260, 6.7260])
#
# 	 EPOCH 179, totalloss: 12.321, tensor([0.0260, 0.0000, 5.3680, 6.9270])
#
# 	 EPOCH 180, totalloss: 12.104, tensor([0.0260, 0.0000, 5.1920, 6.8870])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 181, totalloss: 12.847, tensor([0.0270, 0.0000, 5.7570, 7.0630])
#
# 	 EPOCH 182, totalloss: 12.173, tensor([0.0260, 0.0000, 5.3710, 6.7750])
#
# 	 EPOCH 183, totalloss: 11.954, tensor([0.0270, 0.0000, 5.1530, 6.7740])
#
# 	 EPOCH 184, totalloss: 11.892, tensor([0.0260, 0.0000, 5.1320, 6.7340])
#
# 	 EPOCH 185, totalloss: 11.952, tensor([0.0260, 0.0000, 5.3170, 6.6090])
#
# 	 EPOCH 186, totalloss: 12.092, tensor([0.0280, 0.0000, 5.3990, 6.6650])
#
# 	 EPOCH 187, totalloss: 12.501, tensor([0.0260, 0.0000, 5.3860, 7.0880])
#
# 	 EPOCH 188, totalloss: 12.066, tensor([0.0200, 0.0000, 5.1880, 6.8580])
#
# 	 EPOCH 189, totalloss: 11.793, tensor([0.0290, 0.0000, 5.2810, 6.4840])
#
# 	 EPOCH 190, totalloss: 12.138, tensor([0.0240, 0.0000, 5.2330, 6.8810])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 58 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 191, totalloss: 12.238, tensor([0.0220, 0.0000, 5.3010, 6.9150])
#
# 	 EPOCH 192, totalloss: 12.27, tensor([0.0240, 0.0000, 5.3050, 6.9400])
#
# 	 EPOCH 193, totalloss: 12.156, tensor([0.0280, 0.0000, 5.2220, 6.9070])
#
# 	 EPOCH 194, totalloss: 12.015, tensor([0.0210, 0.0000, 5.2660, 6.7280])
#
# 	 EPOCH 195, totalloss: 12.212, tensor([0.0250, 0.0000, 5.3910, 6.7960])
#
# 	 EPOCH 196, totalloss: 11.97, tensor([0.0300, 0.0000, 5.2340, 6.7060])
#
# 	 EPOCH 197, totalloss: 12.068, tensor([0.0260, 0.0000, 5.3350, 6.7080])
#
# 	 EPOCH 198, totalloss: 11.637, tensor([0.0290, 0.0000, 5.0590, 6.5500])
#
# 	 EPOCH 199, totalloss: 12.014, tensor([0.0240, 0.0000, 5.0740, 6.9160])
#
# 	 EPOCH 200, totalloss: 12.079, tensor([0.0240, 0.0000, 5.3270, 6.7270])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 201, totalloss: 11.851, tensor([0.0220, 0.0000, 5.2050, 6.6250])
#
# 	 EPOCH 202, totalloss: 11.839, tensor([0.0220, 0.0000, 5.3580, 6.4590])
#
# 	 EPOCH 203, totalloss: 11.646, tensor([0.0210, 0.0000, 5.1050, 6.5190])
#
# 	 EPOCH 204, totalloss: 11.885, tensor([0.0190, 0.0000, 5.1010, 6.7650])
#
# 	 EPOCH 205, totalloss: 11.474, tensor([0.0240, 0.0000, 5.0220, 6.4290])
#
# 	 EPOCH 206, totalloss: 11.864, tensor([0.0260, 0.0000, 5.2150, 6.6230])
#
# 	 EPOCH 207, totalloss: 11.545, tensor([0.0180, 0.0000, 4.9760, 6.5500])
#
# 	 EPOCH 208, totalloss: 12.131, tensor([0.0240, 0.0000, 5.2790, 6.8290])
#
# 	 EPOCH 209, totalloss: 12.178, tensor([0.0170, 0.0000, 5.0870, 7.0730])
#
# 	 EPOCH 210, totalloss: 12.363, tensor([0.0180, 0.0000, 5.3740, 6.9710])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 57 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 211, totalloss: 11.928, tensor([0.0210, 0.0000, 5.2370, 6.6700])
#
# 	 EPOCH 212, totalloss: 11.79, tensor([0.0220, 0.0000, 5.3020, 6.4670])
#
# 	 EPOCH 213, totalloss: 11.77, tensor([0.0250, 0.0000, 5.0220, 6.7230])
#
# 	 EPOCH 214, totalloss: 11.743, tensor([0.0280, 0.0000, 5.2130, 6.5030])
#
# 	 EPOCH 215, totalloss: 11.443, tensor([0.0230, 0.0000, 5.0360, 6.3840])
#
# 	 EPOCH 216, totalloss: 11.489, tensor([0.0300, 0.0000, 4.8890, 6.5700])
#
# 	 EPOCH 217, totalloss: 11.399, tensor([0.0200, 0.0000, 5.0500, 6.3290])
#
# 	 EPOCH 218, totalloss: 11.651, tensor([0.0210, 0.0000, 5.1320, 6.4980])
#
# 	 EPOCH 219, totalloss: 11.34, tensor([0.0150, 0.0000, 5.1260, 6.1980])
#
# 	 EPOCH 220, totalloss: 11.393, tensor([0.0190, 0.0000, 4.9320, 6.4410])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 221, totalloss: 10.962, tensor([0.0170, 0.0000, 4.8730, 6.0710])
#
# 	 EPOCH 222, totalloss: 10.878, tensor([0.0160, 0.0000, 4.7570, 6.1050])
#
# 	 EPOCH 223, totalloss: 11.58, tensor([0.0170, 0.0000, 5.1790, 6.3850])
#
# 	 EPOCH 224, totalloss: 11.738, tensor([0.0300, 0.0000, 4.9780, 6.7300])
#
# 	 EPOCH 225, totalloss: 11.502, tensor([0.0220, 0.0000, 4.9540, 6.5260])
#
# 	 EPOCH 226, totalloss: 11.449, tensor([0.0190, 0.0000, 5.0070, 6.4230])
#
# 	 EPOCH 227, totalloss: 12.029, tensor([0.0270, 0.0000, 5.4230, 6.5790])
#
# 	 EPOCH 228, totalloss: 11.051, tensor([0.0180, 0.0000, 4.9680, 6.0650])
#
# 	 EPOCH 229, totalloss: 11.557, tensor([0.0160, 0.0000, 5.1870, 6.3550])
#
# 	 EPOCH 230, totalloss: 11.372, tensor([0.0230, 0.0000, 4.9480, 6.4010])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 231, totalloss: 11.388, tensor([0.0160, 0.0000, 4.9270, 6.4440])
#
# 	 EPOCH 232, totalloss: 11.349, tensor([0.0150, 0.0000, 5.1100, 6.2240])
#
# 	 EPOCH 233, totalloss: 11.249, tensor([0.0160, 0.0000, 4.9130, 6.3200])
#
# 	 EPOCH 234, totalloss: 11.254, tensor([0.0300, 0.0000, 4.9730, 6.2510])
#
# 	 EPOCH 235, totalloss: 11.099, tensor([0.0140, 0.0000, 5.0130, 6.0710])
#
# 	 EPOCH 236, totalloss: 11.269, tensor([0.0180, 0.0000, 4.9350, 6.3150])
#
# 	 EPOCH 237, totalloss: 10.969, tensor([0.0150, 0.0000, 4.8160, 6.1380])
#
# 	 EPOCH 238, totalloss: 11.466, tensor([0.0180, 0.0000, 4.9220, 6.5260])
#
# 	 EPOCH 239, totalloss: 11.637, tensor([0.0220, 0.0000, 5.0100, 6.6060])
#
# 	 EPOCH 240, totalloss: 11.856, tensor([0.0260, 0.0000, 5.1920, 6.6380])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 241, totalloss: 11.087, tensor([0.0190, 0.0000, 4.9990, 6.0690])
#
# 	 EPOCH 242, totalloss: 11.137, tensor([0.0180, 0.0000, 4.8310, 6.2880])
#
# 	 EPOCH 243, totalloss: 11.22, tensor([0.0140, 0.0000, 4.9990, 6.2070])
#
# 	 EPOCH 244, totalloss: 10.94, tensor([0.0140, 0.0000, 4.8040, 6.1220])
#
# 	 EPOCH 245, totalloss: 11.365, tensor([0.0140, 0.0000, 5.0060, 6.3450])
#
# 	 EPOCH 246, totalloss: 11.223, tensor([0.0140, 0.0000, 4.9250, 6.2840])
#
# 	 EPOCH 247, totalloss: 11.481, tensor([0.0120, 0.0000, 5.0470, 6.4220])
#
# 	 EPOCH 248, totalloss: 11.143, tensor([0.0180, 0.0000, 4.7880, 6.3380])
#
# 	 EPOCH 249, totalloss: 10.975, tensor([0.0200, 0.0000, 4.8060, 6.1490])
#
# 	 EPOCH 250, totalloss: 11.206, tensor([0.0110, 0.0000, 4.7900, 6.4050])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 251, totalloss: 11.122, tensor([0.0210, 0.0000, 4.8410, 6.2600])
#
# 	 EPOCH 252, totalloss: 11.012, tensor([0.0170, 0.0000, 4.8410, 6.1540])
#
# 	 EPOCH 253, totalloss: 11.061, tensor([0.0220, 0.0000, 4.8710, 6.1690])
#
# 	 EPOCH 254, totalloss: 11.319, tensor([0.0210, 0.0000, 4.8460, 6.4520])
#
# 	 EPOCH 255, totalloss: 11.299, tensor([0.0210, 0.0000, 4.9610, 6.3170])
#
# 	 EPOCH 256, totalloss: 10.921, tensor([0.0170, 0.0000, 4.8430, 6.0610])
#
# 	 EPOCH 257, totalloss: 11.046, tensor([0.0140, 0.0000, 4.6980, 6.3330])
#
# 	 EPOCH 258, totalloss: 11.804, tensor([0.0170, 0.0000, 5.1370, 6.6500])
#
# 	 EPOCH 259, totalloss: 11.331, tensor([0.0220, 0.0000, 5.0230, 6.2860])
#
# 	 EPOCH 260, totalloss: 10.957, tensor([0.0110, 0.0000, 4.7130, 6.2320])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 76 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 261, totalloss: 11.335, tensor([0.0130, 0.0000, 4.8910, 6.4300])
#
# 	 EPOCH 262, totalloss: 11.06, tensor([0.0120, 0.0000, 4.8480, 6.2000])
#
# 	 EPOCH 263, totalloss: 10.995, tensor([0.0160, 0.0000, 4.6390, 6.3400])
#
# 	 EPOCH 264, totalloss: 11.19, tensor([0.0150, 0.0000, 4.9680, 6.2060])
#
# 	 EPOCH 265, totalloss: 10.755, tensor([0.0190, 0.0000, 4.6040, 6.1320])
#
# 	 EPOCH 266, totalloss: 10.677, tensor([0.0130, 0.0000, 4.7000, 5.9640])
#
# 	 EPOCH 267, totalloss: 11.109, tensor([0.0140, 0.0000, 4.6890, 6.4060])
#
# 	 EPOCH 268, totalloss: 10.643, tensor([0.0170, 0.0000, 4.7500, 5.8770])
#
# 	 EPOCH 269, totalloss: 10.578, tensor([0.0130, 0.0000, 4.5630, 6.0020])
#
# 	 EPOCH 270, totalloss: 11.246, tensor([0.0240, 0.0000, 4.8850, 6.3370])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
# 	 EPOCH 271, totalloss: 11.038, tensor([0.0210, 0.0000, 4.8240, 6.1940])
#
# 	 EPOCH 272, totalloss: 10.584, tensor([0.0110, 0.0000, 4.5480, 6.0250])
#
# 	 EPOCH 273, totalloss: 10.58, tensor([0.0110, 0.0000, 4.6920, 5.8770])
#
# 	 EPOCH 274, totalloss: 10.796, tensor([0.0130, 0.0000, 4.8960, 5.8870])
#
# 	 EPOCH 275, totalloss: 11.148, tensor([0.0160, 0.0000, 4.8990, 6.2330])
#
# 	 EPOCH 276, totalloss: 10.876, tensor([0.0230, 0.0000, 4.7630, 6.0900])
#
# 	 EPOCH 277, totalloss: 10.734, tensor([0.0180, 0.0000, 4.8350, 5.8810])
#
# 	 EPOCH 278, totalloss: 10.478, tensor([0.0140, 0.0000, 4.6130, 5.8510])
#
# 	 EPOCH 279, totalloss: 10.723, tensor([0.0140, 0.0000, 4.5750, 6.1340])
#
# 	 EPOCH 280, totalloss: 10.602, tensor([0.0140, 0.0000, 4.5730, 6.0150])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 281, totalloss: 10.377, tensor([0.0120, 0.0000, 4.4630, 5.9020])
#
# 	 EPOCH 282, totalloss: 10.348, tensor([0.0100, 0.0000, 4.5290, 5.8090])
#
# 	 EPOCH 283, totalloss: 10.716, tensor([0.0130, 0.0000, 4.6130, 6.0900])
#
# 	 EPOCH 284, totalloss: 10.376, tensor([0.0100, 0.0000, 4.5730, 5.7930])
#
# 	 EPOCH 285, totalloss: 10.311, tensor([0.0100, 0.0000, 4.4650, 5.8360])
#
# 	 EPOCH 286, totalloss: 10.537, tensor([0.0140, 0.0000, 4.4500, 6.0730])
#
# 	 EPOCH 287, totalloss: 10.649, tensor([0.0250, 0.0000, 4.6950, 5.9300])
#
# 	 EPOCH 288, totalloss: 10.571, tensor([0.0200, 0.0000, 4.6070, 5.9450])
#
# 	 EPOCH 289, totalloss: 10.603, tensor([0.0120, 0.0000, 4.6900, 5.9010])
#
# 	 EPOCH 290, totalloss: 10.651, tensor([0.0120, 0.0000, 4.7090, 5.9300])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 291, totalloss: 10.695, tensor([0.0130, 0.0000, 4.8130, 5.8700])
#
# 	 EPOCH 292, totalloss: 11.0, tensor([0.0150, 0.0000, 4.8790, 6.1070])
#
# 	 EPOCH 293, totalloss: 10.54, tensor([0.0140, 0.0000, 4.6790, 5.8480])
#
# 	 EPOCH 294, totalloss: 10.571, tensor([0.0130, 0.0000, 4.5880, 5.9700])
#
# 	 EPOCH 295, totalloss: 10.546, tensor([0.0150, 0.0000, 4.6650, 5.8660])
#
# 	 EPOCH 296, totalloss: 10.806, tensor([0.0130, 0.0000, 4.7350, 6.0580])
#
# 	 EPOCH 297, totalloss: 10.517, tensor([0.0140, 0.0000, 4.6670, 5.8360])
#
# 	 EPOCH 298, totalloss: 10.803, tensor([0.0260, 0.0000, 4.7520, 6.0250])
#
# 	 EPOCH 299, totalloss: 10.785, tensor([0.0470, 0.0000, 4.6290, 6.1080])
#
# 	 EPOCH 300, totalloss: 10.134, tensor([0.0310, 0.0000, 4.4120, 5.6910])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 301, totalloss: 10.394, tensor([0.0140, 0.0000, 4.6610, 5.7180])
#
# 	 EPOCH 302, totalloss: 10.166, tensor([0.0120, 0.0000, 4.5620, 5.5930])
#
# 	 EPOCH 303, totalloss: 10.181, tensor([0.0110, 0.0000, 4.4810, 5.6890])
#
# 	 EPOCH 304, totalloss: 10.29, tensor([0.0170, 0.0000, 4.4390, 5.8340])
#
# 	 EPOCH 305, totalloss: 10.563, tensor([0.0130, 0.0000, 4.6850, 5.8650])
#
# 	 EPOCH 306, totalloss: 10.557, tensor([0.0110, 0.0000, 4.5990, 5.9460])
#
# 	 EPOCH 307, totalloss: 10.244, tensor([0.0120, 0.0000, 4.4590, 5.7740])
#
# 	 EPOCH 308, totalloss: 10.151, tensor([0.0120, 0.0000, 4.4190, 5.7200])
#
# 	 EPOCH 309, totalloss: 10.505, tensor([0.0160, 0.0000, 4.6130, 5.8770])
#
# 	 EPOCH 310, totalloss: 10.853, tensor([0.0290, 0.0000, 4.8780, 5.9460])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 59 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 311, totalloss: 10.543, tensor([0.0160, 0.0000, 4.5900, 5.9370])
#
# 	 EPOCH 312, totalloss: 10.055, tensor([0.0110, 0.0000, 4.4250, 5.6190])
#
# 	 EPOCH 313, totalloss: 10.253, tensor([0.0240, 0.0000, 4.4800, 5.7490])
#
# 	 EPOCH 314, totalloss: 10.177, tensor([0.0150, 0.0000, 4.5000, 5.6620])
#
# 	 EPOCH 315, totalloss: 10.419, tensor([0.0110, 0.0000, 4.4720, 5.9360])
#
# 	 EPOCH 316, totalloss: 9.839, tensor([0.0080, 0.0000, 4.2080, 5.6230])
#
# 	 EPOCH 317, totalloss: 10.08, tensor([0.0100, 0.0000, 4.3740, 5.6960])
#
# 	 EPOCH 318, totalloss: 10.399, tensor([0.0100, 0.0000, 4.5450, 5.8440])
#
# 	 EPOCH 319, totalloss: 10.446, tensor([0.0100, 0.0000, 4.5160, 5.9210])
#
# 	 EPOCH 320, totalloss: 10.323, tensor([0.0160, 0.0000, 4.5640, 5.7430])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 66 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 321, totalloss: 10.259, tensor([0.0100, 0.0000, 4.5230, 5.7260])
#
# 	 EPOCH 322, totalloss: 10.069, tensor([0.0080, 0.0000, 4.3860, 5.6750])
#
# 	 EPOCH 323, totalloss: 9.948, tensor([0.0130, 0.0000, 4.3920, 5.5440])
#
# 	 EPOCH 324, totalloss: 10.237, tensor([0.0120, 0.0000, 4.5020, 5.7220])
#
# 	 EPOCH 325, totalloss: 10.888, tensor([0.0120, 0.0000, 4.8070, 6.0680])
#
# 	 EPOCH 326, totalloss: 10.457, tensor([0.0130, 0.0000, 4.5560, 5.8880])
#
# 	 EPOCH 327, totalloss: 10.107, tensor([0.0110, 0.0000, 4.3420, 5.7550])
#
# 	 EPOCH 328, totalloss: 10.097, tensor([0.0130, 0.0000, 4.4510, 5.6330])
#
# 	 EPOCH 329, totalloss: 10.127, tensor([0.0130, 0.0000, 4.4260, 5.6880])
#
# 	 EPOCH 330, totalloss: 10.207, tensor([0.0090, 0.0000, 4.5310, 5.6670])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 75 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 331, totalloss: 10.088, tensor([0.0080, 0.0000, 4.5120, 5.5680])
#
# 	 EPOCH 332, totalloss: 9.911, tensor([0.0090, 0.0000, 4.3820, 5.5190])
#
# 	 EPOCH 333, totalloss: 10.486, tensor([0.0110, 0.0000, 4.6870, 5.7890])
#
# 	 EPOCH 334, totalloss: 10.725, tensor([0.0110, 0.0000, 4.8840, 5.8300])
#
# 	 EPOCH 335, totalloss: 10.369, tensor([0.0080, 0.0000, 4.4900, 5.8710])
#
# 	 EPOCH 336, totalloss: 10.126, tensor([0.0150, 0.0000, 4.4980, 5.6130])
#
# 	 EPOCH 337, totalloss: 10.115, tensor([0.0150, 0.0000, 4.4140, 5.6860])
#
# 	 EPOCH 338, totalloss: 10.191, tensor([0.0110, 0.0000, 4.4950, 5.6850])
#
# 	 EPOCH 339, totalloss: 10.585, tensor([0.0080, 0.0000, 4.7950, 5.7820])
#
# 	 EPOCH 340, totalloss: 10.362, tensor([0.0080, 0.0000, 4.7080, 5.6460])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 70 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 341, totalloss: 9.978, tensor([0.0100, 0.0000, 4.2760, 5.6930])
#
# 	 EPOCH 342, totalloss: 10.069, tensor([0.0110, 0.0000, 4.3920, 5.6660])
# 	 EPOCH 343, totalloss: 10.049, tensor([0.0070, 0.0000, 4.3380, 5.7040])
#
# 	 EPOCH 344, totalloss: 10.151, tensor([0.0100, 0.0000, 4.5080, 5.6330])
#
# 	 EPOCH 345, totalloss: 9.922, tensor([0.0130, 0.0000, 4.3690, 5.5400])
#
# 	 EPOCH 346, totalloss: 9.945, tensor([0.0120, 0.0000, 4.3930, 5.5400])
#
# 	 EPOCH 347, totalloss: 10.055, tensor([0.0120, 0.0000, 4.4440, 5.5990])
#
# 	 EPOCH 348, totalloss: 9.816, tensor([0.0080, 0.0000, 4.4270, 5.3810])
#
# 	 EPOCH 349, totalloss: 9.788, tensor([0.0100, 0.0000, 4.3940, 5.3830])
#
# 	 EPOCH 350, totalloss: 10.151, tensor([0.0130, 0.0000, 4.4520, 5.6860])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 351, totalloss: 9.968, tensor([0.0100, 0.0000, 4.4600, 5.4990])
#
# 	 EPOCH 352, totalloss: 9.69, tensor([0.0080, 0.0000, 4.2150, 5.4670])
#
# 	 EPOCH 353, totalloss: 10.093, tensor([0.0130, 0.0000, 4.5010, 5.5790])
#
# 	 EPOCH 354, totalloss: 10.312, tensor([0.0120, 0.0000, 4.6130, 5.6870])
#
# 	 EPOCH 355, totalloss: 9.98, tensor([0.0120, 0.0000, 4.5230, 5.4450])
#
# 	 EPOCH 356, totalloss: 9.801, tensor([0.0140, 0.0000, 4.2100, 5.5780])
#
# 	 EPOCH 357, totalloss: 9.623, tensor([0.0150, 0.0000, 4.1930, 5.4150])
#
# 	 EPOCH 358, totalloss: 10.039, tensor([0.0100, 0.0000, 4.4460, 5.5830])
#
# 	 EPOCH 359, totalloss: 9.797, tensor([0.0100, 0.0000, 4.3440, 5.4430])
#
# 	 EPOCH 360, totalloss: 9.493, tensor([0.0090, 0.0000, 4.2690, 5.2140])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 75 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 361, totalloss: 9.725, tensor([0.0140, 0.0000, 4.2740, 5.4370])
#
# 	 EPOCH 362, totalloss: 9.65, tensor([0.0120, 0.0000, 4.2070, 5.4310])
#
# 	 EPOCH 363, totalloss: 9.841, tensor([0.0130, 0.0000, 4.2240, 5.6040])
#
# 	 EPOCH 364, totalloss: 9.81, tensor([0.0100, 0.0000, 4.2970, 5.5030])
#
# 	 EPOCH 365, totalloss: 9.691, tensor([0.0080, 0.0000, 4.3110, 5.3720])
#
# 	 EPOCH 366, totalloss: 9.439, tensor([0.0090, 0.0000, 4.1420, 5.2880])
#
# 	 EPOCH 367, totalloss: 9.858, tensor([0.0130, 0.0000, 4.2910, 5.5540])
#
# 	 EPOCH 368, totalloss: 9.747, tensor([0.0090, 0.0000, 4.4730, 5.2660])
#
# 	 EPOCH 369, totalloss: 9.773, tensor([0.0150, 0.0000, 4.3030, 5.4560])
#
# 	 EPOCH 370, totalloss: 9.758, tensor([0.0100, 0.0000, 4.3350, 5.4130])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 74 %
# Accuracy of the network on validation model set AESTHETICS: 61 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 371, totalloss: 9.521, tensor([0.0120, 0.0000, 4.1840, 5.3250])
#
# 	 EPOCH 372, totalloss: 9.87, tensor([0.0080, 0.0000, 4.3250, 5.5370])
#
# 	 EPOCH 373, totalloss: 9.969, tensor([0.0140, 0.0000, 4.2690, 5.6860])
#
# 	 EPOCH 374, totalloss: 9.765, tensor([0.0120, 0.0000, 4.3370, 5.4170])
#
# 	 EPOCH 375, totalloss: 10.224, tensor([0.0100, 0.0000, 4.5320, 5.6820])
#
# 	 EPOCH 376, totalloss: 9.77, tensor([0.0080, 0.0000, 4.3510, 5.4100])
#
# 	 EPOCH 377, totalloss: 10.064, tensor([0.0130, 0.0000, 4.2540, 5.7970])
#
# 	 EPOCH 378, totalloss: 10.563, tensor([0.0120, 0.0000, 4.4090, 6.1420])
#
# 	 EPOCH 379, totalloss: 9.665, tensor([0.0140, 0.0000, 4.2030, 5.4470])
#
# 	 EPOCH 380, totalloss: 9.607, tensor([0.0150, 0.0000, 4.2180, 5.3750])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 75 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 381, totalloss: 9.513, tensor([0.0130, 0.0000, 4.2860, 5.2150])
#
# 	 EPOCH 382, totalloss: 9.592, tensor([0.0090, 0.0000, 4.2200, 5.3630])
#
# 	 EPOCH 383, totalloss: 9.841, tensor([0.0090, 0.0000, 4.2220, 5.6100])
#
# 	 EPOCH 384, totalloss: 9.532, tensor([0.0190, 0.0000, 4.1590, 5.3540])
#
# 	 EPOCH 385, totalloss: 9.504, tensor([0.0140, 0.0000, 4.1590, 5.3300])
#
# 	 EPOCH 386, totalloss: 9.835, tensor([0.0080, 0.0000, 4.3080, 5.5180])
#
# 	 EPOCH 387, totalloss: 9.671, tensor([0.0080, 0.0000, 4.3450, 5.3190])
#
# 	 EPOCH 388, totalloss: 9.642, tensor([5.0000e-03, 0.0000e+00, 4.3700e+00, 5.2660e+00])
#
# 	 EPOCH 389, totalloss: 9.502, tensor([0.0070, 0.0000, 4.1670, 5.3280])
#
# 	 EPOCH 390, totalloss: 9.5, tensor([0.0080, 0.0000, 4.1820, 5.3100])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 67 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 391, totalloss: 9.583, tensor([0.0070, 0.0000, 4.1710, 5.4040])
#
# 	 EPOCH 392, totalloss: 9.86, tensor([0.0090, 0.0000, 4.4650, 5.3850])
#
# 	 EPOCH 393, totalloss: 9.549, tensor([0.0070, 0.0000, 4.0650, 5.4770])
#
# 	 EPOCH 394, totalloss: 10.014, tensor([0.0070, 0.0000, 4.4750, 5.5320])
#
# 	 EPOCH 395, totalloss: 9.851, tensor([0.0150, 0.0000, 4.3250, 5.5110])
#
# 	 EPOCH 396, totalloss: 9.726, tensor([0.0100, 0.0000, 4.3120, 5.4050])
#
# 	 EPOCH 397, totalloss: 9.278, tensor([0.0070, 0.0000, 4.0570, 5.2140])
#
# 	 EPOCH 398, totalloss: 9.533, tensor([0.0070, 0.0000, 4.1350, 5.3910])
#
# 	 EPOCH 399, totalloss: 9.775, tensor([0.0090, 0.0000, 4.2880, 5.4790])
#
# 	 EPOCH 400, totalloss: 9.967, tensor([0.0060, 0.0000, 4.1780, 5.7820])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# ...
# --------------------------------------------------------------------------------
#
# 	 EPOCH 871, totalloss: 7.454, tensor([3.0000e-03, 0.0000e+00, 3.2270e+00, 4.2240e+00])
#
# 	 EPOCH 872, totalloss: 7.152, tensor([3.0000e-03, 0.0000e+00, 3.1720e+00, 3.9780e+00])
#
# 	 EPOCH 873, totalloss: 7.494, tensor([4.0000e-03, 0.0000e+00, 3.2990e+00, 4.1910e+00])
#
# 	 EPOCH 874, totalloss: 7.108, tensor([0.0060, 0.0000, 3.1020, 4.0010])
#
# 	 EPOCH 875, totalloss: 7.057, tensor([0.0050, 0.0000, 3.1070, 3.9450])
#
# 	 EPOCH 876, totalloss: 7.293, tensor([0.0070, 0.0000, 3.1740, 4.1120])
#
# 	 EPOCH 877, totalloss: 7.161, tensor([3.0000e-03, 0.0000e+00, 3.1250e+00, 4.0330e+00])
#
# 	 EPOCH 878, totalloss: 7.18, tensor([0.0080, 0.0000, 3.3840, 3.7880])
#
# 	 EPOCH 879, totalloss: 7.678, tensor([0.0120, 0.0000, 3.4660, 4.2000])
#
# 	 EPOCH 880, totalloss: 7.392, tensor([0.0050, 0.0000, 3.4370, 3.9500])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 66 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 881, totalloss: 7.118, tensor([0.0050, 0.0000, 3.2450, 3.8670])
#
# 	 EPOCH 882, totalloss: 7.376, tensor([0.0050, 0.0000, 3.3880, 3.9830])
#
# 	 EPOCH 883, totalloss: 7.388, tensor([4.0000e-03, 0.0000e+00, 3.1860e+00, 4.1990e+00])
#
# 	 EPOCH 884, totalloss: 7.433, tensor([4.0000e-03, 0.0000e+00, 3.3050e+00, 4.1240e+00])
#
# 	 EPOCH 885, totalloss: 7.41, tensor([0.0100, 0.0000, 3.2350, 4.1640])
#
# 	 EPOCH 886, totalloss: 7.21, tensor([0.0080, 0.0000, 3.1480, 4.0540])
#
# 	 EPOCH 887, totalloss: 7.126, tensor([4.0000e-03, 0.0000e+00, 3.0830e+00, 4.0390e+00])
#
# 	 EPOCH 888, totalloss: 7.293, tensor([0.0060, 0.0000, 3.3870, 3.9000])
#
# 	 EPOCH 889, totalloss: 7.491, tensor([3.0000e-03, 0.0000e+00, 3.3430e+00, 4.1450e+00])
#
# 	 EPOCH 890, totalloss: 7.262, tensor([3.0000e-03, 0.0000e+00, 3.1600e+00, 4.0990e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 67 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 891, totalloss: 7.276, tensor([0.0040, 0.0000, 3.3270, 3.9460])
#
# 	 EPOCH 892, totalloss: 7.087, tensor([3.0000e-03, 0.0000e+00, 3.1510e+00, 3.9330e+00])
#
# 	 EPOCH 893, totalloss: 7.428, tensor([3.0000e-03, 0.0000e+00, 3.3600e+00, 4.0650e+00])
#
# 	 EPOCH 894, totalloss: 7.322, tensor([4.0000e-03, 0.0000e+00, 3.2940e+00, 4.0240e+00])
#
# 	 EPOCH 895, totalloss: 7.856, tensor([0.0070, 0.0000, 3.3950, 4.4550])
# 	 EPOCH 896, totalloss: 7.645, tensor([0.0060, 0.0000, 3.3000, 4.3390])
#
# 	 EPOCH 897, totalloss: 7.168, tensor([3.0000e-03, 0.0000e+00, 3.1450e+00, 4.0190e+00])
#
# 	 EPOCH 898, totalloss: 7.165, tensor([3.0000e-03, 0.0000e+00, 3.2080e+00, 3.9530e+00])
#
# 	 EPOCH 899, totalloss: 6.905, tensor([0.0040, 0.0000, 2.9560, 3.9450])
#
# 	 EPOCH 900, totalloss: 6.951, tensor([3.0000e-03, 0.0000e+00, 3.0590e+00, 3.8880e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 901, totalloss: 7.271, tensor([3.0000e-03, 0.0000e+00, 3.1880e+00, 4.0810e+00])
#
# 	 EPOCH 902, totalloss: 7.571, tensor([2.0000e-03, 0.0000e+00, 3.3950e+00, 4.1730e+00])
#
# 	 EPOCH 903, totalloss: 7.178, tensor([3.0000e-03, 0.0000e+00, 3.1220e+00, 4.0520e+00])
#
# 	 EPOCH 904, totalloss: 6.827, tensor([3.0000e-03, 0.0000e+00, 2.9080e+00, 3.9160e+00])
#
# 	 EPOCH 905, totalloss: 7.018, tensor([3.0000e-03, 0.0000e+00, 3.0500e+00, 3.9650e+00])
#
# 	 EPOCH 906, totalloss: 7.356, tensor([2.0000e-03, 0.0000e+00, 3.3060e+00, 4.0480e+00])
#
# 	 EPOCH 907, totalloss: 7.202, tensor([2.0000e-03, 0.0000e+00, 3.1080e+00, 4.0920e+00])
#
# 	 EPOCH 908, totalloss: 7.142, tensor([0.0040, 0.0000, 3.1490, 3.9890])
#
# 	 EPOCH 909, totalloss: 7.123, tensor([0.0040, 0.0000, 3.1390, 3.9790])
#
# 	 EPOCH 910, totalloss: 7.135, tensor([0.0040, 0.0000, 3.1310, 4.0000])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 68 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 911, totalloss: 7.352, tensor([4.0000e-03, 0.0000e+00, 3.3030e+00, 4.0450e+00])
#
# 	 EPOCH 912, totalloss: 7.174, tensor([3.0000e-03, 0.0000e+00, 3.1300e+00, 4.0410e+00])
#
# 	 EPOCH 913, totalloss: 7.061, tensor([0.0130, 0.0000, 2.9780, 4.0700])
#
# 	 EPOCH 914, totalloss: 7.122, tensor([0.0110, 0.0000, 3.1930, 3.9180])
#
# 	 EPOCH 915, totalloss: 6.968, tensor([3.0000e-03, 0.0000e+00, 3.1010e+00, 3.8640e+00])
#
# 	 EPOCH 916, totalloss: 6.998, tensor([0.0040, 0.0000, 3.1700, 3.8230])
#
# 	 EPOCH 917, totalloss: 7.181, tensor([2.0000e-03, 0.0000e+00, 3.2630e+00, 3.9160e+00])
#
# 	 EPOCH 918, totalloss: 6.972, tensor([0.0100, 0.0000, 3.0670, 3.8950])
#
# 	 EPOCH 919, totalloss: 7.266, tensor([0.0130, 0.0000, 3.1540, 4.0990])
#
# 	 EPOCH 920, totalloss: 7.211, tensor([3.0000e-03, 0.0000e+00, 3.1700e+00, 4.0380e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 79 %
# Accuracy of the network on validation model set AESTHETICS: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 921, totalloss: 7.07, tensor([3.0000e-03, 0.0000e+00, 3.1650e+00, 3.9030e+00])
#
# 	 EPOCH 922, totalloss: 6.983, tensor([4.0000e-03, 0.0000e+00, 2.9540e+00, 4.0250e+00])
#
# 	 EPOCH 923, totalloss: 7.203, tensor([0.0050, 0.0000, 3.2400, 3.9580])
#
# 	 EPOCH 924, totalloss: 7.199, tensor([0.0060, 0.0000, 3.1640, 4.0290])
#
# 	 EPOCH 925, totalloss: 7.154, tensor([3.0000e-03, 0.0000e+00, 3.1480e+00, 4.0030e+00])
#
# 	 EPOCH 926, totalloss: 7.225, tensor([2.0000e-03, 0.0000e+00, 3.2150e+00, 4.0080e+00])
#
# 	 EPOCH 927, totalloss: 7.118, tensor([2.0000e-03, 0.0000e+00, 3.1390e+00, 3.9760e+00])
#
# 	 EPOCH 928, totalloss: 6.887, tensor([2.0000e-03, 0.0000e+00, 3.1250e+00, 3.7610e+00])
#
# 	 EPOCH 929, totalloss: 7.052, tensor([0.0040, 0.0000, 3.1370, 3.9110])
#
# 	 EPOCH 930, totalloss: 7.202, tensor([3.0000e-03, 0.0000e+00, 3.1840e+00, 4.0150e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 60 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 931, totalloss: 7.087, tensor([3.0000e-03, 0.0000e+00, 3.2340e+00, 3.8510e+00])
#
# 	 EPOCH 932, totalloss: 6.934, tensor([0.0040, 0.0000, 3.0270, 3.9040])
#
# 	 EPOCH 933, totalloss: 7.273, tensor([3.0000e-03, 0.0000e+00, 3.2680e+00, 4.0020e+00])
#
# 	 EPOCH 934, totalloss: 6.969, tensor([0.0040, 0.0000, 3.1950, 3.7710])
#
# 	 EPOCH 935, totalloss: 7.331, tensor([0.0040, 0.0000, 3.3960, 3.9310])
#
# 	 EPOCH 936, totalloss: 6.958, tensor([2.0000e-03, 0.0000e+00, 2.9660e+00, 3.9900e+00])
#
# 	 EPOCH 937, totalloss: 6.974, tensor([3.0000e-03, 0.0000e+00, 3.0110e+00, 3.9600e+00])
#
# 	 EPOCH 938, totalloss: 6.987, tensor([0.0040, 0.0000, 3.1270, 3.8560])
#
# 	 EPOCH 939, totalloss: 7.353, tensor([0.0060, 0.0000, 3.2670, 4.0790])
#
# 	 EPOCH 940, totalloss: 7.082, tensor([0.0050, 0.0000, 3.1160, 3.9610])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 63 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 941, totalloss: 6.896, tensor([0.0080, 0.0000, 3.0550, 3.8330])
#
# 	 EPOCH 942, totalloss: 6.984, tensor([0.0070, 0.0000, 3.1520, 3.8250])
#
# 	 EPOCH 943, totalloss: 7.178, tensor([3.0000e-03, 0.0000e+00, 3.1080e+00, 4.0660e+00])
#
# 	 EPOCH 944, totalloss: 7.552, tensor([4.0000e-03, 0.0000e+00, 3.2300e+00, 4.3190e+00])
#
# 	 EPOCH 945, totalloss: 7.112, tensor([0.0050, 0.0000, 3.0800, 4.0280])
#
# 	 EPOCH 946, totalloss: 7.424, tensor([0.0060, 0.0000, 3.3150, 4.1020])
#
# 	 EPOCH 947, totalloss: 6.98, tensor([3.0000e-03, 0.0000e+00, 3.1080e+00, 3.8690e+00])
#
# 	 EPOCH 948, totalloss: 7.272, tensor([4.0000e-03, 0.0000e+00, 3.2040e+00, 4.0640e+00])
#
# 	 EPOCH 949, totalloss: 7.313, tensor([3.0000e-03, 0.0000e+00, 3.1940e+00, 4.1160e+00])
#
# 	 EPOCH 950, totalloss: 7.035, tensor([2.0000e-03, 0.0000e+00, 3.0830e+00, 3.9500e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 62 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 951, totalloss: 6.973, tensor([3.0000e-03, 0.0000e+00, 3.0450e+00, 3.9250e+00])
#
# 	 EPOCH 952, totalloss: 7.284, tensor([0.0040, 0.0000, 3.2800, 4.0000])
#
# 	 EPOCH 953, totalloss: 6.744, tensor([0.0070, 0.0000, 2.9690, 3.7680])
#
# 	 EPOCH 954, totalloss: 6.971, tensor([3.0000e-03, 0.0000e+00, 3.0440e+00, 3.9240e+00])
#
# 	 EPOCH 955, totalloss: 6.918, tensor([3.0000e-03, 0.0000e+00, 2.9850e+00, 3.9300e+00])
#
# 	 EPOCH 956, totalloss: 6.953, tensor([0.0040, 0.0000, 3.1520, 3.7970])
#
# 	 EPOCH 957, totalloss: 7.162, tensor([3.0000e-03, 0.0000e+00, 2.9940e+00, 4.1660e+00])
#
# 	 EPOCH 958, totalloss: 7.504, tensor([4.0000e-03, 0.0000e+00, 3.2290e+00, 4.2700e+00])
#
# 	 EPOCH 959, totalloss: 7.41, tensor([0.0050, 0.0000, 3.2670, 4.1380])
#
# 	 EPOCH 960, totalloss: 6.948, tensor([0.0060, 0.0000, 3.0770, 3.8640])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 100 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 73 %
# Accuracy of the network on validation model set AESTHETICS: 64 %
# --------------------------------------------------------------------------------
# 	 EPOCH 961, totalloss: 7.37, tensor([0.0100, 0.0000, 3.3630, 3.9970])
#
# 	 EPOCH 962, totalloss: 7.328, tensor([0.0070, 0.0000, 3.4040, 3.9180])
#
# 	 EPOCH 963, totalloss: 7.224, tensor([0.0060, 0.0000, 3.1220, 4.0950])
#
# 	 EPOCH 964, totalloss: 6.818, tensor([3.0000e-03, 0.0000e+00, 2.9840e+00, 3.8320e+00])
#
# 	 EPOCH 965, totalloss: 7.031, tensor([4.0000e-03, 0.0000e+00, 3.0130e+00, 4.0140e+00])
#
# 	 EPOCH 966, totalloss: 6.975, tensor([0.0040, 0.0000, 3.0400, 3.9320])
#
# 	 EPOCH 967, totalloss: 6.996, tensor([3.0000e-03, 0.0000e+00, 3.1130e+00, 3.8800e+00])
#
# 	 EPOCH 968, totalloss: 6.984, tensor([0.0050, 0.0000, 3.0830, 3.8960])
#
# 	 EPOCH 969, totalloss: 7.072, tensor([0.0040, 0.0000, 3.1600, 3.9090])
#
# 	 EPOCH 970, totalloss: 7.041, tensor([3.0000e-03, 0.0000e+00, 2.9560e+00, 4.0820e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 71 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 971, totalloss: 6.809, tensor([2.0000e-03, 0.0000e+00, 3.0250e+00, 3.7820e+00])
#
# 	 EPOCH 972, totalloss: 7.219, tensor([2.0000e-03, 0.0000e+00, 3.1670e+00, 4.0490e+00])
#
# 	 EPOCH 973, totalloss: 7.173, tensor([3.0000e-03, 0.0000e+00, 3.0790e+00, 4.0910e+00])
#
# 	 EPOCH 974, totalloss: 6.92, tensor([3.0000e-03, 0.0000e+00, 3.0670e+00, 3.8500e+00])
#
# 	 EPOCH 975, totalloss: 6.869, tensor([3.0000e-03, 0.0000e+00, 3.0490e+00, 3.8180e+00])
#
# 	 EPOCH 976, totalloss: 7.007, tensor([3.0000e-03, 0.0000e+00, 3.0820e+00, 3.9220e+00])
#
# 	 EPOCH 977, totalloss: 7.217, tensor([2.0000e-03, 0.0000e+00, 3.1840e+00, 4.0310e+00])
#
# 	 EPOCH 978, totalloss: 7.045, tensor([3.0000e-03, 0.0000e+00, 3.1490e+00, 3.8930e+00])
#
# 	 EPOCH 979, totalloss: 7.031, tensor([2.0000e-03, 0.0000e+00, 3.1350e+00, 3.8950e+00])
#
# 	 EPOCH 980, totalloss: 7.004, tensor([0.0040, 0.0000, 3.0920, 3.9090])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 72 %
# Accuracy of the network on validation model set AESTHETICS: 70 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 981, totalloss: 6.738, tensor([3.0000e-03, 0.0000e+00, 2.9840e+00, 3.7500e+00])
#
# 	 EPOCH 982, totalloss: 6.838, tensor([2.0000e-03, 0.0000e+00, 3.0990e+00, 3.7370e+00])
#
# 	 EPOCH 983, totalloss: 7.278, tensor([3.0000e-03, 0.0000e+00, 3.2540e+00, 4.0210e+00])
#
# 	 EPOCH 984, totalloss: 7.13, tensor([3.0000e-03, 0.0000e+00, 3.2240e+00, 3.9030e+00])
#
# 	 EPOCH 985, totalloss: 7.125, tensor([3.0000e-03, 0.0000e+00, 3.2070e+00, 3.9140e+00])
#
# 	 EPOCH 986, totalloss: 7.012, tensor([0.0070, 0.0000, 3.1840, 3.8220])
#
# 	 EPOCH 987, totalloss: 7.003, tensor([0.0050, 0.0000, 3.0980, 3.8990])
#
# 	 EPOCH 988, totalloss: 6.847, tensor([0.0040, 0.0000, 2.9720, 3.8700])
#
# 	 EPOCH 989, totalloss: 6.931, tensor([0.0040, 0.0000, 2.9710, 3.9560])
#
# 	 EPOCH 990, totalloss: 7.166, tensor([4.0000e-03, 0.0000e+00, 3.1390e+00, 4.0240e+00])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 69 %
# Accuracy of the network on validation model set AESTHETICS: 69 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 991, totalloss: 7.381, tensor([0.0050, 0.0000, 3.2650, 4.1120])
#
# 	 EPOCH 992, totalloss: 7.095, tensor([2.0000e-03, 0.0000e+00, 3.2120e+00, 3.8800e+00])
#
# 	 EPOCH 993, totalloss: 7.038, tensor([3.0000e-03, 0.0000e+00, 3.1300e+00, 3.9050e+00])
#
# 	 EPOCH 994, totalloss: 7.243, tensor([3.0000e-03, 0.0000e+00, 3.0600e+00, 4.1800e+00])
#
# 	 EPOCH 995, totalloss: 7.055, tensor([0.0050, 0.0000, 3.0460, 4.0040])
#
# 	 EPOCH 996, totalloss: 6.872, tensor([0.0040, 0.0000, 2.9430, 3.9250])
#
# 	 EPOCH 997, totalloss: 6.975, tensor([0.0070, 0.0000, 3.0930, 3.8760])
#
# 	 EPOCH 998, totalloss: 7.205, tensor([4.0000e-03, 0.0000e+00, 3.1130e+00, 4.0870e+00])
#
# 	 EPOCH 999, totalloss: 6.981, tensor([3.0000e-03, 0.0000e+00, 3.1380e+00, 3.8390e+00])
# Finished Training
# Accuracy of the network on validation model set STYLE: 99 %
# Accuracy of the network on validation model set SEMANTIC: 100 %
# Accuracy of the network on validation model set FUNCTIONALITY: 77 %
# Accuracy of the network on validation model set AESTHETICS: 67 %

# %%
## train on single class: columns
# !CUDA_VISIBLE_DEVICES=0 python train_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_column.yml"
# Out:
# RANDOM_SEED: 0
# DATA:
#   PATH: /home/alexandracarlson/Desktop/acadia2020_3daesthetics_dataset
#   SEMCLASS: column
#   WHICH_TASK: all
# BASE_MODEL:
#   CLASSES: 4
#   CONV_INIT: normal
#   HIDDEN_DIMS: [128, 256, 512]
#   INPUT_MESH_FEATS: 3
#   WHICH_GCN_FN: GraphConvClf_singlesemclass
# OPTIM:
#   BATCH_SIZE: 32
#   CLIP_GRADIENTS: 12.5
#   EPOCH: 2500
#   LR: 0.0002
#   MOMENTUM: 0.9
#   VAL_BATCH_SIZE: 1
#   WEIGHT_DECAY: 0.005
#   WORKERS: 8
# CHECKPOINT:
#   best_acc: 0.0
#   best_loss: 1.7976931348623157e+308
#   experiment_path: /tf/notebooks/acadia2020_graphcnn_src/acadia2020_graphcnn_training_results/exp_11_23_12_27_32_ai_aesthetics_optim_nettype-GraphConvClf_singlesemclass_class-column
#   full_experiment_name: exp_11_23_12_27_32_ai_aesthetics_optim_nettype-GraphConvClf_singlesemclass_class-column
#
# config_yml          : /tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_train_singlesemclass_column.yml
# config_override     : []
# Splitting Dataset..
# /tf/notebooks/acadia2020_graphcnn_src/NamingBookV3_lessthan100kverts.csv
# number of training samples: 1450
# Training Samples: 46
# Validation Samples: 100
#
#  ***************** Training *****************
#
# 	 EPOCH 0, totalloss: 29.25, tensor([ 0.9010, 12.8040, 15.5450])
# --------------------------------------------------------------------------------
# Accuracy of the network on validation model set STYLE: 73 %
# Accuracy of the network on validation model set FUNCTIONALITY: 42 %
# Accuracy of the network on validation model set AESTHETICS: 35 %
# --------------------------------------------------------------------------------
#
# 	 EPOCH 1, totalloss: 27.832, tensor([ 0.8010, 12.0710, 14.9600])
#
# 	 EPOCH 2, totalloss: 27.594, tensor([ 0.7580, 11.9120, 14.9230])
#
# 	 EPOCH 3, totalloss: 26.923, tensor([ 0.7270, 11.6690, 14.5280])
#
# 	 EPOCH 4, totalloss: 26.717, tensor([ 0.7240, 11.4500, 14.5440])
#
# 	 EPOCH 5, totalloss: 26.848, tensor([ 0.7110, 11.6820, 14.4560])
#
# 	 EPOCH 6, totalloss: 26.724, tensor([ 0.7020, 11.5930, 14.4280])
#
# 	 EPOCH 7, totalloss: 26.476, tensor([ 0.6850, 11.4140, 14.3770])
# ^C

# %%
## test pretrained network
# !python test_aesthetics.py --config-yml "/tf/notebooks/acadia2020_graphcnn_src/config/mesh2aesthetics_test.yml"

# %%
## run the optimization framework; hit 'shift+enter' keys to run
## IMPORTANT INFO about running the acoustic optimization script:
## The Command Format for this script: 
## bash run_acousticoptim.sh INPUT_MESH SILHOUETTE_DEFORM_FLAG SILHOUETTE_REF_IMG ACOUSTIC_DEFORM_FLAG WHICH_ACOUSTIC_PARAMS OUTPUT_NAME
## where `INPUT_MESH_FILEPATH` is the absolute filepath of the mesh you would like to deform
##       `TRAINED_GRAPH_FILEPATH` is the filepath to the trained mesh2aesthetic graph convolutional neural network
##       `STYLE_PARAM` is either 'baroque', 'modern', or 'classic' 
##       `SEM_PARAM`  is either 'house' or 'column'
##       `FUNC_PARAM` is an integer number from [1,2,3,4], where 1 is low functionality and 4 is high functionality
##       `AESTH_PARAM` is an integer number from [1,2,3,4], where 1 is poor aesthetics and 5 is good aesthetics 
##       `OUTPUT_FILENAME` is the absolute filepath where you would like the deformed output mesh to be saved.
##       `NUM_ITERS` is the number of iterations to run the optimization.
##       `CFG_FILE` is the absolute path to the configuration file. You will need to change this to the config file path that you used for training the model (see above cell)
##
## Example Command:
#!cd /storage/concerthall && bash run_acousticoptim.sh \
#                            INPUT_MESH_FILEPATH \
#                            TRAINED_GRAPH_FILEPATH \
#                            STYLE_PARAM \
#                            SEM_PARAM \
#                            FUNC_PARAM \
#                            AESTH_PARAM \
#                            OUTPUT_FILENAME \
#                            NUM_ITERS \
#                            CFG_FILE
#
# !cd /storage/acadia2020_graphcnn && bash run_param_optim.sh \
                            "/storage/3Dmodels/bench.obj" \
                            "/storage/acadia2020_graphcnn_training_results/exp_09_26_14_01_06_ai_aesthetics_optim/model_best_loss.pkl" \
                            "modern" \
                            "house" \
                            4 \
                            5 \
                            "test_sil_deform.obj" \
                            250 \
                            "/storage/acadia2020_graphcnn/config/mesh2aesthetics_train.yml"
